# %% [markdown]
# # <div align="center">CP322-A Mini-Project 1: Machine Learning</div>
# ## <div align="center">Group 6</div>
# ### <div align="center">due on 15-Oct-2023 at 11:30 PM</div>

# %% [markdown]
# Imports:

# %%
import numpy as np
import heapq
from math import sqrt
from collections import Counter
from scipy import stats
import matplotlib.pyplot as plt
import statistics

# %% [markdown]
# ## Task 1: Acquire, preprocess, and analyze the data

# %% [markdown]
# 1. Load the datasets into NumPy objects (i.e., arrays or matrices) in Python. Remember to convert the wine dataset
# to a binary task, as discussed above.
# 2. Clean the data. Are there any missing or malformed features? Are there other data oddities that need to be
# dealt with? You should remove any examples with missing or malformed features and note this in your
# report. For categorical variables, you can use a one-hot encoding.
# 3. Compute basic statistics on the data to understand it better. E.g., what are the distributions of the positive vs.
# negative classes, what are the distributions of some of the numerical features? what are the correlations between
# the features? how do the scatter plots of pair-wise features look like for some subset of features?

# %%
def readFile(filename):
    
    data = []
    labels = []
    with open(filename, "r") as file:
        for line in file:
            line = line.strip()
            if line:  # Skip empty lines
                row = line.split(",")
                if filename=="data/iris.data":
                    data.append([float(val) for val in row[:-1]])
                    labels.append(row[-1])
                elif filename == "Rice_Cammeo_Osmancik.arff.txt":
                    data.append([float(val) for val in row[:-1]])
                    label = row[-1]
                    labels.append(0 if label == 'Cammeo' else 1)
                else:
                    if "?" not in row and " ?" not in row:
                        data.append(row)

    data = np.array(data)
    if filename == "data/iris.data" or "Rice_Cammeo_Osmancik.arff.txt":
        return np.array(data),np.array(labels)
    else:
        return data
    
def readFileLog(filename):
    data = []
    labels = []
    with open(filename, "r") as file:
        for line in file:
            line = line.strip()
            if line:  # Skip empty lines
                row = line.split(",")
                if filename == "adult.data":
                    # Convert non-numerical features to float
                    age = float(row[0])
                    fnlwgt = float(row[2])
                    education_num = float(row[4])
                    capital_gain = float(row[10])
                    capital_loss = float(row[11])
                    hours_per_week = float(row[12])
                    # Combine the numerical features
                    numerical_features = [age, fnlwgt, education_num, capital_gain, capital_loss, hours_per_week]
                    # Append the numerical features
                    data.append(numerical_features)
                    label = row[-1]
                    # Map the labels to binary values, e.g., '<=50K' to 0 and '>50K' to 1
                    labels.append(0 if label == ' <=50K' else 1)
                elif filename == "Rice_Cammeo_Osmancik.arff.txt":
                    data.append([float(val) for val in row[:-1]])
                    label = row[-1]
                    labels.append(0 if label == 'Cammeo' else 1)
                elif filename == "data/agaricus-lepiota.data":
                    label = row[0]
                    if "?" not in row:
                        labels.append("poisonous" if label == 'e' else 'edible')
                        data.append([val for val in row[:-1]])  
                        
                else:
                    data.append([float(val) for val in row[:-1]])
                    label = row[-1]
                    labels.append(0 if label == 'b' else 1)


    return data, labels
    
class dataAnalysis:
    def __init__(self, data, categories, classifications):
        self.data = data
        self.size = len(data)
        self.categories = categories
        self.classifications = classifications
    def printLabelStats(self):
        '''
        ===================================================================================
        DESCRIPTION: 
        ===================================================================================
        Print statistics on every classification in data
        ===================================================================================
        '''
        print("=====================================================")
        print("Classification Analysis:")
        print("=====================================================")
        print(f"Total: {self.size} (%100)")
        
        for label in self.classifications:
            count = len(self.data[self.data[:, -1] == label])
            percentage = round(100*count/self.size,2)
            print(f"Value: {label}, Count: {count}, Percentage: %{percentage}")
            
    def printCategoryStats(self):
        '''
        ===================================================================================
        DESCRIPTION: 
        ===================================================================================
        Print statistics on every attribute in data
        ===================================================================================
        '''
        data = self.data
        categories = self.categories
        size = self.size
        labels = column = data[:, -1]
        print("=====================================================")
        print("Attribute Analysis:")
        print("=====================================================")
        for i in range(len(categories)):
            category = categories[i]
            column = data[:, i].astype(float)
            
            avg = np.mean(column)
            med = np.median(column)
            mode = float(stats.mode(column,keepdims=True)[0][0])
            std_dev = np.std(column)
        
            unique_values, counts = np.unique(column, return_counts=True)
            
            print("-----------------------------------------------------")
            print(f"{category.upper()} Analysis:")
            print("-----------------------------------------------------")
            for value, count in zip(unique_values, counts):
                percentage = round(100*count/self.size,2)
                print(f"Value: {value}, Count: {count}, Percentage: %{percentage}")
                
            print(f"\nMean: {avg}")
            print(f"Median: {med}")
            print(f"Mode: {mode}")
            print(f"Standard Deviation: {std_dev}")
            
#             plt.figure(figsize=(4, 4))
#             plt.bar(labels, column, edgecolor='black')
#             plt.xlabel(category)
#             plt.ylabel("Output")
#             plt.title("Bar Chart of Numeric Data by Labels")
#             plt.show()

# %% [markdown]
# ### Dataset 1 (Ionosphere):

# %%
filename = "data/ionosphere.data"

ionosphere_data = readFile(filename)[0]

categories = [""]
classifications = [""]

print("\nData:")
print(ionosphere_data)

# ionAnalysis = dataAnalysis(ionosphere_data,categories,classifications)
# Out:
# Data:
# [['1' '0' '0.99539' ... '0.18641' '-0.45300' 'g']
#  ['1' '0' '1' ... '-0.13738' '-0.02447' 'b']
#  ['1' '0' '1' ... '0.56045' '-0.38238' 'g']
#  ...
#  ['1' '0' '0.94701' ... '0.92697' '-0.00577' 'g']
#  ['1' '0' '0.90608' ... '0.87403' '-0.16243' 'g']
#  ['1' '0' '0.84710' ... '0.85764' '-0.06151' 'g']]

# %% [markdown]
# ### Dataset 2 (Adult Data Set):

# %%
filename = "data/adult.data"
adult_data = readFile(filename)[0]

# print(adult_data)

categories = ['age', 'workclass', 'fnlwgt', 'education','education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', "native-country"]
classifications = [">50K", "<=50K"]

# age: continuous.
# workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# fnlwgt: continuous.
# education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# education-num: continuous.
# marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# sex: Female, Male.
# capital-gain: continuous.
# capital-loss: continuous.
# hours-per-week: continuous.
# native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

workclass = ["Private", "Self-emp-not-inc", "Self-emp-inc", "Federal-gov", "Local-gov", "State-gov", "Without-pay", "Never-worked"]
education = ["Bachelors", "Some-college", "11th", "HS-grad", "Prof-school", "Assoc-acdm", "Assoc-voc", "9th", "7th-8th", "12th", "Masters", '1st-4th', "10th", 'Doctorate', '5th-6th', "Preschool"]
marital_status = ["Married-civ-spouse", "Divorced", "Never-married", "Separated", "Widowed", "Married-spouse-absent", "Married-AF-spouse"]
occupation = ["Tech-support", "Craft-repair", "Other-service", 'Sales', "Exec-managerial", "Prof-specialty", "Handlers-cleaners", "Machine-op-inspct", "Adm-clerical", "Farming-fishing", "Transport-moving", "Priv-house-serv", "Protective-serv", "Armed-Forces"]
relationship = ["Wife", "Own-child", "Husband", "Not-in-family", "Other-relative", "Unmarried"]
race = ['White', 'Asian-Pac-Islander', "Amer-Indian-Eskimo", 'Other', 'Black']
sex = ['Female', 'Male']
native_country = ['United-States', 'Cambodia', 'England', 'Puerto-Rico', 'Canada', 'Germany', 'Outlying-US(Guam-USVI-etc)', 'India', 'Japan', 'Greece', 'South', 'China', 'Cuba', 'Iran', 'Honduras', 'Philippines', 'Italy', 'Poland', 'Jamaica', 'Vietnam', 'Mexico', 'Portugal', 'Ireland', 'France', 'Dominican-Republic', 'Laos', 'Ecuador', 'Taiwan', 'Haiti', 'Columbia', 'Hungary', 'Guatemala', 'Nicaragua', 'Scotland', 'Thailand', 'Yugoslavia', 'El-Salvador', 'Trinadad&Tobago','Peru', 'Hong', 'Holand-Netherlands']

columns = [workclass, education, marital_status,occupation,relationship,race,sex,native_country]

for c in columns:
    for i in range(len(c)):
        word = c[i]
        adult_data[adult_data==" " + word] = str(i)

print(adult_data)

cleaned_data = np.char.strip(adult_data)
print(cleaned_data)

        

adultAnalysis = dataAnalysis(cleaned_data,categories,classifications)
adultAnalysis.printLabelStats()
adultAnalysis.printCategoryStats()

#what are the distributions of some of the numerical features?
# Out:
# [['39' '5' ' 77516' ... ' 40' '0' ' <=50K']
#  ['50' '1' ' 83311' ... ' 13' '0' ' <=50K']
#  ['38' '0' ' 215646' ... ' 40' '0' ' <=50K']
#  ...
#  ['58' '0' ' 151910' ... ' 40' '0' ' <=50K']
#  ['22' '0' ' 201490' ... ' 20' '0' ' <=50K']
#  ['52' '2' ' 287927' ... ' 40' '0' ' >50K']]
# [['39' '5' '77516' ... '40' '0' '<=50K']
#  ['50' '1' '83311' ... '13' '0' '<=50K']
#  ['38' '0' '215646' ... '40' '0' '<=50K']
#  ...
#  ['58' '0' '151910' ... '40' '0' '<=50K']
#  ['22' '0' '201490' ... '20' '0' '<=50K']
#  ['52' '2' '287927' ... '40' '0' '>50K']]
# =====================================================
# Classification Analysis:
# =====================================================
# Total: 30162 (%100)
# Value: >50K, Count: 7508, Percentage: %24.89
# Value: <=50K, Count: 22654, Percentage: %75.11
# =====================================================
# Attribute Analysis:
# =====================================================
# -----------------------------------------------------
# AGE Analysis:
# -----------------------------------------------------
# Value: 17.0, Count: 328, Percentage: %1.09
# Value: 18.0, Count: 447, Percentage: %1.48
# Value: 19.0, Count: 594, Percentage: %1.97
# Value: 20.0, Count: 629, Percentage: %2.09
# Value: 21.0, Count: 621, Percentage: %2.06
# Value: 22.0, Count: 674, Percentage: %2.23
# Value: 23.0, Count: 824, Percentage: %2.73
# Value: 24.0, Count: 752, Percentage: %2.49
# Value: 25.0, Count: 799, Percentage: %2.65
# Value: 26.0, Count: 745, Percentage: %2.47
# Value: 27.0, Count: 789, Percentage: %2.62
# Value: 28.0, Count: 808, Percentage: %2.68
# Value: 29.0, Count: 774, Percentage: %2.57
# Value: 30.0, Count: 813, Percentage: %2.7
# Value: 31.0, Count: 851, Percentage: %2.82
# Value: 32.0, Count: 789, Percentage: %2.62
# Value: 33.0, Count: 837, Percentage: %2.78
# Value: 34.0, Count: 836, Percentage: %2.77
# Value: 35.0, Count: 828, Percentage: %2.75
# Value: 36.0, Count: 852, Percentage: %2.82
# Value: 37.0, Count: 828, Percentage: %2.75
# Value: 38.0, Count: 791, Percentage: %2.62
# Value: 39.0, Count: 786, Percentage: %2.61
# Value: 40.0, Count: 765, Percentage: %2.54
# Value: 41.0, Count: 769, Percentage: %2.55
# Value: 42.0, Count: 741, Percentage: %2.46
# Value: 43.0, Count: 743, Percentage: %2.46
# Value: 44.0, Count: 704, Percentage: %2.33
# Value: 45.0, Count: 706, Percentage: %2.34
# Value: 46.0, Count: 711, Percentage: %2.36
# Value: 47.0, Count: 683, Percentage: %2.26
# Value: 48.0, Count: 523, Percentage: %1.73
# Value: 49.0, Count: 555, Percentage: %1.84
# Value: 50.0, Count: 575, Percentage: %1.91
# Value: 51.0, Count: 571, Percentage: %1.89
# Value: 52.0, Count: 455, Percentage: %1.51
# Value: 53.0, Count: 448, Percentage: %1.49
# Value: 54.0, Count: 394, Percentage: %1.31
# Value: 55.0, Count: 386, Percentage: %1.28
# Value: 56.0, Count: 343, Percentage: %1.14
# Value: 57.0, Count: 337, Percentage: %1.12
# Value: 58.0, Count: 344, Percentage: %1.14
# Value: 59.0, Count: 332, Percentage: %1.1
# Value: 60.0, Count: 276, Percentage: %0.92
# Value: 61.0, Count: 259, Percentage: %0.86
# Value: 62.0, Count: 213, Percentage: %0.71
# Value: 63.0, Count: 186, Percentage: %0.62
# Value: 64.0, Count: 173, Percentage: %0.57
# Value: 65.0, Count: 136, Percentage: %0.45
# Value: 66.0, Count: 110, Percentage: %0.36
# Value: 67.0, Count: 111, Percentage: %0.37
# Value: 68.0, Count: 90, Percentage: %0.3
# Value: 69.0, Count: 80, Percentage: %0.27
# Value: 70.0, Count: 64, Percentage: %0.21
# Value: 71.0, Count: 54, Percentage: %0.18
# Value: 72.0, Count: 40, Percentage: %0.13
# Value: 73.0, Count: 49, Percentage: %0.16
# Value: 74.0, Count: 38, Percentage: %0.13
# Value: 75.0, Count: 34, Percentage: %0.11
# Value: 76.0, Count: 29, Percentage: %0.1
# Value: 77.0, Count: 20, Percentage: %0.07
# Value: 78.0, Count: 14, Percentage: %0.05
# Value: 79.0, Count: 15, Percentage: %0.05
# Value: 80.0, Count: 16, Percentage: %0.05
# Value: 81.0, Count: 13, Percentage: %0.04
# Value: 82.0, Count: 7, Percentage: %0.02
# Value: 83.0, Count: 5, Percentage: %0.02
# Value: 84.0, Count: 8, Percentage: %0.03
# Value: 85.0, Count: 3, Percentage: %0.01
# Value: 86.0, Count: 1, Percentage: %0.0
# Value: 88.0, Count: 3, Percentage: %0.01
# Value: 90.0, Count: 35, Percentage: %0.12
#
# Mean: 38.437901995888865
# Median: 37.0
# Mode: 36.0
# Standard Deviation: 13.134447039742295
# -----------------------------------------------------
# WORKCLASS Analysis:
# -----------------------------------------------------
# Value: 0.0, Count: 22286, Percentage: %73.89
# Value: 1.0, Count: 2499, Percentage: %8.29
# Value: 2.0, Count: 1074, Percentage: %3.56
# Value: 3.0, Count: 943, Percentage: %3.13
# Value: 4.0, Count: 2067, Percentage: %6.85
# Value: 5.0, Count: 1279, Percentage: %4.24
# Value: 6.0, Count: 14, Percentage: %0.05
#
# Mean: 0.7367880114050792
# Median: 0.0
# Mode: 0.0
# Standard Deviation: 1.4618840471328831
# -----------------------------------------------------
# FNLWGT Analysis:
# -----------------------------------------------------
# Value: 13769.0, Count: 1, Percentage: %0.0
# Value: 14878.0, Count: 1, Percentage: %0.0
# Value: 18827.0, Count: 1, Percentage: %0.0
# Value: 19214.0, Count: 1, Percentage: %0.0
# Value: 19302.0, Count: 5, Percentage: %0.02
# Value: 19395.0, Count: 2, Percentage: %0.01
# Value: 19410.0, Count: 1, Percentage: %0.0
# Value: 19491.0, Count: 1, Percentage: %0.0
# Value: 19520.0, Count: 1, Percentage: %0.0
# Value: 19700.0, Count: 1, Percentage: %0.0
# Value: 19752.0, Count: 1, Percentage: %0.0
# Value: 19847.0, Count: 2, Percentage: %0.01
# Value: 19899.0, Count: 1, Percentage: %0.0
# Value: 19914.0, Count: 4, Percentage: %0.01
# Value: 20057.0, Count: 2, Percentage: %0.01
# Value: 20098.0, Count: 1, Percentage: %0.0
# Value: 20101.0, Count: 1, Percentage: %0.0
# Value: 20109.0, Count: 1, Percentage: %0.0
# Value: 20179.0, Count: 1, Percentage: %0.0
# Value: 20296.0, Count: 1, Percentage: %0.0
# Value: 20308.0, Count: 1, Percentage: %0.0
# Value: 20323.0, Count: 1, Percentage: %0.0
# Value: 20333.0, Count: 1, Percentage: %0.0
# Value: 20438.0, Count: 1, Percentage: %0.0
# Value: 20469.0, Count: 1, Percentage: %0.0
# Value: 20507.0, Count: 1, Percentage: %0.0
# Value: 20511.0, Count: 1, Percentage: %0.0
# Value: 20534.0, Count: 3, Percentage: %0.01
# Value: 20676.0, Count: 1, Percentage: %0.0
# Value: 20728.0, Count: 1, Percentage: %0.0
# Value: 20795.0, Count: 4, Percentage: %0.01
# Value: 20809.0, Count: 1, Percentage: %0.0
# Value: 20953.0, Count: 1, Percentage: %0.0
# Value: 20956.0, Count: 2, Percentage: %0.01
# Value: 21095.0, Count: 1, Percentage: %0.0
# Value: 21101.0, Count: 1, Percentage: %0.0
# Value: 21154.0, Count: 1, Percentage: %0.0
# Value: 21174.0, Count: 1, Percentage: %0.0
# Value: 21306.0, Count: 1, Percentage: %0.0
# Value: 21472.0, Count: 1, Percentage: %0.0
# Value: 21626.0, Count: 2, Percentage: %0.01
# Value: 21698.0, Count: 3, Percentage: %0.01
# Value: 21792.0, Count: 1, Percentage: %0.0
# Value: 21856.0, Count: 1, Percentage: %0.0
# Value: 21876.0, Count: 1, Percentage: %0.0
# Value: 21906.0, Count: 1, Percentage: %0.0
# Value: 22042.0, Count: 1, Percentage: %0.0
# Value: 22055.0, Count: 1, Percentage: %0.0
# Value: 22154.0, Count: 1, Percentage: %0.0
# Value: 22155.0, Count: 1, Percentage: %0.0
# Value: 22186.0, Count: 1, Percentage: %0.0
# Value: 22201.0, Count: 4, Percentage: %0.01
# Value: 22211.0, Count: 2, Percentage: %0.01
# Value: 22245.0, Count: 5, Percentage: %0.02
# Value: 22313.0, Count: 1, Percentage: %0.0
# Value: 22328.0, Count: 1, Percentage: %0.0
# Value: 22418.0, Count: 2, Percentage: %0.01
# Value: 22422.0, Count: 2, Percentage: %0.01
# Value: 22428.0, Count: 1, Percentage: %0.0
# Value: 22463.0, Count: 2, Percentage: %0.01
# Value: 22494.0, Count: 3, Percentage: %0.01
# Value: 22546.0, Count: 1, Percentage: %0.0
# Value: 22641.0, Count: 3, Percentage: %0.01
# Value: 22743.0, Count: 1, Percentage: %0.0
# Value: 22831.0, Count: 1, Percentage: %0.0
# Value: 22900.0, Count: 1, Percentage: %0.0
# Value: 22907.0, Count: 1, Percentage: %0.0
# Value: 22966.0, Count: 3, Percentage: %0.01
# Value: 22978.0, Count: 1, Percentage: %0.0
# Value: 23037.0, Count: 2, Percentage: %0.01
# Value: 23074.0, Count: 1, Percentage: %0.0
# Value: 23157.0, Count: 1, Percentage: %0.0
# Value: 23324.0, Count: 1, Percentage: %0.0
# Value: 23438.0, Count: 3, Percentage: %0.01
# Value: 23494.0, Count: 1, Percentage: %0.0
# Value: 23510.0, Count: 1, Percentage: %0.0
# Value: 23545.0, Count: 1, Percentage: %0.0
# Value: 23580.0, Count: 1, Percentage: %0.0
# Value: 23621.0, Count: 1, Percentage: %0.0
# Value: 23646.0, Count: 1, Percentage: %0.0
# Value: 23686.0, Count: 1, Percentage: %0.0
# Value: 23698.0, Count: 1, Percentage: %0.0
# Value: 23740.0, Count: 1, Percentage: %0.0
# Value: 23776.0, Count: 1, Percentage: %0.0
# Value: 23778.0, Count: 2, Percentage: %0.01
# Value: 23780.0, Count: 2, Percentage: %0.01
# Value: 23789.0, Count: 2, Percentage: %0.01
# Value: 23813.0, Count: 1, Percentage: %0.0
# Value: 23871.0, Count: 2, Percentage: %0.01
# Value: 23892.0, Count: 2, Percentage: %0.01
# Value: 23940.0, Count: 1, Percentage: %0.0
# Value: 24008.0, Count: 3, Percentage: %0.01
# Value: 24013.0, Count: 1, Percentage: %0.0
# Value: 24046.0, Count: 1, Percentage: %0.0
# Value: 24050.0, Count: 1, Percentage: %0.0
# Value: 24090.0, Count: 1, Percentage: %0.0
# Value: 24106.0, Count: 4, Percentage: %0.01
# Value: 24108.0, Count: 1, Percentage: %0.0
# Value: 24127.0, Count: 1, Percentage: %0.0
# Value: 24139.0, Count: 1, Percentage: %0.0
# Value: 24153.0, Count: 2, Percentage: %0.01
# Value: 24185.0, Count: 2, Percentage: %0.01
# Value: 24243.0, Count: 1, Percentage: %0.0
# Value: 24264.0, Count: 1, Percentage: %0.0
# Value: 24266.0, Count: 1, Percentage: %0.0
# Value: 24292.0, Count: 1, Percentage: %0.0
# Value: 24342.0, Count: 2, Percentage: %0.01
# Value: 24344.0, Count: 1, Percentage: %0.0
# Value: 24364.0, Count: 1, Percentage: %0.0
# Value: 24384.0, Count: 2, Percentage: %0.01
# Value: 24395.0, Count: 2, Percentage: %0.01
# Value: 24473.0, Count: 1, Percentage: %0.0
# Value: 24504.0, Count: 2, Percentage: %0.01
# Value: 24515.0, Count: 1, Percentage: %0.0
# Value: 24529.0, Count: 1, Percentage: %0.0
# Value: 24562.0, Count: 1, Percentage: %0.0
# Value: 24647.0, Count: 1, Percentage: %0.0
# Value: 24694.0, Count: 1, Percentage: %0.0
# Value: 24712.0, Count: 1, Percentage: %0.0
# Value: 24721.0, Count: 1, Percentage: %0.0
# Value: 24723.0, Count: 1, Percentage: %0.0
# Value: 24728.0, Count: 1, Percentage: %0.0
# Value: 24763.0, Count: 4, Percentage: %0.01
# Value: 24790.0, Count: 2, Percentage: %0.01
# Value: 24824.0, Count: 1, Percentage: %0.0
# Value: 24872.0, Count: 1, Percentage: %0.0
# Value: 24896.0, Count: 2, Percentage: %0.01
# Value: 24961.0, Count: 2, Percentage: %0.01
# Value: 24967.0, Count: 1, Percentage: %0.0
# Value: 24982.0, Count: 2, Percentage: %0.01
# Value: 25005.0, Count: 2, Percentage: %0.01
# Value: 25031.0, Count: 1, Percentage: %0.0
# Value: 25045.0, Count: 1, Percentage: %0.0
# Value: 25051.0, Count: 1, Percentage: %0.0
# Value: 25124.0, Count: 1, Percentage: %0.0
# Value: 25141.0, Count: 1, Percentage: %0.0
# Value: 25216.0, Count: 1, Percentage: %0.0
# Value: 25240.0, Count: 1, Percentage: %0.0
# Value: 25249.0, Count: 1, Percentage: %0.0
# Value: 25265.0, Count: 2, Percentage: %0.01
# Value: 25319.0, Count: 1, Percentage: %0.0
# Value: 25386.0, Count: 1, Percentage: %0.0
# Value: 25429.0, Count: 3, Percentage: %0.01
# Value: 25468.0, Count: 1, Percentage: %0.0
# Value: 25497.0, Count: 1, Percentage: %0.0
# Value: 25505.0, Count: 1, Percentage: %0.0
# Value: 25610.0, Count: 1, Percentage: %0.0
# Value: 25631.0, Count: 1, Percentage: %0.0
# Value: 25649.0, Count: 1, Percentage: %0.0
# Value: 25684.0, Count: 1, Percentage: %0.0
# Value: 25690.0, Count: 1, Percentage: %0.0
# Value: 25803.0, Count: 2, Percentage: %0.01
# Value: 25825.0, Count: 1, Percentage: %0.0
# Value: 25826.0, Count: 1, Percentage: %0.0
# Value: 25828.0, Count: 1, Percentage: %0.0
# Value: 25837.0, Count: 2, Percentage: %0.01
# Value: 25864.0, Count: 2, Percentage: %0.01
# Value: 25932.0, Count: 1, Percentage: %0.0
# Value: 25955.0, Count: 4, Percentage: %0.01
# Value: 26009.0, Count: 1, Percentage: %0.0
# Value: 26109.0, Count: 1, Percentage: %0.0
# Value: 26145.0, Count: 2, Percentage: %0.01
# Value: 26248.0, Count: 2, Percentage: %0.01
# Value: 26254.0, Count: 1, Percentage: %0.0
# Value: 26290.0, Count: 1, Percentage: %0.0
# Value: 26358.0, Count: 1, Percentage: %0.0
# Value: 26401.0, Count: 1, Percentage: %0.0
# Value: 26410.0, Count: 1, Percentage: %0.0
# Value: 26451.0, Count: 1, Percentage: %0.0
# Value: 26490.0, Count: 1, Percentage: %0.0
# Value: 26502.0, Count: 2, Percentage: %0.01
# Value: 26522.0, Count: 1, Percentage: %0.0
# Value: 26543.0, Count: 2, Percentage: %0.01
# Value: 26598.0, Count: 2, Percentage: %0.01
# Value: 26669.0, Count: 2, Percentage: %0.01
# Value: 26672.0, Count: 1, Percentage: %0.0
# Value: 26683.0, Count: 1, Percentage: %0.0
# Value: 26698.0, Count: 2, Percentage: %0.01
# Value: 26716.0, Count: 2, Percentage: %0.01
# Value: 26721.0, Count: 1, Percentage: %0.0
# Value: 26756.0, Count: 1, Percentage: %0.0
# Value: 26781.0, Count: 4, Percentage: %0.01
# Value: 26803.0, Count: 1, Percentage: %0.0
# Value: 26832.0, Count: 1, Percentage: %0.0
# Value: 26842.0, Count: 2, Percentage: %0.01
# Value: 26857.0, Count: 1, Percentage: %0.0
# Value: 26865.0, Count: 1, Percentage: %0.0
# Value: 26880.0, Count: 1, Percentage: %0.0
# Value: 26892.0, Count: 3, Percentage: %0.01
# Value: 26898.0, Count: 1, Percentage: %0.0
# Value: 26904.0, Count: 1, Percentage: %0.0
# Value: 26911.0, Count: 1, Percentage: %0.0
# Value: 26915.0, Count: 1, Percentage: %0.0
# Value: 26929.0, Count: 1, Percentage: %0.0
# Value: 26950.0, Count: 1, Percentage: %0.0
# Value: 26966.0, Count: 1, Percentage: %0.0
# Value: 26973.0, Count: 1, Percentage: %0.0
# Value: 26987.0, Count: 2, Percentage: %0.01
# Value: 26994.0, Count: 1, Percentage: %0.0
# Value: 26999.0, Count: 1, Percentage: %0.0
# Value: 27012.0, Count: 1, Percentage: %0.0
# Value: 27032.0, Count: 1, Percentage: %0.0
# Value: 27037.0, Count: 1, Percentage: %0.0
# Value: 27044.0, Count: 1, Percentage: %0.0
# Value: 27049.0, Count: 4, Percentage: %0.01
# Value: 27051.0, Count: 2, Percentage: %0.01
# Value: 27053.0, Count: 1, Percentage: %0.0
# Value: 27067.0, Count: 1, Percentage: %0.0
# Value: 27142.0, Count: 1, Percentage: %0.0
# Value: 27153.0, Count: 2, Percentage: %0.01
# Value: 27162.0, Count: 1, Percentage: %0.0
# Value: 27166.0, Count: 1, Percentage: %0.0
# Value: 27187.0, Count: 1, Percentage: %0.0
# Value: 27207.0, Count: 2, Percentage: %0.01
# Value: 27242.0, Count: 4, Percentage: %0.01
# Value: 27243.0, Count: 1, Percentage: %0.0
# Value: 27305.0, Count: 2, Percentage: %0.01
# Value: 27332.0, Count: 1, Percentage: %0.0
# Value: 27337.0, Count: 1, Percentage: %0.0
# Value: 27380.0, Count: 1, Percentage: %0.0
# Value: 27382.0, Count: 1, Percentage: %0.0
# Value: 27385.0, Count: 2, Percentage: %0.01
# Value: 27408.0, Count: 4, Percentage: %0.01
# Value: 27409.0, Count: 1, Percentage: %0.0
# Value: 27411.0, Count: 1, Percentage: %0.0
# Value: 27415.0, Count: 1, Percentage: %0.0
# Value: 27432.0, Count: 1, Percentage: %0.0
# Value: 27433.0, Count: 2, Percentage: %0.01
# Value: 27444.0, Count: 3, Percentage: %0.01
# Value: 27466.0, Count: 1, Percentage: %0.0
# Value: 27484.0, Count: 1, Percentage: %0.0
# Value: 27494.0, Count: 2, Percentage: %0.01
# Value: 27539.0, Count: 1, Percentage: %0.0
# Value: 27620.0, Count: 1, Percentage: %0.0
# Value: 27624.0, Count: 1, Percentage: %0.0
# Value: 27653.0, Count: 1, Percentage: %0.0
# Value: 27661.0, Count: 2, Percentage: %0.01
# Value: 27669.0, Count: 1, Percentage: %0.0
# Value: 27678.0, Count: 1, Percentage: %0.0
# Value: 27763.0, Count: 1, Percentage: %0.0
# Value: 27766.0, Count: 1, Percentage: %0.0
# Value: 27776.0, Count: 3, Percentage: %0.01
# Value: 27780.0, Count: 1, Percentage: %0.0
# Value: 27802.0, Count: 2, Percentage: %0.01
# Value: 27815.0, Count: 1, Percentage: %0.0
# Value: 27821.0, Count: 2, Percentage: %0.01
# Value: 27834.0, Count: 1, Percentage: %0.0
# Value: 27856.0, Count: 2, Percentage: %0.01
# Value: 27882.0, Count: 1, Percentage: %0.0
# Value: 27886.0, Count: 2, Percentage: %0.01
# Value: 27920.0, Count: 1, Percentage: %0.0
# Value: 27939.0, Count: 1, Percentage: %0.0
# Value: 27956.0, Count: 1, Percentage: %0.0
# Value: 27959.0, Count: 1, Percentage: %0.0
# Value: 27997.0, Count: 2, Percentage: %0.01
# Value: 28008.0, Count: 1, Percentage: %0.0
# Value: 28031.0, Count: 1, Percentage: %0.0
# Value: 28035.0, Count: 3, Percentage: %0.01
# Value: 28053.0, Count: 1, Percentage: %0.0
# Value: 28061.0, Count: 1, Percentage: %0.0
# Value: 28119.0, Count: 2, Percentage: %0.01
# Value: 28145.0, Count: 1, Percentage: %0.0
# Value: 28151.0, Count: 1, Percentage: %0.0
# Value: 28160.0, Count: 1, Percentage: %0.0
# Value: 28186.0, Count: 1, Percentage: %0.0
# Value: 28225.0, Count: 1, Percentage: %0.0
# Value: 28281.0, Count: 1, Percentage: %0.0
# Value: 28291.0, Count: 2, Percentage: %0.01
# Value: 28334.0, Count: 3, Percentage: %0.01
# Value: 28366.0, Count: 1, Percentage: %0.0
# Value: 28367.0, Count: 2, Percentage: %0.01
# Value: 28375.0, Count: 1, Percentage: %0.0
# Value: 28419.0, Count: 2, Percentage: %0.01
# Value: 28443.0, Count: 1, Percentage: %0.0
# Value: 28451.0, Count: 1, Percentage: %0.0
# Value: 28473.0, Count: 1, Percentage: %0.0
# Value: 28497.0, Count: 2, Percentage: %0.01
# Value: 28518.0, Count: 1, Percentage: %0.0
# Value: 28520.0, Count: 1, Percentage: %0.0
# Value: 28568.0, Count: 1, Percentage: %0.0
# Value: 28572.0, Count: 4, Percentage: %0.01
# Value: 28612.0, Count: 1, Percentage: %0.0
# Value: 28648.0, Count: 1, Percentage: %0.0
# Value: 28683.0, Count: 1, Percentage: %0.0
# Value: 28729.0, Count: 1, Percentage: %0.0
# Value: 28735.0, Count: 1, Percentage: %0.0
# Value: 28738.0, Count: 1, Percentage: %0.0
# Value: 28765.0, Count: 1, Percentage: %0.0
# Value: 28790.0, Count: 1, Percentage: %0.0
# Value: 28791.0, Count: 2, Percentage: %0.01
# Value: 28848.0, Count: 1, Percentage: %0.0
# Value: 28856.0, Count: 2, Percentage: %0.01
# Value: 28887.0, Count: 2, Percentage: %0.01
# Value: 28952.0, Count: 1, Percentage: %0.0
# Value: 28984.0, Count: 1, Percentage: %0.0
# Value: 28996.0, Count: 2, Percentage: %0.01
# Value: 29020.0, Count: 1, Percentage: %0.0
# Value: 29036.0, Count: 1, Percentage: %0.0
# Value: 29054.0, Count: 3, Percentage: %0.01
# Value: 29059.0, Count: 1, Percentage: %0.0
# Value: 29075.0, Count: 1, Percentage: %0.0
# Value: 29083.0, Count: 1, Percentage: %0.0
# Value: 29115.0, Count: 1, Percentage: %0.0
# Value: 29145.0, Count: 3, Percentage: %0.01
# Value: 29152.0, Count: 1, Percentage: %0.0
# Value: 29174.0, Count: 1, Percentage: %0.0
# Value: 29231.0, Count: 1, Percentage: %0.0
# Value: 29235.0, Count: 3, Percentage: %0.01
# Value: 29250.0, Count: 1, Percentage: %0.0
# Value: 29254.0, Count: 2, Percentage: %0.01
# Value: 29261.0, Count: 3, Percentage: %0.01
# Value: 29276.0, Count: 1, Percentage: %0.0
# Value: 29306.0, Count: 1, Percentage: %0.0
# Value: 29312.0, Count: 2, Percentage: %0.01
# Value: 29320.0, Count: 2, Percentage: %0.01
# Value: 29324.0, Count: 1, Percentage: %0.0
# Value: 29361.0, Count: 1, Percentage: %0.0
# Value: 29375.0, Count: 1, Percentage: %0.0
# Value: 29393.0, Count: 1, Percentage: %0.0
# Value: 29430.0, Count: 1, Percentage: %0.0
# Value: 29431.0, Count: 1, Percentage: %0.0
# Value: 29437.0, Count: 1, Percentage: %0.0
# Value: 29444.0, Count: 2, Percentage: %0.01
# Value: 29510.0, Count: 1, Percentage: %0.0
# Value: 29522.0, Count: 1, Percentage: %0.0
# Value: 29523.0, Count: 1, Percentage: %0.0
# Value: 29526.0, Count: 1, Percentage: %0.0
# Value: 29557.0, Count: 1, Percentage: %0.0
# Value: 29571.0, Count: 1, Percentage: %0.0
# Value: 29580.0, Count: 1, Percentage: %0.0
# Value: 29582.0, Count: 1, Percentage: %0.0
# Value: 29591.0, Count: 3, Percentage: %0.01
# Value: 29599.0, Count: 2, Percentage: %0.01
# Value: 29616.0, Count: 1, Percentage: %0.0
# Value: 29617.0, Count: 1, Percentage: %0.0
# Value: 29623.0, Count: 1, Percentage: %0.0
# Value: 29658.0, Count: 2, Percentage: %0.01
# Value: 29662.0, Count: 2, Percentage: %0.01
# Value: 29675.0, Count: 1, Percentage: %0.0
# Value: 29696.0, Count: 2, Percentage: %0.01
# Value: 29702.0, Count: 4, Percentage: %0.01
# Value: 29732.0, Count: 2, Percentage: %0.01
# Value: 29762.0, Count: 5, Percentage: %0.02
# Value: 29778.0, Count: 1, Percentage: %0.0
# Value: 29798.0, Count: 1, Percentage: %0.0
# Value: 29807.0, Count: 1, Percentage: %0.0
# Value: 29810.0, Count: 4, Percentage: %0.01
# Value: 29814.0, Count: 5, Percentage: %0.02
# Value: 29819.0, Count: 1, Percentage: %0.0
# Value: 29828.0, Count: 1, Percentage: %0.0
# Value: 29841.0, Count: 1, Percentage: %0.0
# Value: 29859.0, Count: 1, Percentage: %0.0
# Value: 29865.0, Count: 1, Percentage: %0.0
# Value: 29874.0, Count: 3, Percentage: %0.01
# Value: 29887.0, Count: 2, Percentage: %0.01
# Value: 29904.0, Count: 1, Percentage: %0.0
# Value: 29909.0, Count: 1, Percentage: %0.0
# Value: 29927.0, Count: 1, Percentage: %0.0
# Value: 29928.0, Count: 1, Percentage: %0.0
# Value: 29933.0, Count: 2, Percentage: %0.01
# Value: 29957.0, Count: 1, Percentage: %0.0
# Value: 29962.0, Count: 2, Percentage: %0.01
# Value: 29974.0, Count: 1, Percentage: %0.0
# Value: 29980.0, Count: 1, Percentage: %0.0
# Value: 29984.0, Count: 1, Percentage: %0.0
# Value: 30008.0, Count: 3, Percentage: %0.01
# Value: 30030.0, Count: 1, Percentage: %0.0
# Value: 30035.0, Count: 1, Percentage: %0.0
# Value: 30039.0, Count: 1, Percentage: %0.0
# Value: 30063.0, Count: 1, Percentage: %0.0
# Value: 30069.0, Count: 1, Percentage: %0.0
# Value: 30070.0, Count: 1, Percentage: %0.0
# Value: 30073.0, Count: 1, Percentage: %0.0
# Value: 30111.0, Count: 1, Percentage: %0.0
# Value: 30118.0, Count: 1, Percentage: %0.0
# Value: 30126.0, Count: 1, Percentage: %0.0
# Value: 30219.0, Count: 2, Percentage: %0.01
# Value: 30226.0, Count: 1, Percentage: %0.0
# Value: 30244.0, Count: 2, Percentage: %0.01
# Value: 30267.0, Count: 2, Percentage: %0.01
# Value: 30269.0, Count: 1, Percentage: %0.0
# Value: 30270.0, Count: 1, Percentage: %0.0
# Value: 30271.0, Count: 1, Percentage: %0.0
# Value: 30289.0, Count: 2, Percentage: %0.01
# Value: 30290.0, Count: 3, Percentage: %0.01
# Value: 30381.0, Count: 1, Percentage: %0.0
# Value: 30424.0, Count: 1, Percentage: %0.0
# Value: 30433.0, Count: 1, Percentage: %0.0
# Value: 30447.0, Count: 2, Percentage: %0.01
# Value: 30457.0, Count: 2, Percentage: %0.01
# Value: 30497.0, Count: 2, Percentage: %0.01
# Value: 30509.0, Count: 2, Percentage: %0.01
# Value: 30529.0, Count: 4, Percentage: %0.01
# Value: 30559.0, Count: 1, Percentage: %0.0
# Value: 30565.0, Count: 1, Percentage: %0.0
# Value: 30575.0, Count: 2, Percentage: %0.01
# Value: 30599.0, Count: 1, Percentage: %0.0
# Value: 30602.0, Count: 1, Percentage: %0.0
# Value: 30619.0, Count: 1, Percentage: %0.0
# Value: 30653.0, Count: 1, Percentage: %0.0
# Value: 30656.0, Count: 1, Percentage: %0.0
# Value: 30664.0, Count: 1, Percentage: %0.0
# Value: 30673.0, Count: 4, Percentage: %0.01
# Value: 30682.0, Count: 2, Percentage: %0.01
# Value: 30687.0, Count: 1, Percentage: %0.0
# Value: 30713.0, Count: 1, Percentage: %0.0
# Value: 30731.0, Count: 3, Percentage: %0.01
# Value: 30751.0, Count: 1, Percentage: %0.0
# Value: 30759.0, Count: 3, Percentage: %0.01
# Value: 30771.0, Count: 1, Percentage: %0.0
# Value: 30793.0, Count: 1, Percentage: %0.0
# Value: 30796.0, Count: 1, Percentage: %0.0
# Value: 30800.0, Count: 1, Percentage: %0.0
# Value: 30813.0, Count: 1, Percentage: %0.0
# Value: 30824.0, Count: 2, Percentage: %0.01
# Value: 30840.0, Count: 2, Percentage: %0.01
# Value: 30908.0, Count: 1, Percentage: %0.0
# Value: 30912.0, Count: 2, Percentage: %0.01
# Value: 30916.0, Count: 5, Percentage: %0.02
# Value: 30973.0, Count: 1, Percentage: %0.0
# Value: 31007.0, Count: 1, Percentage: %0.0
# Value: 31014.0, Count: 1, Percentage: %0.0
# Value: 31023.0, Count: 4, Percentage: %0.01
# Value: 31033.0, Count: 1, Percentage: %0.0
# Value: 31053.0, Count: 1, Percentage: %0.0
# Value: 31069.0, Count: 1, Percentage: %0.0
# Value: 31095.0, Count: 2, Percentage: %0.01
# Value: 31137.0, Count: 2, Percentage: %0.01
# Value: 31141.0, Count: 2, Percentage: %0.01
# Value: 31143.0, Count: 2, Percentage: %0.01
# Value: 31161.0, Count: 1, Percentage: %0.0
# Value: 31166.0, Count: 1, Percentage: %0.0
# Value: 31195.0, Count: 1, Percentage: %0.0
# Value: 31221.0, Count: 1, Percentage: %0.0
# Value: 31251.0, Count: 2, Percentage: %0.01
# Value: 31264.0, Count: 2, Percentage: %0.01
# Value: 31267.0, Count: 4, Percentage: %0.01
# Value: 31269.0, Count: 1, Percentage: %0.0
# Value: 31290.0, Count: 1, Percentage: %0.0
# Value: 31339.0, Count: 4, Percentage: %0.01
# Value: 31350.0, Count: 2, Percentage: %0.01
# Value: 31352.0, Count: 1, Percentage: %0.0
# Value: 31359.0, Count: 1, Percentage: %0.0
# Value: 31360.0, Count: 1, Percentage: %0.0
# Value: 31365.0, Count: 1, Percentage: %0.0
# Value: 31368.0, Count: 1, Percentage: %0.0
# Value: 31387.0, Count: 2, Percentage: %0.01
# Value: 31389.0, Count: 1, Percentage: %0.0
# Value: 31391.0, Count: 1, Percentage: %0.0
# Value: 31428.0, Count: 1, Percentage: %0.0
# Value: 31432.0, Count: 1, Percentage: %0.0
# Value: 31438.0, Count: 1, Percentage: %0.0
# Value: 31449.0, Count: 1, Percentage: %0.0
# Value: 31460.0, Count: 2, Percentage: %0.01
# Value: 31478.0, Count: 1, Percentage: %0.0
# Value: 31481.0, Count: 1, Percentage: %0.0
# Value: 31493.0, Count: 1, Percentage: %0.0
# Value: 31510.0, Count: 1, Percentage: %0.0
# Value: 31532.0, Count: 1, Percentage: %0.0
# Value: 31533.0, Count: 2, Percentage: %0.01
# Value: 31573.0, Count: 1, Percentage: %0.0
# Value: 31577.0, Count: 2, Percentage: %0.01
# Value: 31588.0, Count: 1, Percentage: %0.0
# Value: 31600.0, Count: 1, Percentage: %0.0
# Value: 31603.0, Count: 1, Percentage: %0.0
# Value: 31606.0, Count: 2, Percentage: %0.01
# Value: 31621.0, Count: 3, Percentage: %0.01
# Value: 31627.0, Count: 1, Percentage: %0.0
# Value: 31650.0, Count: 1, Percentage: %0.0
# Value: 31659.0, Count: 2, Percentage: %0.01
# Value: 31670.0, Count: 2, Percentage: %0.01
# Value: 31703.0, Count: 1, Percentage: %0.0
# Value: 31717.0, Count: 2, Percentage: %0.01
# Value: 31725.0, Count: 1, Percentage: %0.0
# Value: 31728.0, Count: 1, Percentage: %0.0
# Value: 31732.0, Count: 2, Percentage: %0.01
# Value: 31740.0, Count: 5, Percentage: %0.02
# Value: 31757.0, Count: 1, Percentage: %0.0
# Value: 31778.0, Count: 2, Percentage: %0.01
# Value: 31782.0, Count: 2, Percentage: %0.01
# Value: 31801.0, Count: 1, Percentage: %0.0
# Value: 31807.0, Count: 1, Percentage: %0.0
# Value: 31826.0, Count: 1, Percentage: %0.0
# Value: 31838.0, Count: 1, Percentage: %0.0
# Value: 31840.0, Count: 1, Percentage: %0.0
# Value: 31842.0, Count: 1, Percentage: %0.0
# Value: 31848.0, Count: 2, Percentage: %0.01
# Value: 31873.0, Count: 1, Percentage: %0.0
# Value: 31905.0, Count: 1, Percentage: %0.0
# Value: 31924.0, Count: 1, Percentage: %0.0
# Value: 31935.0, Count: 3, Percentage: %0.01
# Value: 31964.0, Count: 2, Percentage: %0.01
# Value: 31965.0, Count: 1, Percentage: %0.0
# Value: 31983.0, Count: 1, Percentage: %0.0
# Value: 31985.0, Count: 1, Percentage: %0.0
# Value: 31993.0, Count: 1, Percentage: %0.0
# Value: 32000.0, Count: 1, Percentage: %0.0
# Value: 32008.0, Count: 1, Percentage: %0.0
# Value: 32016.0, Count: 2, Percentage: %0.01
# Value: 32059.0, Count: 1, Percentage: %0.0
# Value: 32121.0, Count: 1, Percentage: %0.0
# Value: 32124.0, Count: 1, Percentage: %0.0
# Value: 32126.0, Count: 1, Percentage: %0.0
# Value: 32146.0, Count: 2, Percentage: %0.01
# Value: 32172.0, Count: 1, Percentage: %0.0
# Value: 32185.0, Count: 4, Percentage: %0.01
# Value: 32186.0, Count: 1, Percentage: %0.0
# Value: 32212.0, Count: 1, Percentage: %0.0
# Value: 32214.0, Count: 1, Percentage: %0.0
# Value: 32220.0, Count: 1, Percentage: %0.0
# Value: 32239.0, Count: 1, Percentage: %0.0
# Value: 32244.0, Count: 1, Percentage: %0.0
# Value: 32271.0, Count: 1, Percentage: %0.0
# Value: 32275.0, Count: 1, Percentage: %0.0
# Value: 32276.0, Count: 2, Percentage: %0.01
# Value: 32280.0, Count: 1, Percentage: %0.0
# Value: 32287.0, Count: 1, Percentage: %0.0
# Value: 32291.0, Count: 1, Percentage: %0.0
# Value: 32311.0, Count: 1, Percentage: %0.0
# Value: 32312.0, Count: 1, Percentage: %0.0
# Value: 32316.0, Count: 1, Percentage: %0.0
# Value: 32334.0, Count: 1, Percentage: %0.0
# Value: 32356.0, Count: 1, Percentage: %0.0
# Value: 32365.0, Count: 2, Percentage: %0.01
# Value: 32372.0, Count: 3, Percentage: %0.01
# Value: 32406.0, Count: 2, Percentage: %0.01
# Value: 32423.0, Count: 1, Percentage: %0.0
# Value: 32426.0, Count: 1, Percentage: %0.0
# Value: 32446.0, Count: 1, Percentage: %0.0
# Value: 32451.0, Count: 1, Percentage: %0.0
# Value: 32477.0, Count: 1, Percentage: %0.0
# Value: 32509.0, Count: 1, Percentage: %0.0
# Value: 32519.0, Count: 1, Percentage: %0.0
# Value: 32528.0, Count: 5, Percentage: %0.02
# Value: 32533.0, Count: 1, Percentage: %0.0
# Value: 32537.0, Count: 1, Percentage: %0.0
# Value: 32546.0, Count: 1, Percentage: %0.0
# Value: 32550.0, Count: 1, Percentage: %0.0
# Value: 32552.0, Count: 2, Percentage: %0.01
# Value: 32587.0, Count: 1, Percentage: %0.0
# Value: 32607.0, Count: 1, Percentage: %0.0
# Value: 32616.0, Count: 3, Percentage: %0.01
# Value: 32627.0, Count: 1, Percentage: %0.0
# Value: 32639.0, Count: 1, Percentage: %0.0
# Value: 32650.0, Count: 1, Percentage: %0.0
# Value: 32668.0, Count: 1, Percentage: %0.0
# Value: 32694.0, Count: 2, Percentage: %0.01
# Value: 32709.0, Count: 2, Percentage: %0.01
# Value: 32732.0, Count: 5, Percentage: %0.02
# Value: 32763.0, Count: 1, Percentage: %0.0
# Value: 32776.0, Count: 1, Percentage: %0.0
# Value: 32778.0, Count: 2, Percentage: %0.01
# Value: 32779.0, Count: 1, Percentage: %0.0
# Value: 32801.0, Count: 1, Percentage: %0.0
# Value: 32825.0, Count: 2, Percentage: %0.01
# Value: 32837.0, Count: 1, Percentage: %0.0
# Value: 32855.0, Count: 2, Percentage: %0.01
# Value: 32878.0, Count: 1, Percentage: %0.0
# Value: 32896.0, Count: 1, Percentage: %0.0
# Value: 32897.0, Count: 2, Percentage: %0.01
# Value: 32916.0, Count: 2, Percentage: %0.01
# Value: 32921.0, Count: 3, Percentage: %0.01
# Value: 32922.0, Count: 1, Percentage: %0.0
# Value: 32950.0, Count: 6, Percentage: %0.02
# Value: 32954.0, Count: 1, Percentage: %0.0
# Value: 32958.0, Count: 1, Percentage: %0.0
# Value: 32981.0, Count: 1, Percentage: %0.0
# Value: 33001.0, Count: 2, Percentage: %0.01
# Value: 33002.0, Count: 1, Percentage: %0.0
# Value: 33016.0, Count: 1, Percentage: %0.0
# Value: 33035.0, Count: 1, Percentage: %0.0
# Value: 33068.0, Count: 3, Percentage: %0.01
# Value: 33087.0, Count: 2, Percentage: %0.01
# Value: 33088.0, Count: 1, Percentage: %0.0
# Value: 33105.0, Count: 3, Percentage: %0.01
# Value: 33109.0, Count: 2, Percentage: %0.01
# Value: 33117.0, Count: 4, Percentage: %0.01
# Value: 33121.0, Count: 1, Percentage: %0.0
# Value: 33124.0, Count: 3, Percentage: %0.01
# Value: 33126.0, Count: 5, Percentage: %0.02
# Value: 33138.0, Count: 1, Percentage: %0.0
# Value: 33142.0, Count: 1, Percentage: %0.0
# Value: 33155.0, Count: 3, Percentage: %0.01
# Value: 33221.0, Count: 1, Percentage: %0.0
# Value: 33234.0, Count: 1, Percentage: %0.0
# Value: 33266.0, Count: 1, Percentage: %0.0
# Value: 33274.0, Count: 1, Percentage: %0.0
# Value: 33300.0, Count: 2, Percentage: %0.01
# Value: 33304.0, Count: 4, Percentage: %0.01
# Value: 33308.0, Count: 3, Percentage: %0.01
# Value: 33309.0, Count: 1, Percentage: %0.0
# Value: 33310.0, Count: 3, Percentage: %0.01
# Value: 33315.0, Count: 1, Percentage: %0.0
# Value: 33323.0, Count: 1, Percentage: %0.0
# Value: 33331.0, Count: 5, Percentage: %0.02
# Value: 33350.0, Count: 1, Percentage: %0.0
# Value: 33355.0, Count: 2, Percentage: %0.01
# Value: 33363.0, Count: 1, Percentage: %0.0
# Value: 33365.0, Count: 1, Percentage: %0.0
# Value: 33373.0, Count: 1, Percentage: %0.0
# Value: 33374.0, Count: 1, Percentage: %0.0
# Value: 33394.0, Count: 1, Percentage: %0.0
# Value: 33397.0, Count: 2, Percentage: %0.01
# Value: 33404.0, Count: 2, Percentage: %0.01
# Value: 33417.0, Count: 1, Percentage: %0.0
# Value: 33423.0, Count: 1, Percentage: %0.0
# Value: 33429.0, Count: 1, Percentage: %0.0
# Value: 33432.0, Count: 1, Percentage: %0.0
# Value: 33442.0, Count: 1, Percentage: %0.0
# Value: 33487.0, Count: 3, Percentage: %0.01
# Value: 33521.0, Count: 4, Percentage: %0.01
# Value: 33551.0, Count: 2, Percentage: %0.01
# Value: 33610.0, Count: 4, Percentage: %0.01
# Value: 33616.0, Count: 2, Percentage: %0.01
# Value: 33619.0, Count: 1, Percentage: %0.0
# Value: 33644.0, Count: 1, Percentage: %0.0
# Value: 33658.0, Count: 3, Percentage: %0.01
# Value: 33662.0, Count: 1, Percentage: %0.0
# Value: 33669.0, Count: 1, Percentage: %0.0
# Value: 33673.0, Count: 1, Percentage: %0.0
# Value: 33678.0, Count: 2, Percentage: %0.01
# Value: 33688.0, Count: 1, Percentage: %0.0
# Value: 33710.0, Count: 1, Percentage: %0.0
# Value: 33717.0, Count: 1, Percentage: %0.0
# Value: 33725.0, Count: 2, Percentage: %0.01
# Value: 33727.0, Count: 1, Percentage: %0.0
# Value: 33729.0, Count: 1, Percentage: %0.0
# Value: 33794.0, Count: 3, Percentage: %0.01
# Value: 33795.0, Count: 1, Percentage: %0.0
# Value: 33798.0, Count: 5, Percentage: %0.02
# Value: 33831.0, Count: 1, Percentage: %0.0
# Value: 33842.0, Count: 1, Percentage: %0.0
# Value: 33863.0, Count: 3, Percentage: %0.01
# Value: 33865.0, Count: 1, Percentage: %0.0
# Value: 33884.0, Count: 1, Percentage: %0.0
# Value: 33886.0, Count: 1, Percentage: %0.0
# Value: 33887.0, Count: 2, Percentage: %0.01
# Value: 33895.0, Count: 1, Percentage: %0.0
# Value: 33939.0, Count: 1, Percentage: %0.0
# Value: 33945.0, Count: 1, Percentage: %0.0
# Value: 33975.0, Count: 6, Percentage: %0.02
# Value: 33983.0, Count: 3, Percentage: %0.01
# Value: 34007.0, Count: 3, Percentage: %0.01
# Value: 34019.0, Count: 1, Percentage: %0.0
# Value: 34021.0, Count: 1, Percentage: %0.0
# Value: 34028.0, Count: 1, Percentage: %0.0
# Value: 34029.0, Count: 1, Percentage: %0.0
# Value: 34037.0, Count: 4, Percentage: %0.01
# Value: 34066.0, Count: 1, Percentage: %0.0
# Value: 34067.0, Count: 1, Percentage: %0.0
# Value: 34080.0, Count: 2, Percentage: %0.01
# Value: 34091.0, Count: 1, Percentage: %0.0
# Value: 34098.0, Count: 1, Percentage: %0.0
# Value: 34102.0, Count: 1, Percentage: %0.0
# Value: 34104.0, Count: 3, Percentage: %0.01
# Value: 34110.0, Count: 1, Percentage: %0.0
# Value: 34112.0, Count: 1, Percentage: %0.0
# Value: 34113.0, Count: 2, Percentage: %0.01
# Value: 34125.0, Count: 1, Percentage: %0.0
# Value: 34127.0, Count: 1, Percentage: %0.0
# Value: 34146.0, Count: 1, Percentage: %0.0
# Value: 34173.0, Count: 3, Percentage: %0.01
# Value: 34178.0, Count: 1, Percentage: %0.0
# Value: 34180.0, Count: 5, Percentage: %0.02
# Value: 34186.0, Count: 1, Percentage: %0.0
# Value: 34218.0, Count: 3, Percentage: %0.01
# Value: 34233.0, Count: 1, Percentage: %0.0
# Value: 34246.0, Count: 1, Percentage: %0.0
# Value: 34248.0, Count: 3, Percentage: %0.01
# Value: 34269.0, Count: 1, Percentage: %0.0
# Value: 34273.0, Count: 1, Percentage: %0.0
# Value: 34278.0, Count: 2, Percentage: %0.01
# Value: 34292.0, Count: 2, Percentage: %0.01
# Value: 34297.0, Count: 1, Percentage: %0.0
# Value: 34307.0, Count: 1, Percentage: %0.0
# Value: 34310.0, Count: 3, Percentage: %0.01
# Value: 34335.0, Count: 1, Percentage: %0.0
# Value: 34339.0, Count: 1, Percentage: %0.0
# Value: 34340.0, Count: 1, Percentage: %0.0
# Value: 34361.0, Count: 1, Percentage: %0.0
# Value: 34364.0, Count: 1, Percentage: %0.0
# Value: 34368.0, Count: 1, Percentage: %0.0
# Value: 34374.0, Count: 2, Percentage: %0.01
# Value: 34377.0, Count: 2, Percentage: %0.01
# Value: 34378.0, Count: 6, Percentage: %0.02
# Value: 34383.0, Count: 1, Percentage: %0.0
# Value: 34393.0, Count: 1, Percentage: %0.0
# Value: 34402.0, Count: 2, Percentage: %0.01
# Value: 34419.0, Count: 2, Percentage: %0.01
# Value: 34437.0, Count: 1, Percentage: %0.0
# Value: 34443.0, Count: 1, Percentage: %0.0
# Value: 34446.0, Count: 4, Percentage: %0.01
# Value: 34452.0, Count: 1, Percentage: %0.0
# Value: 34458.0, Count: 1, Percentage: %0.0
# Value: 34503.0, Count: 1, Percentage: %0.0
# Value: 34506.0, Count: 2, Percentage: %0.01
# Value: 34532.0, Count: 1, Percentage: %0.0
# Value: 34540.0, Count: 1, Percentage: %0.0
# Value: 34541.0, Count: 1, Percentage: %0.0
# Value: 34545.0, Count: 1, Percentage: %0.0
# Value: 34568.0, Count: 2, Percentage: %0.01
# Value: 34572.0, Count: 5, Percentage: %0.02
# Value: 34574.0, Count: 1, Percentage: %0.0
# Value: 34590.0, Count: 1, Percentage: %0.0
# Value: 34616.0, Count: 3, Percentage: %0.01
# Value: 34626.0, Count: 1, Percentage: %0.0
# Value: 34632.0, Count: 2, Percentage: %0.01
# Value: 34640.0, Count: 1, Percentage: %0.0
# Value: 34701.0, Count: 1, Percentage: %0.0
# Value: 34706.0, Count: 1, Percentage: %0.0
# Value: 34722.0, Count: 2, Percentage: %0.01
# Value: 34744.0, Count: 1, Percentage: %0.0
# Value: 34747.0, Count: 1, Percentage: %0.0
# Value: 34748.0, Count: 1, Percentage: %0.0
# Value: 34788.0, Count: 1, Percentage: %0.0
# Value: 34796.0, Count: 1, Percentage: %0.0
# Value: 34803.0, Count: 2, Percentage: %0.01
# Value: 34816.0, Count: 1, Percentage: %0.0
# Value: 34832.0, Count: 2, Percentage: %0.01
# Value: 34845.0, Count: 3, Percentage: %0.01
# Value: 34848.0, Count: 2, Percentage: %0.01
# Value: 34862.0, Count: 2, Percentage: %0.01
# Value: 34878.0, Count: 1, Percentage: %0.0
# Value: 34918.0, Count: 3, Percentage: %0.01
# Value: 34935.0, Count: 1, Percentage: %0.0
# Value: 34965.0, Count: 1, Percentage: %0.0
# Value: 34973.0, Count: 2, Percentage: %0.01
# Value: 34975.0, Count: 1, Percentage: %0.0
# Value: 34987.0, Count: 3, Percentage: %0.01
# Value: 34996.0, Count: 2, Percentage: %0.01
# Value: 34998.0, Count: 1, Percentage: %0.0
# Value: 35001.0, Count: 1, Percentage: %0.0
# Value: 35015.0, Count: 1, Percentage: %0.0
# Value: 35021.0, Count: 1, Percentage: %0.0
# Value: 35032.0, Count: 4, Percentage: %0.01
# Value: 35034.0, Count: 1, Percentage: %0.0
# Value: 35065.0, Count: 1, Percentage: %0.0
# Value: 35092.0, Count: 1, Percentage: %0.0
# Value: 35102.0, Count: 1, Percentage: %0.0
# Value: 35136.0, Count: 1, Percentage: %0.0
# Value: 35166.0, Count: 2, Percentage: %0.01
# Value: 35210.0, Count: 1, Percentage: %0.0
# Value: 35211.0, Count: 2, Percentage: %0.01
# Value: 35224.0, Count: 1, Percentage: %0.0
# Value: 35236.0, Count: 2, Percentage: %0.01
# Value: 35245.0, Count: 1, Percentage: %0.0
# Value: 35295.0, Count: 2, Percentage: %0.01
# Value: 35305.0, Count: 2, Percentage: %0.01
# Value: 35309.0, Count: 2, Percentage: %0.01
# Value: 35330.0, Count: 3, Percentage: %0.01
# Value: 35340.0, Count: 1, Percentage: %0.0
# Value: 35373.0, Count: 1, Percentage: %0.0
# Value: 35378.0, Count: 2, Percentage: %0.01
# Value: 35406.0, Count: 2, Percentage: %0.01
# Value: 35411.0, Count: 1, Percentage: %0.0
# Value: 35424.0, Count: 1, Percentage: %0.0
# Value: 35429.0, Count: 2, Percentage: %0.01
# Value: 35448.0, Count: 2, Percentage: %0.01
# Value: 35459.0, Count: 1, Percentage: %0.0
# Value: 35494.0, Count: 1, Percentage: %0.0
# Value: 35520.0, Count: 1, Percentage: %0.0
# Value: 35551.0, Count: 2, Percentage: %0.01
# Value: 35557.0, Count: 1, Percentage: %0.0
# Value: 35561.0, Count: 1, Percentage: %0.0
# Value: 35576.0, Count: 4, Percentage: %0.01
# Value: 35595.0, Count: 3, Percentage: %0.01
# Value: 35598.0, Count: 1, Percentage: %0.0
# Value: 35603.0, Count: 1, Percentage: %0.0
# Value: 35626.0, Count: 1, Percentage: %0.0
# Value: 35633.0, Count: 3, Percentage: %0.01
# Value: 35644.0, Count: 3, Percentage: %0.01
# Value: 35649.0, Count: 2, Percentage: %0.01
# Value: 35662.0, Count: 1, Percentage: %0.0
# Value: 35663.0, Count: 1, Percentage: %0.0
# Value: 35683.0, Count: 1, Percentage: %0.0
# Value: 35723.0, Count: 3, Percentage: %0.01
# Value: 35724.0, Count: 1, Percentage: %0.0
# Value: 35783.0, Count: 1, Percentage: %0.0
# Value: 35824.0, Count: 2, Percentage: %0.01
# Value: 35854.0, Count: 1, Percentage: %0.0
# Value: 35865.0, Count: 2, Percentage: %0.01
# Value: 35884.0, Count: 1, Percentage: %0.0
# Value: 35890.0, Count: 1, Percentage: %0.0
# Value: 35910.0, Count: 2, Percentage: %0.01
# Value: 35917.0, Count: 2, Percentage: %0.01
# Value: 35945.0, Count: 3, Percentage: %0.01
# Value: 35961.0, Count: 1, Percentage: %0.0
# Value: 35969.0, Count: 2, Percentage: %0.01
# Value: 36006.0, Count: 1, Percentage: %0.0
# Value: 36011.0, Count: 1, Percentage: %0.0
# Value: 36012.0, Count: 2, Percentage: %0.01
# Value: 36020.0, Count: 1, Percentage: %0.0
# Value: 36032.0, Count: 2, Percentage: %0.01
# Value: 36058.0, Count: 1, Percentage: %0.0
# Value: 36069.0, Count: 3, Percentage: %0.01
# Value: 36077.0, Count: 1, Percentage: %0.0
# Value: 36162.0, Count: 1, Percentage: %0.0
# Value: 36169.0, Count: 1, Percentage: %0.0
# Value: 36177.0, Count: 2, Percentage: %0.01
# Value: 36186.0, Count: 1, Percentage: %0.0
# Value: 36201.0, Count: 1, Percentage: %0.0
# Value: 36209.0, Count: 1, Percentage: %0.0
# Value: 36214.0, Count: 2, Percentage: %0.01
# Value: 36218.0, Count: 1, Percentage: %0.0
# Value: 36228.0, Count: 3, Percentage: %0.01
# Value: 36235.0, Count: 1, Percentage: %0.0
# Value: 36251.0, Count: 1, Percentage: %0.0
# Value: 36270.0, Count: 3, Percentage: %0.01
# Value: 36271.0, Count: 2, Percentage: %0.01
# Value: 36275.0, Count: 1, Percentage: %0.0
# Value: 36302.0, Count: 2, Percentage: %0.01
# Value: 36311.0, Count: 1, Percentage: %0.0
# Value: 36325.0, Count: 1, Percentage: %0.0
# Value: 36327.0, Count: 2, Percentage: %0.01
# Value: 36340.0, Count: 1, Percentage: %0.0
# Value: 36364.0, Count: 1, Percentage: %0.0
# Value: 36376.0, Count: 1, Percentage: %0.0
# Value: 36383.0, Count: 1, Percentage: %0.0
# Value: 36385.0, Count: 2, Percentage: %0.01
# Value: 36397.0, Count: 1, Percentage: %0.0
# Value: 36411.0, Count: 1, Percentage: %0.0
# Value: 36423.0, Count: 1, Percentage: %0.0
# Value: 36425.0, Count: 2, Percentage: %0.01
# Value: 36440.0, Count: 2, Percentage: %0.01
# Value: 36467.0, Count: 1, Percentage: %0.0
# Value: 36480.0, Count: 3, Percentage: %0.01
# Value: 36489.0, Count: 2, Percentage: %0.01
# Value: 36503.0, Count: 1, Percentage: %0.0
# Value: 36539.0, Count: 1, Percentage: %0.0
# Value: 36592.0, Count: 1, Percentage: %0.0
# Value: 36601.0, Count: 2, Percentage: %0.01
# Value: 36651.0, Count: 1, Percentage: %0.0
# Value: 36671.0, Count: 1, Percentage: %0.0
# Value: 36699.0, Count: 1, Percentage: %0.0
# Value: 36851.0, Count: 2, Percentage: %0.01
# Value: 36876.0, Count: 1, Percentage: %0.0
# Value: 36877.0, Count: 1, Percentage: %0.0
# Value: 36882.0, Count: 2, Percentage: %0.01
# Value: 36885.0, Count: 1, Percentage: %0.0
# Value: 36924.0, Count: 2, Percentage: %0.01
# Value: 36936.0, Count: 1, Percentage: %0.0
# Value: 36956.0, Count: 1, Percentage: %0.0
# Value: 36960.0, Count: 1, Percentage: %0.0
# Value: 36984.0, Count: 1, Percentage: %0.0
# Value: 36989.0, Count: 3, Percentage: %0.01
# Value: 36990.0, Count: 1, Percentage: %0.0
# Value: 36999.0, Count: 1, Percentage: %0.0
# Value: 37019.0, Count: 1, Percentage: %0.0
# Value: 37023.0, Count: 1, Percentage: %0.0
# Value: 37028.0, Count: 1, Percentage: %0.0
# Value: 37070.0, Count: 2, Percentage: %0.01
# Value: 37072.0, Count: 2, Percentage: %0.01
# Value: 37088.0, Count: 4, Percentage: %0.01
# Value: 37092.0, Count: 1, Percentage: %0.0
# Value: 37109.0, Count: 1, Percentage: %0.0
# Value: 37202.0, Count: 1, Percentage: %0.0
# Value: 37203.0, Count: 1, Percentage: %0.0
# Value: 37210.0, Count: 2, Percentage: %0.01
# Value: 37215.0, Count: 1, Percentage: %0.0
# Value: 37232.0, Count: 2, Percentage: %0.01
# Value: 37237.0, Count: 2, Percentage: %0.01
# Value: 37238.0, Count: 1, Percentage: %0.0
# Value: 37250.0, Count: 2, Percentage: %0.01
# Value: 37274.0, Count: 2, Percentage: %0.01
# Value: 37289.0, Count: 2, Percentage: %0.01
# Value: 37302.0, Count: 2, Percentage: %0.01
# Value: 37306.0, Count: 1, Percentage: %0.0
# Value: 37314.0, Count: 2, Percentage: %0.01
# Value: 37332.0, Count: 1, Percentage: %0.0
# Value: 37345.0, Count: 1, Percentage: %0.0
# Value: 37353.0, Count: 1, Percentage: %0.0
# Value: 37359.0, Count: 2, Percentage: %0.01
# Value: 37379.0, Count: 2, Percentage: %0.01
# Value: 37380.0, Count: 2, Percentage: %0.01
# Value: 37394.0, Count: 1, Percentage: %0.0
# Value: 37402.0, Count: 1, Percentage: %0.0
# Value: 37438.0, Count: 1, Percentage: %0.0
# Value: 37440.0, Count: 1, Percentage: %0.0
# Value: 37482.0, Count: 1, Percentage: %0.0
# Value: 37546.0, Count: 3, Percentage: %0.01
# Value: 37599.0, Count: 1, Percentage: %0.0
# Value: 37618.0, Count: 2, Percentage: %0.01
# Value: 37646.0, Count: 2, Percentage: %0.01
# Value: 37672.0, Count: 2, Percentage: %0.01
# Value: 37676.0, Count: 1, Percentage: %0.0
# Value: 37683.0, Count: 1, Percentage: %0.0
# Value: 37720.0, Count: 1, Percentage: %0.0
# Value: 37741.0, Count: 1, Percentage: %0.0
# Value: 37745.0, Count: 1, Percentage: %0.0
# Value: 37754.0, Count: 1, Percentage: %0.0
# Value: 37778.0, Count: 5, Percentage: %0.02
# Value: 37783.0, Count: 2, Percentage: %0.01
# Value: 37792.0, Count: 1, Percentage: %0.0
# Value: 37821.0, Count: 1, Percentage: %0.0
# Value: 37848.0, Count: 1, Percentage: %0.0
# Value: 37869.0, Count: 5, Percentage: %0.02
# Value: 37894.0, Count: 1, Percentage: %0.0
# Value: 37913.0, Count: 1, Percentage: %0.0
# Value: 37918.0, Count: 1, Percentage: %0.0
# Value: 37931.0, Count: 2, Percentage: %0.01
# Value: 37932.0, Count: 1, Percentage: %0.0
# Value: 37933.0, Count: 5, Percentage: %0.02
# Value: 37937.0, Count: 4, Percentage: %0.01
# Value: 37939.0, Count: 1, Percentage: %0.0
# Value: 37987.0, Count: 1, Percentage: %0.0
# Value: 37997.0, Count: 3, Percentage: %0.01
# Value: 38001.0, Count: 1, Percentage: %0.0
# Value: 38079.0, Count: 1, Percentage: %0.0
# Value: 38090.0, Count: 1, Percentage: %0.0
# Value: 38151.0, Count: 2, Percentage: %0.01
# Value: 38158.0, Count: 1, Percentage: %0.0
# Value: 38223.0, Count: 2, Percentage: %0.01
# Value: 38232.0, Count: 1, Percentage: %0.0
# Value: 38238.0, Count: 1, Percentage: %0.0
# Value: 38240.0, Count: 2, Percentage: %0.01
# Value: 38245.0, Count: 1, Percentage: %0.0
# Value: 38251.0, Count: 3, Percentage: %0.01
# Value: 38294.0, Count: 2, Percentage: %0.01
# Value: 38307.0, Count: 1, Percentage: %0.0
# Value: 38309.0, Count: 2, Percentage: %0.01
# Value: 38310.0, Count: 1, Percentage: %0.0
# Value: 38312.0, Count: 2, Percentage: %0.01
# Value: 38352.0, Count: 1, Percentage: %0.0
# Value: 38353.0, Count: 2, Percentage: %0.01
# Value: 38360.0, Count: 1, Percentage: %0.0
# Value: 38397.0, Count: 1, Percentage: %0.0
# Value: 38434.0, Count: 2, Percentage: %0.01
# Value: 38455.0, Count: 2, Percentage: %0.01
# Value: 38468.0, Count: 1, Percentage: %0.0
# Value: 38472.0, Count: 1, Percentage: %0.0
# Value: 38488.0, Count: 1, Percentage: %0.0
# Value: 38563.0, Count: 1, Percentage: %0.0
# Value: 38573.0, Count: 1, Percentage: %0.0
# Value: 38599.0, Count: 1, Percentage: %0.0
# Value: 38606.0, Count: 1, Percentage: %0.0
# Value: 38611.0, Count: 1, Percentage: %0.0
# Value: 38619.0, Count: 2, Percentage: %0.01
# Value: 38620.0, Count: 1, Percentage: %0.0
# Value: 38621.0, Count: 1, Percentage: %0.0
# Value: 38622.0, Count: 1, Percentage: %0.0
# Value: 38645.0, Count: 1, Percentage: %0.0
# Value: 38707.0, Count: 1, Percentage: %0.0
# Value: 38721.0, Count: 1, Percentage: %0.0
# Value: 38771.0, Count: 1, Percentage: %0.0
# Value: 38772.0, Count: 2, Percentage: %0.01
# Value: 38795.0, Count: 4, Percentage: %0.01
# Value: 38797.0, Count: 1, Percentage: %0.0
# Value: 38819.0, Count: 2, Percentage: %0.01
# Value: 38822.0, Count: 1, Percentage: %0.0
# Value: 38848.0, Count: 1, Percentage: %0.0
# Value: 38876.0, Count: 3, Percentage: %0.01
# Value: 38905.0, Count: 1, Percentage: %0.0
# Value: 38918.0, Count: 2, Percentage: %0.01
# Value: 38948.0, Count: 4, Percentage: %0.01
# Value: 38950.0, Count: 3, Percentage: %0.01
# Value: 38973.0, Count: 1, Percentage: %0.0
# Value: 39014.0, Count: 1, Percentage: %0.0
# Value: 39026.0, Count: 1, Percentage: %0.0
# Value: 39054.0, Count: 3, Percentage: %0.01
# Value: 39060.0, Count: 1, Percentage: %0.0
# Value: 39089.0, Count: 1, Percentage: %0.0
# Value: 39092.0, Count: 1, Percentage: %0.0
# Value: 39110.0, Count: 1, Percentage: %0.0
# Value: 39150.0, Count: 1, Percentage: %0.0
# Value: 39181.0, Count: 1, Percentage: %0.0
# Value: 39182.0, Count: 1, Percentage: %0.0
# Value: 39207.0, Count: 1, Percentage: %0.0
# Value: 39212.0, Count: 1, Percentage: %0.0
# Value: 39222.0, Count: 1, Percentage: %0.0
# Value: 39232.0, Count: 2, Percentage: %0.01
# Value: 39234.0, Count: 1, Percentage: %0.0
# Value: 39236.0, Count: 3, Percentage: %0.01
# Value: 39239.0, Count: 1, Percentage: %0.0
# Value: 39324.0, Count: 1, Percentage: %0.0
# Value: 39352.0, Count: 1, Percentage: %0.0
# Value: 39369.0, Count: 1, Percentage: %0.0
# Value: 39380.0, Count: 2, Percentage: %0.01
# Value: 39386.0, Count: 1, Percentage: %0.0
# Value: 39388.0, Count: 1, Percentage: %0.0
# Value: 39411.0, Count: 1, Percentage: %0.0
# Value: 39432.0, Count: 1, Percentage: %0.0
# Value: 39464.0, Count: 1, Percentage: %0.0
# Value: 39477.0, Count: 2, Percentage: %0.01
# Value: 39478.0, Count: 2, Percentage: %0.01
# Value: 39484.0, Count: 1, Percentage: %0.0
# Value: 39493.0, Count: 1, Percentage: %0.0
# Value: 39529.0, Count: 1, Percentage: %0.0
# Value: 39530.0, Count: 2, Percentage: %0.01
# Value: 39539.0, Count: 1, Percentage: %0.0
# Value: 39581.0, Count: 3, Percentage: %0.01
# Value: 39586.0, Count: 1, Percentage: %0.0
# Value: 39603.0, Count: 1, Percentage: %0.0
# Value: 39606.0, Count: 3, Percentage: %0.01
# Value: 39609.0, Count: 1, Percentage: %0.0
# Value: 39610.0, Count: 1, Percentage: %0.0
# Value: 39615.0, Count: 4, Percentage: %0.01
# ...
# Value: 4.0, Count: 2817, Percentage: %9.34
#
# Mean: 0.4451959419136662
# Median: 0.0
# Mode: 0.0
# Standard Deviation: 1.196938008356543
# -----------------------------------------------------
# SEX Analysis:
# -----------------------------------------------------
# Value: 0.0, Count: 9782, Percentage: %32.43
# Value: 1.0, Count: 20380, Percentage: %67.57
#
# Mean: 0.6756846362973278
# Median: 1.0
# Mode: 1.0
# Standard Deviation: 0.46811847706438126
# -----------------------------------------------------
# CAPITAL-GAIN Analysis:
# -----------------------------------------------------
# Value: 0.0, Count: 27624, Percentage: %91.59
# Value: 114.0, Count: 6, Percentage: %0.02
# Value: 401.0, Count: 1, Percentage: %0.0
# Value: 594.0, Count: 28, Percentage: %0.09
# Value: 914.0, Count: 8, Percentage: %0.03
# Value: 991.0, Count: 3, Percentage: %0.01
# Value: 1055.0, Count: 21, Percentage: %0.07
# Value: 1086.0, Count: 1, Percentage: %0.0
# Value: 1151.0, Count: 8, Percentage: %0.03
# Value: 1173.0, Count: 1, Percentage: %0.0
# Value: 1409.0, Count: 3, Percentage: %0.01
# Value: 1424.0, Count: 3, Percentage: %0.01
# Value: 1455.0, Count: 1, Percentage: %0.0
# Value: 1471.0, Count: 7, Percentage: %0.02
# Value: 1506.0, Count: 14, Percentage: %0.05
# Value: 1639.0, Count: 1, Percentage: %0.0
# Value: 1797.0, Count: 5, Percentage: %0.02
# Value: 1831.0, Count: 7, Percentage: %0.02
# Value: 1848.0, Count: 5, Percentage: %0.02
# Value: 2009.0, Count: 2, Percentage: %0.01
# Value: 2036.0, Count: 4, Percentage: %0.01
# Value: 2050.0, Count: 3, Percentage: %0.01
# Value: 2062.0, Count: 2, Percentage: %0.01
# Value: 2105.0, Count: 8, Percentage: %0.03
# Value: 2174.0, Count: 46, Percentage: %0.15
# Value: 2176.0, Count: 20, Percentage: %0.07
# Value: 2202.0, Count: 15, Percentage: %0.05
# Value: 2228.0, Count: 3, Percentage: %0.01
# Value: 2290.0, Count: 5, Percentage: %0.02
# Value: 2329.0, Count: 4, Percentage: %0.01
# Value: 2346.0, Count: 4, Percentage: %0.01
# Value: 2354.0, Count: 10, Percentage: %0.03
# Value: 2387.0, Count: 1, Percentage: %0.0
# Value: 2407.0, Count: 18, Percentage: %0.06
# Value: 2414.0, Count: 6, Percentage: %0.02
# Value: 2463.0, Count: 11, Percentage: %0.04
# Value: 2538.0, Count: 1, Percentage: %0.0
# Value: 2580.0, Count: 12, Percentage: %0.04
# Value: 2597.0, Count: 20, Percentage: %0.07
# Value: 2635.0, Count: 10, Percentage: %0.03
# Value: 2653.0, Count: 4, Percentage: %0.01
# Value: 2829.0, Count: 30, Percentage: %0.1
# Value: 2885.0, Count: 22, Percentage: %0.07
# Value: 2907.0, Count: 10, Percentage: %0.03
# Value: 2936.0, Count: 3, Percentage: %0.01
# Value: 2961.0, Count: 2, Percentage: %0.01
# Value: 2964.0, Count: 6, Percentage: %0.02
# Value: 2977.0, Count: 8, Percentage: %0.03
# Value: 2993.0, Count: 1, Percentage: %0.0
# Value: 3103.0, Count: 94, Percentage: %0.31
# Value: 3137.0, Count: 36, Percentage: %0.12
# Value: 3273.0, Count: 6, Percentage: %0.02
# Value: 3325.0, Count: 53, Percentage: %0.18
# Value: 3411.0, Count: 21, Percentage: %0.07
# Value: 3418.0, Count: 3, Percentage: %0.01
# Value: 3432.0, Count: 2, Percentage: %0.01
# Value: 3456.0, Count: 2, Percentage: %0.01
# Value: 3464.0, Count: 20, Percentage: %0.07
# Value: 3471.0, Count: 7, Percentage: %0.02
# Value: 3674.0, Count: 13, Percentage: %0.04
# Value: 3781.0, Count: 10, Percentage: %0.03
# Value: 3818.0, Count: 5, Percentage: %0.02
# Value: 3887.0, Count: 6, Percentage: %0.02
# Value: 3908.0, Count: 31, Percentage: %0.1
# Value: 3942.0, Count: 12, Percentage: %0.04
# Value: 4064.0, Count: 40, Percentage: %0.13
# Value: 4101.0, Count: 19, Percentage: %0.06
# Value: 4386.0, Count: 67, Percentage: %0.22
# Value: 4416.0, Count: 11, Percentage: %0.04
# Value: 4508.0, Count: 11, Percentage: %0.04
# Value: 4650.0, Count: 40, Percentage: %0.13
# Value: 4687.0, Count: 3, Percentage: %0.01
# Value: 4787.0, Count: 22, Percentage: %0.07
# Value: 4865.0, Count: 16, Percentage: %0.05
# Value: 4931.0, Count: 1, Percentage: %0.0
# Value: 4934.0, Count: 7, Percentage: %0.02
# Value: 5013.0, Count: 69, Percentage: %0.23
# Value: 5060.0, Count: 1, Percentage: %0.0
# Value: 5178.0, Count: 91, Percentage: %0.3
# Value: 5455.0, Count: 11, Percentage: %0.04
# Value: 5556.0, Count: 4, Percentage: %0.01
# Value: 5721.0, Count: 3, Percentage: %0.01
# Value: 6097.0, Count: 1, Percentage: %0.0
# Value: 6360.0, Count: 3, Percentage: %0.01
# Value: 6418.0, Count: 7, Percentage: %0.02
# Value: 6497.0, Count: 11, Percentage: %0.04
# Value: 6514.0, Count: 4, Percentage: %0.01
# Value: 6723.0, Count: 2, Percentage: %0.01
# Value: 6767.0, Count: 3, Percentage: %0.01
# Value: 6849.0, Count: 26, Percentage: %0.09
# Value: 7298.0, Count: 240, Percentage: %0.8
# Value: 7430.0, Count: 8, Percentage: %0.03
# Value: 7443.0, Count: 5, Percentage: %0.02
# Value: 7688.0, Count: 270, Percentage: %0.9
# Value: 7896.0, Count: 2, Percentage: %0.01
# Value: 7978.0, Count: 1, Percentage: %0.0
# Value: 8614.0, Count: 52, Percentage: %0.17
# Value: 9386.0, Count: 16, Percentage: %0.05
# Value: 9562.0, Count: 4, Percentage: %0.01
# Value: 10520.0, Count: 43, Percentage: %0.14
# Value: 10566.0, Count: 6, Percentage: %0.02
# Value: 10605.0, Count: 9, Percentage: %0.03
# Value: 11678.0, Count: 2, Percentage: %0.01
# Value: 13550.0, Count: 25, Percentage: %0.08
# Value: 14084.0, Count: 39, Percentage: %0.13
# Value: 14344.0, Count: 26, Percentage: %0.09
# Value: 15020.0, Count: 5, Percentage: %0.02
# Value: 15024.0, Count: 337, Percentage: %1.12
# Value: 15831.0, Count: 6, Percentage: %0.02
# Value: 18481.0, Count: 2, Percentage: %0.01
# Value: 20051.0, Count: 33, Percentage: %0.11
# Value: 22040.0, Count: 1, Percentage: %0.0
# Value: 25124.0, Count: 2, Percentage: %0.01
# Value: 25236.0, Count: 11, Percentage: %0.04
# Value: 27828.0, Count: 32, Percentage: %0.11
# Value: 34095.0, Count: 3, Percentage: %0.01
# Value: 41310.0, Count: 2, Percentage: %0.01
# Value: 99999.0, Count: 148, Percentage: %0.49
#
# Mean: 1092.0078575691268
# Median: 0.0
# Mode: 0.0
# Standard Deviation: 7406.223719548601
# -----------------------------------------------------
# CAPITAL-LOSS Analysis:
# -----------------------------------------------------
# Value: 0.0, Count: 28735, Percentage: %95.27
# Value: 155.0, Count: 1, Percentage: %0.0
# Value: 213.0, Count: 4, Percentage: %0.01
# Value: 323.0, Count: 3, Percentage: %0.01
# Value: 419.0, Count: 1, Percentage: %0.0
# Value: 625.0, Count: 12, Percentage: %0.04
# Value: 653.0, Count: 3, Percentage: %0.01
# Value: 810.0, Count: 2, Percentage: %0.01
# Value: 880.0, Count: 6, Percentage: %0.02
# Value: 974.0, Count: 2, Percentage: %0.01
# Value: 1092.0, Count: 7, Percentage: %0.02
# Value: 1138.0, Count: 2, Percentage: %0.01
# Value: 1258.0, Count: 3, Percentage: %0.01
# Value: 1340.0, Count: 7, Percentage: %0.02
# Value: 1380.0, Count: 7, Percentage: %0.02
# Value: 1408.0, Count: 19, Percentage: %0.06
# Value: 1411.0, Count: 1, Percentage: %0.0
# Value: 1485.0, Count: 45, Percentage: %0.15
# Value: 1504.0, Count: 16, Percentage: %0.05
# Value: 1539.0, Count: 1, Percentage: %0.0
# Value: 1564.0, Count: 24, Percentage: %0.08
# Value: 1573.0, Count: 5, Percentage: %0.02
# Value: 1579.0, Count: 20, Percentage: %0.07
# Value: 1590.0, Count: 37, Percentage: %0.12
# Value: 1594.0, Count: 8, Percentage: %0.03
# Value: 1602.0, Count: 34, Percentage: %0.11
# Value: 1617.0, Count: 9, Percentage: %0.03
# Value: 1628.0, Count: 13, Percentage: %0.04
# Value: 1648.0, Count: 2, Percentage: %0.01
# Value: 1651.0, Count: 9, Percentage: %0.03
# Value: 1668.0, Count: 3, Percentage: %0.01
# Value: 1669.0, Count: 23, Percentage: %0.08
# Value: 1672.0, Count: 34, Percentage: %0.11
# Value: 1719.0, Count: 20, Percentage: %0.07
# Value: 1721.0, Count: 16, Percentage: %0.05
# Value: 1726.0, Count: 4, Percentage: %0.01
# Value: 1735.0, Count: 2, Percentage: %0.01
# Value: 1740.0, Count: 41, Percentage: %0.14
# Value: 1741.0, Count: 23, Percentage: %0.08
# Value: 1755.0, Count: 2, Percentage: %0.01
# Value: 1762.0, Count: 13, Percentage: %0.04
# Value: 1816.0, Count: 2, Percentage: %0.01
# Value: 1825.0, Count: 3, Percentage: %0.01
# Value: 1844.0, Count: 1, Percentage: %0.0
# Value: 1848.0, Count: 50, Percentage: %0.17
# Value: 1876.0, Count: 39, Percentage: %0.13
# Value: 1887.0, Count: 155, Percentage: %0.51
# Value: 1902.0, Count: 194, Percentage: %0.64
# Value: 1944.0, Count: 1, Percentage: %0.0
# Value: 1974.0, Count: 18, Percentage: %0.06
# Value: 1977.0, Count: 162, Percentage: %0.54
# Value: 1980.0, Count: 23, Percentage: %0.08
# Value: 2001.0, Count: 21, Percentage: %0.07
# Value: 2002.0, Count: 20, Percentage: %0.07
# Value: 2042.0, Count: 9, Percentage: %0.03
# Value: 2051.0, Count: 21, Percentage: %0.07
# Value: 2057.0, Count: 6, Percentage: %0.02
# Value: 2080.0, Count: 1, Percentage: %0.0
# Value: 2129.0, Count: 2, Percentage: %0.01
# Value: 2149.0, Count: 2, Percentage: %0.01
# Value: 2174.0, Count: 6, Percentage: %0.02
# Value: 2179.0, Count: 14, Percentage: %0.05
# Value: 2201.0, Count: 1, Percentage: %0.0
# Value: 2205.0, Count: 8, Percentage: %0.03
# Value: 2206.0, Count: 5, Percentage: %0.02
# Value: 2231.0, Count: 3, Percentage: %0.01
# Value: 2238.0, Count: 2, Percentage: %0.01
# Value: 2246.0, Count: 6, Percentage: %0.02
# Value: 2258.0, Count: 25, Percentage: %0.08
# Value: 2267.0, Count: 3, Percentage: %0.01
# Value: 2282.0, Count: 1, Percentage: %0.0
# Value: 2339.0, Count: 14, Percentage: %0.05
# Value: 2352.0, Count: 2, Percentage: %0.01
# Value: 2377.0, Count: 17, Percentage: %0.06
# Value: 2392.0, Count: 8, Percentage: %0.03
# Value: 2415.0, Count: 45, Percentage: %0.15
# Value: 2444.0, Count: 12, Percentage: %0.04
# Value: 2457.0, Count: 1, Percentage: %0.0
# Value: 2467.0, Count: 1, Percentage: %0.0
# Value: 2472.0, Count: 1, Percentage: %0.0
# Value: 2547.0, Count: 4, Percentage: %0.01
# Value: 2559.0, Count: 12, Percentage: %0.04
# Value: 2603.0, Count: 4, Percentage: %0.01
# Value: 2754.0, Count: 2, Percentage: %0.01
# Value: 2824.0, Count: 8, Percentage: %0.03
# Value: 3004.0, Count: 1, Percentage: %0.0
# Value: 3683.0, Count: 2, Percentage: %0.01
# Value: 3770.0, Count: 2, Percentage: %0.01
# Value: 3900.0, Count: 2, Percentage: %0.01
# Value: 4356.0, Count: 1, Percentage: %0.0
#
# Mean: 88.37248856176646
# Median: 0.0
# Mode: 0.0
# Standard Deviation: 404.29166831606875
# -----------------------------------------------------
# HOURS-PER-WEEK Analysis:
# -----------------------------------------------------
# Value: 1.0, Count: 7, Percentage: %0.02
# Value: 2.0, Count: 15, Percentage: %0.05
# Value: 3.0, Count: 24, Percentage: %0.08
# Value: 4.0, Count: 27, Percentage: %0.09
# Value: 5.0, Count: 38, Percentage: %0.13
# Value: 6.0, Count: 40, Percentage: %0.13
# Value: 7.0, Count: 19, Percentage: %0.06
# Value: 8.0, Count: 102, Percentage: %0.34
# Value: 9.0, Count: 17, Percentage: %0.06
# Value: 10.0, Count: 222, Percentage: %0.74
# Value: 11.0, Count: 9, Percentage: %0.03
# Value: 12.0, Count: 137, Percentage: %0.45
# Value: 13.0, Count: 18, Percentage: %0.06
# Value: 14.0, Count: 29, Percentage: %0.1
# Value: 15.0, Count: 346, Percentage: %1.15
# Value: 16.0, Count: 180, Percentage: %0.6
# Value: 17.0, Count: 27, Percentage: %0.09
# Value: 18.0, Count: 63, Percentage: %0.21
# Value: 19.0, Count: 14, Percentage: %0.05
# Value: 20.0, Count: 1054, Percentage: %3.49
# Value: 21.0, Count: 23, Percentage: %0.08
# Value: 22.0, Count: 39, Percentage: %0.13
# Value: 23.0, Count: 20, Percentage: %0.07
# Value: 24.0, Count: 217, Percentage: %0.72
# Value: 25.0, Count: 574, Percentage: %1.9
# Value: 26.0, Count: 28, Percentage: %0.09
# Value: 27.0, Count: 28, Percentage: %0.09
# Value: 28.0, Count: 72, Percentage: %0.24
# Value: 29.0, Count: 5, Percentage: %0.02
# Value: 30.0, Count: 989, Percentage: %3.28
# Value: 31.0, Count: 5, Percentage: %0.02
# Value: 32.0, Count: 238, Percentage: %0.79
# Value: 33.0, Count: 37, Percentage: %0.12
# Value: 34.0, Count: 27, Percentage: %0.09
# Value: 35.0, Count: 1184, Percentage: %3.93
# Value: 36.0, Count: 202, Percentage: %0.67
# Value: 37.0, Count: 145, Percentage: %0.48
# Value: 38.0, Count: 456, Percentage: %1.51
# Value: 39.0, Count: 37, Percentage: %0.12
# Value: 40.0, Count: 14251, Percentage: %47.25
# Value: 41.0, Count: 34, Percentage: %0.11
# Value: 42.0, Count: 213, Percentage: %0.71
# Value: 43.0, Count: 146, Percentage: %0.48
# Value: 44.0, Count: 209, Percentage: %0.69
# Value: 45.0, Count: 1753, Percentage: %5.81
# Value: 46.0, Count: 80, Percentage: %0.27
# Value: 47.0, Count: 49, Percentage: %0.16
# Value: 48.0, Count: 494, Percentage: %1.64
# Value: 49.0, Count: 26, Percentage: %0.09
# Value: 50.0, Count: 2718, Percentage: %9.01
# Value: 51.0, Count: 13, Percentage: %0.04
# Value: 52.0, Count: 135, Percentage: %0.45
# Value: 53.0, Count: 22, Percentage: %0.07
# Value: 54.0, Count: 38, Percentage: %0.13
# Value: 55.0, Count: 672, Percentage: %2.23
# Value: 56.0, Count: 90, Percentage: %0.3
# Value: 57.0, Count: 17, Percentage: %0.06
# Value: 58.0, Count: 27, Percentage: %0.09
# Value: 59.0, Count: 4, Percentage: %0.01
# Value: 60.0, Count: 1405, Percentage: %4.66
# Value: 61.0, Count: 2, Percentage: %0.01
# Value: 62.0, Count: 18, Percentage: %0.06
# Value: 63.0, Count: 9, Percentage: %0.03
# Value: 64.0, Count: 14, Percentage: %0.05
# Value: 65.0, Count: 241, Percentage: %0.8
# Value: 66.0, Count: 16, Percentage: %0.05
# Value: 67.0, Count: 4, Percentage: %0.01
# Value: 68.0, Count: 12, Percentage: %0.04
# Value: 70.0, Count: 276, Percentage: %0.92
# Value: 72.0, Count: 62, Percentage: %0.21
# Value: 73.0, Count: 2, Percentage: %0.01
# Value: 74.0, Count: 1, Percentage: %0.0
# Value: 75.0, Count: 63, Percentage: %0.21
# Value: 76.0, Count: 3, Percentage: %0.01
# Value: 77.0, Count: 6, Percentage: %0.02
# Value: 78.0, Count: 8, Percentage: %0.03
# Value: 80.0, Count: 120, Percentage: %0.4
# Value: 81.0, Count: 3, Percentage: %0.01
# Value: 82.0, Count: 1, Percentage: %0.0
# Value: 84.0, Count: 40, Percentage: %0.13
# Value: 85.0, Count: 13, Percentage: %0.04
# Value: 86.0, Count: 2, Percentage: %0.01
# Value: 87.0, Count: 1, Percentage: %0.0
# Value: 88.0, Count: 2, Percentage: %0.01
# Value: 89.0, Count: 2, Percentage: %0.01
# Value: 90.0, Count: 28, Percentage: %0.09
# Value: 91.0, Count: 3, Percentage: %0.01
# Value: 92.0, Count: 1, Percentage: %0.0
# Value: 94.0, Count: 1, Percentage: %0.0
# Value: 95.0, Count: 2, Percentage: %0.01
# Value: 96.0, Count: 5, Percentage: %0.02
# Value: 97.0, Count: 2, Percentage: %0.01
# Value: 98.0, Count: 11, Percentage: %0.04
# Value: 99.0, Count: 78, Percentage: %0.26
#
# Mean: 40.93123798156621
# Median: 40.0
# Mode: 40.0
# Standard Deviation: 11.979785633632552
# -----------------------------------------------------
# NATIVE-COUNTRY Analysis:
# -----------------------------------------------------
# Value: 0.0, Count: 27504, Percentage: %91.19
# Value: 1.0, Count: 18, Percentage: %0.06
# Value: 2.0, Count: 86, Percentage: %0.29
# Value: 3.0, Count: 109, Percentage: %0.36
# Value: 4.0, Count: 107, Percentage: %0.35
# Value: 5.0, Count: 128, Percentage: %0.42
# Value: 6.0, Count: 14, Percentage: %0.05
# Value: 7.0, Count: 100, Percentage: %0.33
# Value: 8.0, Count: 59, Percentage: %0.2
# Value: 9.0, Count: 29, Percentage: %0.1
# Value: 10.0, Count: 71, Percentage: %0.24
# Value: 11.0, Count: 68, Percentage: %0.23
# Value: 12.0, Count: 92, Percentage: %0.31
# Value: 13.0, Count: 42, Percentage: %0.14
# Value: 14.0, Count: 12, Percentage: %0.04
# Value: 15.0, Count: 188, Percentage: %0.62
# Value: 16.0, Count: 68, Percentage: %0.23
# Value: 17.0, Count: 56, Percentage: %0.19
# Value: 18.0, Count: 80, Percentage: %0.27
# Value: 19.0, Count: 64, Percentage: %0.21
# Value: 20.0, Count: 610, Percentage: %2.02
# Value: 21.0, Count: 34, Percentage: %0.11
# Value: 22.0, Count: 24, Percentage: %0.08
# Value: 23.0, Count: 27, Percentage: %0.09
# Value: 24.0, Count: 67, Percentage: %0.22
# Value: 25.0, Count: 17, Percentage: %0.06
# Value: 26.0, Count: 27, Percentage: %0.09
# Value: 27.0, Count: 42, Percentage: %0.14
# Value: 28.0, Count: 42, Percentage: %0.14
# Value: 29.0, Count: 56, Percentage: %0.19
# Value: 30.0, Count: 13, Percentage: %0.04
# Value: 31.0, Count: 63, Percentage: %0.21
# Value: 32.0, Count: 33, Percentage: %0.11
# Value: 33.0, Count: 11, Percentage: %0.04
# Value: 34.0, Count: 17, Percentage: %0.06
# Value: 35.0, Count: 16, Percentage: %0.05
# Value: 36.0, Count: 100, Percentage: %0.33
# Value: 37.0, Count: 18, Percentage: %0.06
# Value: 38.0, Count: 30, Percentage: %0.1
# Value: 39.0, Count: 19, Percentage: %0.06
# Value: 40.0, Count: 1, Percentage: %0.0
#
# Mean: 1.5155825210529805
# Median: 0.0
# Mode: 0.0
# Standard Deviation: 5.640981672810041

# %% [markdown]
# ### Dataset 3 (Rice Data Set):

# %%
filename = "data/Rice_Cammeo_Osmancik.arff.txt"

# @ATTRIBUTE Area Integer
# @ATTRIBUTE Perimeter Real
# @ATTRIBUTE Major_Axis_Length Real
# @ATTRIBUTE Minor_Axis_Length Real
# @ATTRIBUTE Eccentricity	Real
# @ATTRIBUTE Convex_Area	Integer
# @ATTRIBUTE Extent Real
# @ATTRIBUTE Class {Cammeo, Osmancik}

categories = ["Area", "Perimeter", "Major_Axis_Length", "Minor_Axis_Length", "Eccentricity", "Convex_Area", "Extent" ]
classifications = ["Cammeo", "Osmancik"]

rice_data = readFile(filename)[0]
print(rice_data)
print()

# # Count the number of positive class instances
# positive_count = sum(1 for label in rice_labels if label == 1)

# # Count the number of negative class instances
# negative_count = sum(1 for label in rice_labels if label == 0)

# print("Distribution of classes:")
# print("Positive (Cammeo):", positive_count)
# print("Negative (Osmancik):", negative_count)

print("\nData:")
# print(rice_data, rice_labels)

# iris_labels = iris_labels.reshape(-1, 1)

# new_rice_data = np.hstack((rice_data, rice_labels))
# # print(new_iris_data)

riceAnalysis = dataAnalysis(rice_data,categories,classifications)
riceAnalysis.printLabelStats()
riceAnalysis.printCategoryStats()

# print(iris_labels)
# Out:
# [['15231' '525.5789794921875' '229.7498779296875' ... '15617'
#   '0.5728955268859863' 'Cammeo']
#  ['14656' '494.3110046386719' '206.0200653076172' ... '15072'
#   '0.615436315536499' 'Cammeo']
#  ['14634' '501.12200927734375' '214.10678100585938' ... '14954'
#   '0.6932588219642639' 'Cammeo']
#  ...
#  ['12437' '442.4989929199219' '183.5729217529297' ... '12645'
#   '0.6267385482788086' 'Osmancik']
#  ['9882' '392.2969970703125' '161.19398498535156' ... '10097'
#   '0.6590636372566223' 'Osmancik']
#  ['11434' '404.7099914550781' '161.0792694091797' ... '11591'
#   '0.8029494285583496' 'Osmancik']]
#
#
# Data:
# =====================================================
# Classification Analysis:
# =====================================================
# Total: 3810 (%100)
# Value: Cammeo, Count: 1630, Percentage: %42.78
# Value: Osmancik, Count: 2180, Percentage: %57.22
# =====================================================
# Attribute Analysis:
# =====================================================
# -----------------------------------------------------
# AREA Analysis:
# -----------------------------------------------------
# Value: 7551.0, Count: 1, Percentage: %0.03
# Value: 7833.0, Count: 1, Percentage: %0.03
# Value: 7943.0, Count: 1, Percentage: %0.03
# Value: 8328.0, Count: 1, Percentage: %0.03
# Value: 8499.0, Count: 1, Percentage: %0.03
# Value: 8501.0, Count: 1, Percentage: %0.03
# Value: 8505.0, Count: 1, Percentage: %0.03
# Value: 8546.0, Count: 1, Percentage: %0.03
# Value: 8604.0, Count: 1, Percentage: %0.03
# Value: 8628.0, Count: 1, Percentage: %0.03
# Value: 8652.0, Count: 1, Percentage: %0.03
# Value: 8679.0, Count: 1, Percentage: %0.03
# Value: 8702.0, Count: 1, Percentage: %0.03
# Value: 8709.0, Count: 1, Percentage: %0.03
# Value: 8810.0, Count: 1, Percentage: %0.03
# Value: 8813.0, Count: 1, Percentage: %0.03
# Value: 8848.0, Count: 1, Percentage: %0.03
# Value: 8850.0, Count: 1, Percentage: %0.03
# Value: 8965.0, Count: 1, Percentage: %0.03
# Value: 8968.0, Count: 1, Percentage: %0.03
# Value: 8990.0, Count: 1, Percentage: %0.03
# Value: 8992.0, Count: 1, Percentage: %0.03
# Value: 9017.0, Count: 1, Percentage: %0.03
# Value: 9028.0, Count: 1, Percentage: %0.03
# Value: 9050.0, Count: 1, Percentage: %0.03
# Value: 9070.0, Count: 1, Percentage: %0.03
# Value: 9080.0, Count: 1, Percentage: %0.03
# Value: 9117.0, Count: 1, Percentage: %0.03
# Value: 9120.0, Count: 1, Percentage: %0.03
# Value: 9127.0, Count: 1, Percentage: %0.03
# Value: 9154.0, Count: 1, Percentage: %0.03
# Value: 9165.0, Count: 1, Percentage: %0.03
# Value: 9212.0, Count: 1, Percentage: %0.03
# Value: 9216.0, Count: 1, Percentage: %0.03
# Value: 9221.0, Count: 1, Percentage: %0.03
# Value: 9225.0, Count: 1, Percentage: %0.03
# Value: 9236.0, Count: 1, Percentage: %0.03
# Value: 9249.0, Count: 1, Percentage: %0.03
# Value: 9251.0, Count: 1, Percentage: %0.03
# Value: 9273.0, Count: 1, Percentage: %0.03
# Value: 9292.0, Count: 1, Percentage: %0.03
# Value: 9322.0, Count: 1, Percentage: %0.03
# Value: 9330.0, Count: 1, Percentage: %0.03
# Value: 9335.0, Count: 1, Percentage: %0.03
# Value: 9346.0, Count: 1, Percentage: %0.03
# Value: 9359.0, Count: 1, Percentage: %0.03
# Value: 9360.0, Count: 1, Percentage: %0.03
# Value: 9369.0, Count: 1, Percentage: %0.03
# Value: 9371.0, Count: 2, Percentage: %0.05
# Value: 9373.0, Count: 1, Percentage: %0.03
# Value: 9405.0, Count: 1, Percentage: %0.03
# Value: 9414.0, Count: 1, Percentage: %0.03
# Value: 9424.0, Count: 1, Percentage: %0.03
# Value: 9426.0, Count: 1, Percentage: %0.03
# Value: 9428.0, Count: 1, Percentage: %0.03
# Value: 9431.0, Count: 1, Percentage: %0.03
# Value: 9441.0, Count: 1, Percentage: %0.03
# Value: 9447.0, Count: 1, Percentage: %0.03
# Value: 9468.0, Count: 1, Percentage: %0.03
# Value: 9483.0, Count: 1, Percentage: %0.03
# Value: 9487.0, Count: 1, Percentage: %0.03
# Value: 9495.0, Count: 1, Percentage: %0.03
# Value: 9510.0, Count: 1, Percentage: %0.03
# Value: 9516.0, Count: 1, Percentage: %0.03
# Value: 9517.0, Count: 1, Percentage: %0.03
# Value: 9519.0, Count: 1, Percentage: %0.03
# Value: 9520.0, Count: 1, Percentage: %0.03
# Value: 9544.0, Count: 1, Percentage: %0.03
# Value: 9561.0, Count: 1, Percentage: %0.03
# Value: 9571.0, Count: 1, Percentage: %0.03
# Value: 9577.0, Count: 2, Percentage: %0.05
# Value: 9584.0, Count: 1, Percentage: %0.03
# Value: 9585.0, Count: 1, Percentage: %0.03
# Value: 9592.0, Count: 1, Percentage: %0.03
# Value: 9593.0, Count: 1, Percentage: %0.03
# Value: 9598.0, Count: 1, Percentage: %0.03
# Value: 9621.0, Count: 1, Percentage: %0.03
# Value: 9622.0, Count: 1, Percentage: %0.03
# Value: 9630.0, Count: 1, Percentage: %0.03
# Value: 9638.0, Count: 1, Percentage: %0.03
# Value: 9646.0, Count: 1, Percentage: %0.03
# Value: 9668.0, Count: 1, Percentage: %0.03
# Value: 9669.0, Count: 1, Percentage: %0.03
# Value: 9677.0, Count: 1, Percentage: %0.03
# Value: 9679.0, Count: 2, Percentage: %0.05
# Value: 9711.0, Count: 1, Percentage: %0.03
# Value: 9722.0, Count: 1, Percentage: %0.03
# Value: 9723.0, Count: 1, Percentage: %0.03
# Value: 9732.0, Count: 1, Percentage: %0.03
# Value: 9733.0, Count: 1, Percentage: %0.03
# Value: 9741.0, Count: 1, Percentage: %0.03
# Value: 9746.0, Count: 1, Percentage: %0.03
# Value: 9749.0, Count: 1, Percentage: %0.03
# Value: 9751.0, Count: 1, Percentage: %0.03
# Value: 9753.0, Count: 1, Percentage: %0.03
# Value: 9759.0, Count: 1, Percentage: %0.03
# Value: 9760.0, Count: 1, Percentage: %0.03
# Value: 9762.0, Count: 1, Percentage: %0.03
# Value: 9763.0, Count: 1, Percentage: %0.03
# Value: 9764.0, Count: 1, Percentage: %0.03
# Value: 9768.0, Count: 1, Percentage: %0.03
# Value: 9772.0, Count: 2, Percentage: %0.05
# Value: 9776.0, Count: 1, Percentage: %0.03
# Value: 9778.0, Count: 1, Percentage: %0.03
# Value: 9798.0, Count: 1, Percentage: %0.03
# Value: 9801.0, Count: 1, Percentage: %0.03
# Value: 9802.0, Count: 2, Percentage: %0.05
# Value: 9817.0, Count: 1, Percentage: %0.03
# Value: 9819.0, Count: 1, Percentage: %0.03
# Value: 9822.0, Count: 1, Percentage: %0.03
# Value: 9834.0, Count: 1, Percentage: %0.03
# Value: 9842.0, Count: 1, Percentage: %0.03
# Value: 9843.0, Count: 1, Percentage: %0.03
# Value: 9853.0, Count: 1, Percentage: %0.03
# Value: 9854.0, Count: 1, Percentage: %0.03
# Value: 9858.0, Count: 1, Percentage: %0.03
# Value: 9862.0, Count: 1, Percentage: %0.03
# Value: 9876.0, Count: 1, Percentage: %0.03
# Value: 9878.0, Count: 1, Percentage: %0.03
# Value: 9882.0, Count: 1, Percentage: %0.03
# Value: 9884.0, Count: 1, Percentage: %0.03
# Value: 9885.0, Count: 1, Percentage: %0.03
# Value: 9903.0, Count: 1, Percentage: %0.03
# Value: 9908.0, Count: 2, Percentage: %0.05
# Value: 9911.0, Count: 1, Percentage: %0.03
# Value: 9918.0, Count: 1, Percentage: %0.03
# Value: 9920.0, Count: 1, Percentage: %0.03
# Value: 9929.0, Count: 1, Percentage: %0.03
# Value: 9933.0, Count: 1, Percentage: %0.03
# Value: 9936.0, Count: 1, Percentage: %0.03
# Value: 9944.0, Count: 1, Percentage: %0.03
# Value: 9945.0, Count: 1, Percentage: %0.03
# Value: 9961.0, Count: 2, Percentage: %0.05
# Value: 9962.0, Count: 2, Percentage: %0.05
# Value: 9963.0, Count: 1, Percentage: %0.03
# Value: 9967.0, Count: 1, Percentage: %0.03
# Value: 9972.0, Count: 1, Percentage: %0.03
# Value: 9975.0, Count: 1, Percentage: %0.03
# Value: 9976.0, Count: 1, Percentage: %0.03
# Value: 9983.0, Count: 1, Percentage: %0.03
# Value: 9994.0, Count: 1, Percentage: %0.03
# Value: 10000.0, Count: 1, Percentage: %0.03
# Value: 10005.0, Count: 1, Percentage: %0.03
# Value: 10007.0, Count: 1, Percentage: %0.03
# Value: 10015.0, Count: 2, Percentage: %0.05
# Value: 10020.0, Count: 1, Percentage: %0.03
# Value: 10023.0, Count: 1, Percentage: %0.03
# Value: 10025.0, Count: 1, Percentage: %0.03
# Value: 10030.0, Count: 1, Percentage: %0.03
# Value: 10032.0, Count: 1, Percentage: %0.03
# Value: 10035.0, Count: 1, Percentage: %0.03
# Value: 10036.0, Count: 1, Percentage: %0.03
# Value: 10037.0, Count: 1, Percentage: %0.03
# Value: 10040.0, Count: 1, Percentage: %0.03
# Value: 10044.0, Count: 1, Percentage: %0.03
# Value: 10061.0, Count: 1, Percentage: %0.03
# Value: 10066.0, Count: 1, Percentage: %0.03
# Value: 10074.0, Count: 2, Percentage: %0.05
# Value: 10083.0, Count: 1, Percentage: %0.03
# Value: 10085.0, Count: 2, Percentage: %0.05
# Value: 10088.0, Count: 1, Percentage: %0.03
# Value: 10101.0, Count: 1, Percentage: %0.03
# Value: 10102.0, Count: 1, Percentage: %0.03
# Value: 10106.0, Count: 1, Percentage: %0.03
# Value: 10114.0, Count: 1, Percentage: %0.03
# Value: 10119.0, Count: 1, Percentage: %0.03
# Value: 10121.0, Count: 1, Percentage: %0.03
# Value: 10128.0, Count: 1, Percentage: %0.03
# Value: 10132.0, Count: 1, Percentage: %0.03
# Value: 10134.0, Count: 1, Percentage: %0.03
# Value: 10138.0, Count: 1, Percentage: %0.03
# Value: 10144.0, Count: 2, Percentage: %0.05
# Value: 10148.0, Count: 1, Percentage: %0.03
# Value: 10150.0, Count: 2, Percentage: %0.05
# Value: 10151.0, Count: 1, Percentage: %0.03
# Value: 10152.0, Count: 1, Percentage: %0.03
# Value: 10156.0, Count: 1, Percentage: %0.03
# Value: 10167.0, Count: 1, Percentage: %0.03
# Value: 10168.0, Count: 1, Percentage: %0.03
# Value: 10171.0, Count: 1, Percentage: %0.03
# Value: 10173.0, Count: 1, Percentage: %0.03
# Value: 10182.0, Count: 1, Percentage: %0.03
# Value: 10185.0, Count: 1, Percentage: %0.03
# Value: 10187.0, Count: 2, Percentage: %0.05
# Value: 10189.0, Count: 1, Percentage: %0.03
# Value: 10190.0, Count: 1, Percentage: %0.03
# Value: 10191.0, Count: 2, Percentage: %0.05
# Value: 10192.0, Count: 1, Percentage: %0.03
# Value: 10193.0, Count: 1, Percentage: %0.03
# Value: 10198.0, Count: 1, Percentage: %0.03
# Value: 10201.0, Count: 1, Percentage: %0.03
# Value: 10208.0, Count: 1, Percentage: %0.03
# Value: 10211.0, Count: 1, Percentage: %0.03
# Value: 10213.0, Count: 1, Percentage: %0.03
# Value: 10214.0, Count: 1, Percentage: %0.03
# Value: 10215.0, Count: 1, Percentage: %0.03
# Value: 10218.0, Count: 1, Percentage: %0.03
# Value: 10221.0, Count: 1, Percentage: %0.03
# Value: 10222.0, Count: 1, Percentage: %0.03
# Value: 10227.0, Count: 1, Percentage: %0.03
# Value: 10228.0, Count: 1, Percentage: %0.03
# Value: 10231.0, Count: 1, Percentage: %0.03
# Value: 10236.0, Count: 1, Percentage: %0.03
# Value: 10241.0, Count: 1, Percentage: %0.03
# Value: 10246.0, Count: 2, Percentage: %0.05
# Value: 10249.0, Count: 1, Percentage: %0.03
# Value: 10250.0, Count: 1, Percentage: %0.03
# Value: 10260.0, Count: 1, Percentage: %0.03
# Value: 10262.0, Count: 1, Percentage: %0.03
# Value: 10264.0, Count: 1, Percentage: %0.03
# Value: 10265.0, Count: 1, Percentage: %0.03
# Value: 10267.0, Count: 1, Percentage: %0.03
# Value: 10271.0, Count: 1, Percentage: %0.03
# Value: 10272.0, Count: 2, Percentage: %0.05
# Value: 10286.0, Count: 3, Percentage: %0.08
# Value: 10289.0, Count: 1, Percentage: %0.03
# Value: 10293.0, Count: 1, Percentage: %0.03
# Value: 10296.0, Count: 1, Percentage: %0.03
# Value: 10297.0, Count: 2, Percentage: %0.05
# Value: 10304.0, Count: 1, Percentage: %0.03
# Value: 10309.0, Count: 1, Percentage: %0.03
# Value: 10311.0, Count: 1, Percentage: %0.03
# Value: 10312.0, Count: 1, Percentage: %0.03
# Value: 10318.0, Count: 1, Percentage: %0.03
# Value: 10326.0, Count: 1, Percentage: %0.03
# Value: 10327.0, Count: 1, Percentage: %0.03
# Value: 10335.0, Count: 1, Percentage: %0.03
# Value: 10344.0, Count: 1, Percentage: %0.03
# Value: 10346.0, Count: 1, Percentage: %0.03
# Value: 10349.0, Count: 1, Percentage: %0.03
# Value: 10351.0, Count: 1, Percentage: %0.03
# Value: 10355.0, Count: 1, Percentage: %0.03
# Value: 10359.0, Count: 1, Percentage: %0.03
# Value: 10360.0, Count: 4, Percentage: %0.1
# Value: 10364.0, Count: 1, Percentage: %0.03
# Value: 10365.0, Count: 1, Percentage: %0.03
# Value: 10366.0, Count: 1, Percentage: %0.03
# Value: 10367.0, Count: 2, Percentage: %0.05
# Value: 10369.0, Count: 1, Percentage: %0.03
# Value: 10380.0, Count: 2, Percentage: %0.05
# Value: 10381.0, Count: 1, Percentage: %0.03
# Value: 10382.0, Count: 1, Percentage: %0.03
# Value: 10384.0, Count: 1, Percentage: %0.03
# Value: 10386.0, Count: 3, Percentage: %0.08
# Value: 10387.0, Count: 1, Percentage: %0.03
# Value: 10388.0, Count: 1, Percentage: %0.03
# Value: 10389.0, Count: 1, Percentage: %0.03
# Value: 10390.0, Count: 1, Percentage: %0.03
# Value: 10392.0, Count: 1, Percentage: %0.03
# Value: 10395.0, Count: 2, Percentage: %0.05
# Value: 10398.0, Count: 1, Percentage: %0.03
# Value: 10409.0, Count: 1, Percentage: %0.03
# Value: 10412.0, Count: 1, Percentage: %0.03
# Value: 10413.0, Count: 1, Percentage: %0.03
# Value: 10420.0, Count: 1, Percentage: %0.03
# Value: 10427.0, Count: 3, Percentage: %0.08
# Value: 10440.0, Count: 1, Percentage: %0.03
# Value: 10442.0, Count: 1, Percentage: %0.03
# Value: 10443.0, Count: 2, Percentage: %0.05
# Value: 10445.0, Count: 2, Percentage: %0.05
# Value: 10451.0, Count: 1, Percentage: %0.03
# Value: 10453.0, Count: 2, Percentage: %0.05
# Value: 10457.0, Count: 1, Percentage: %0.03
# Value: 10458.0, Count: 1, Percentage: %0.03
# Value: 10462.0, Count: 1, Percentage: %0.03
# Value: 10463.0, Count: 1, Percentage: %0.03
# Value: 10468.0, Count: 1, Percentage: %0.03
# Value: 10469.0, Count: 2, Percentage: %0.05
# Value: 10470.0, Count: 1, Percentage: %0.03
# Value: 10472.0, Count: 2, Percentage: %0.05
# Value: 10474.0, Count: 2, Percentage: %0.05
# Value: 10475.0, Count: 1, Percentage: %0.03
# Value: 10480.0, Count: 1, Percentage: %0.03
# Value: 10481.0, Count: 1, Percentage: %0.03
# Value: 10482.0, Count: 1, Percentage: %0.03
# Value: 10483.0, Count: 1, Percentage: %0.03
# Value: 10488.0, Count: 1, Percentage: %0.03
# Value: 10491.0, Count: 1, Percentage: %0.03
# Value: 10492.0, Count: 1, Percentage: %0.03
# Value: 10496.0, Count: 1, Percentage: %0.03
# Value: 10497.0, Count: 2, Percentage: %0.05
# Value: 10499.0, Count: 2, Percentage: %0.05
# Value: 10502.0, Count: 1, Percentage: %0.03
# Value: 10509.0, Count: 1, Percentage: %0.03
# Value: 10510.0, Count: 2, Percentage: %0.05
# Value: 10512.0, Count: 1, Percentage: %0.03
# Value: 10513.0, Count: 1, Percentage: %0.03
# Value: 10516.0, Count: 2, Percentage: %0.05
# Value: 10519.0, Count: 1, Percentage: %0.03
# Value: 10523.0, Count: 1, Percentage: %0.03
# Value: 10524.0, Count: 1, Percentage: %0.03
# Value: 10525.0, Count: 1, Percentage: %0.03
# Value: 10527.0, Count: 2, Percentage: %0.05
# Value: 10528.0, Count: 1, Percentage: %0.03
# Value: 10531.0, Count: 1, Percentage: %0.03
# Value: 10533.0, Count: 1, Percentage: %0.03
# Value: 10534.0, Count: 3, Percentage: %0.08
# Value: 10536.0, Count: 3, Percentage: %0.08
# Value: 10538.0, Count: 1, Percentage: %0.03
# Value: 10539.0, Count: 1, Percentage: %0.03
# Value: 10541.0, Count: 1, Percentage: %0.03
# Value: 10546.0, Count: 1, Percentage: %0.03
# Value: 10549.0, Count: 1, Percentage: %0.03
# Value: 10550.0, Count: 2, Percentage: %0.05
# Value: 10554.0, Count: 1, Percentage: %0.03
# Value: 10557.0, Count: 1, Percentage: %0.03
# Value: 10559.0, Count: 2, Percentage: %0.05
# Value: 10560.0, Count: 1, Percentage: %0.03
# Value: 10561.0, Count: 2, Percentage: %0.05
# Value: 10562.0, Count: 1, Percentage: %0.03
# Value: 10563.0, Count: 1, Percentage: %0.03
# Value: 10566.0, Count: 1, Percentage: %0.03
# Value: 10567.0, Count: 1, Percentage: %0.03
# Value: 10570.0, Count: 1, Percentage: %0.03
# Value: 10572.0, Count: 2, Percentage: %0.05
# Value: 10574.0, Count: 3, Percentage: %0.08
# Value: 10576.0, Count: 1, Percentage: %0.03
# Value: 10577.0, Count: 1, Percentage: %0.03
# Value: 10578.0, Count: 1, Percentage: %0.03
# Value: 10579.0, Count: 1, Percentage: %0.03
# Value: 10580.0, Count: 1, Percentage: %0.03
# Value: 10583.0, Count: 1, Percentage: %0.03
# Value: 10584.0, Count: 1, Percentage: %0.03
# Value: 10585.0, Count: 1, Percentage: %0.03
# Value: 10586.0, Count: 1, Percentage: %0.03
# Value: 10587.0, Count: 1, Percentage: %0.03
# Value: 10588.0, Count: 2, Percentage: %0.05
# Value: 10589.0, Count: 3, Percentage: %0.08
# Value: 10590.0, Count: 1, Percentage: %0.03
# Value: 10591.0, Count: 1, Percentage: %0.03
# Value: 10594.0, Count: 2, Percentage: %0.05
# Value: 10595.0, Count: 2, Percentage: %0.05
# Value: 10598.0, Count: 1, Percentage: %0.03
# Value: 10600.0, Count: 2, Percentage: %0.05
# Value: 10604.0, Count: 3, Percentage: %0.08
# Value: 10608.0, Count: 1, Percentage: %0.03
# Value: 10610.0, Count: 1, Percentage: %0.03
# Value: 10611.0, Count: 1, Percentage: %0.03
# Value: 10612.0, Count: 1, Percentage: %0.03
# Value: 10613.0, Count: 1, Percentage: %0.03
# Value: 10617.0, Count: 1, Percentage: %0.03
# Value: 10620.0, Count: 1, Percentage: %0.03
# Value: 10622.0, Count: 1, Percentage: %0.03
# Value: 10623.0, Count: 1, Percentage: %0.03
# Value: 10627.0, Count: 1, Percentage: %0.03
# Value: 10628.0, Count: 1, Percentage: %0.03
# Value: 10629.0, Count: 1, Percentage: %0.03
# Value: 10632.0, Count: 1, Percentage: %0.03
# Value: 10634.0, Count: 1, Percentage: %0.03
# Value: 10638.0, Count: 2, Percentage: %0.05
# Value: 10640.0, Count: 1, Percentage: %0.03
# Value: 10645.0, Count: 1, Percentage: %0.03
# Value: 10647.0, Count: 1, Percentage: %0.03
# Value: 10650.0, Count: 1, Percentage: %0.03
# Value: 10651.0, Count: 1, Percentage: %0.03
# Value: 10655.0, Count: 1, Percentage: %0.03
# Value: 10657.0, Count: 2, Percentage: %0.05
# Value: 10662.0, Count: 3, Percentage: %0.08
# Value: 10663.0, Count: 1, Percentage: %0.03
# Value: 10664.0, Count: 1, Percentage: %0.03
# Value: 10665.0, Count: 1, Percentage: %0.03
# Value: 10666.0, Count: 1, Percentage: %0.03
# Value: 10667.0, Count: 2, Percentage: %0.05
# Value: 10669.0, Count: 2, Percentage: %0.05
# Value: 10673.0, Count: 1, Percentage: %0.03
# Value: 10680.0, Count: 1, Percentage: %0.03
# Value: 10681.0, Count: 1, Percentage: %0.03
# Value: 10683.0, Count: 1, Percentage: %0.03
# Value: 10685.0, Count: 2, Percentage: %0.05
# Value: 10689.0, Count: 1, Percentage: %0.03
# Value: 10690.0, Count: 2, Percentage: %0.05
# Value: 10691.0, Count: 1, Percentage: %0.03
# Value: 10692.0, Count: 1, Percentage: %0.03
# Value: 10693.0, Count: 1, Percentage: %0.03
# Value: 10694.0, Count: 1, Percentage: %0.03
# Value: 10695.0, Count: 1, Percentage: %0.03
# Value: 10696.0, Count: 1, Percentage: %0.03
# Value: 10697.0, Count: 2, Percentage: %0.05
# Value: 10698.0, Count: 1, Percentage: %0.03
# Value: 10702.0, Count: 1, Percentage: %0.03
# Value: 10705.0, Count: 1, Percentage: %0.03
# Value: 10712.0, Count: 1, Percentage: %0.03
# Value: 10713.0, Count: 1, Percentage: %0.03
# Value: 10719.0, Count: 2, Percentage: %0.05
# Value: 10723.0, Count: 1, Percentage: %0.03
# Value: 10724.0, Count: 1, Percentage: %0.03
# Value: 10725.0, Count: 1, Percentage: %0.03
# Value: 10727.0, Count: 4, Percentage: %0.1
# Value: 10728.0, Count: 1, Percentage: %0.03
# Value: 10729.0, Count: 1, Percentage: %0.03
# Value: 10731.0, Count: 1, Percentage: %0.03
# Value: 10733.0, Count: 1, Percentage: %0.03
# Value: 10735.0, Count: 1, Percentage: %0.03
# Value: 10736.0, Count: 2, Percentage: %0.05
# Value: 10737.0, Count: 2, Percentage: %0.05
# Value: 10740.0, Count: 1, Percentage: %0.03
# Value: 10745.0, Count: 1, Percentage: %0.03
# Value: 10746.0, Count: 1, Percentage: %0.03
# Value: 10749.0, Count: 1, Percentage: %0.03
# Value: 10756.0, Count: 1, Percentage: %0.03
# Value: 10759.0, Count: 1, Percentage: %0.03
# Value: 10760.0, Count: 1, Percentage: %0.03
# Value: 10761.0, Count: 1, Percentage: %0.03
# Value: 10763.0, Count: 2, Percentage: %0.05
# Value: 10765.0, Count: 1, Percentage: %0.03
# Value: 10767.0, Count: 3, Percentage: %0.08
# Value: 10770.0, Count: 1, Percentage: %0.03
# Value: 10773.0, Count: 2, Percentage: %0.05
# Value: 10774.0, Count: 2, Percentage: %0.05
# Value: 10775.0, Count: 1, Percentage: %0.03
# Value: 10777.0, Count: 1, Percentage: %0.03
# Value: 10780.0, Count: 2, Percentage: %0.05
# Value: 10781.0, Count: 1, Percentage: %0.03
# Value: 10782.0, Count: 1, Percentage: %0.03
# Value: 10783.0, Count: 1, Percentage: %0.03
# Value: 10784.0, Count: 1, Percentage: %0.03
# Value: 10785.0, Count: 2, Percentage: %0.05
# Value: 10786.0, Count: 1, Percentage: %0.03
# Value: 10787.0, Count: 2, Percentage: %0.05
# Value: 10788.0, Count: 2, Percentage: %0.05
# Value: 10789.0, Count: 1, Percentage: %0.03
# Value: 10792.0, Count: 1, Percentage: %0.03
# Value: 10795.0, Count: 1, Percentage: %0.03
# Value: 10796.0, Count: 3, Percentage: %0.08
# Value: 10798.0, Count: 1, Percentage: %0.03
# Value: 10800.0, Count: 1, Percentage: %0.03
# Value: 10802.0, Count: 1, Percentage: %0.03
# Value: 10803.0, Count: 2, Percentage: %0.05
# Value: 10805.0, Count: 1, Percentage: %0.03
# Value: 10806.0, Count: 1, Percentage: %0.03
# Value: 10809.0, Count: 1, Percentage: %0.03
# Value: 10810.0, Count: 2, Percentage: %0.05
# Value: 10811.0, Count: 1, Percentage: %0.03
# Value: 10815.0, Count: 2, Percentage: %0.05
# Value: 10816.0, Count: 1, Percentage: %0.03
# Value: 10817.0, Count: 1, Percentage: %0.03
# Value: 10818.0, Count: 1, Percentage: %0.03
# Value: 10819.0, Count: 2, Percentage: %0.05
# Value: 10820.0, Count: 1, Percentage: %0.03
# Value: 10821.0, Count: 2, Percentage: %0.05
# Value: 10824.0, Count: 1, Percentage: %0.03
# Value: 10826.0, Count: 1, Percentage: %0.03
# Value: 10828.0, Count: 2, Percentage: %0.05
# Value: 10829.0, Count: 1, Percentage: %0.03
# Value: 10831.0, Count: 1, Percentage: %0.03
# Value: 10832.0, Count: 1, Percentage: %0.03
# Value: 10833.0, Count: 1, Percentage: %0.03
# Value: 10838.0, Count: 1, Percentage: %0.03
# Value: 10841.0, Count: 3, Percentage: %0.08
# Value: 10842.0, Count: 3, Percentage: %0.08
# Value: 10843.0, Count: 1, Percentage: %0.03
# Value: 10844.0, Count: 1, Percentage: %0.03
# Value: 10846.0, Count: 1, Percentage: %0.03
# Value: 10847.0, Count: 3, Percentage: %0.08
# Value: 10849.0, Count: 1, Percentage: %0.03
# Value: 10851.0, Count: 1, Percentage: %0.03
# Value: 10852.0, Count: 2, Percentage: %0.05
# Value: 10854.0, Count: 1, Percentage: %0.03
# Value: 10855.0, Count: 1, Percentage: %0.03
# Value: 10858.0, Count: 1, Percentage: %0.03
# Value: 10860.0, Count: 1, Percentage: %0.03
# Value: 10862.0, Count: 2, Percentage: %0.05
# Value: 10863.0, Count: 1, Percentage: %0.03
# Value: 10864.0, Count: 1, Percentage: %0.03
# Value: 10866.0, Count: 1, Percentage: %0.03
# Value: 10870.0, Count: 2, Percentage: %0.05
# Value: 10871.0, Count: 2, Percentage: %0.05
# Value: 10873.0, Count: 3, Percentage: %0.08
# Value: 10874.0, Count: 1, Percentage: %0.03
# Value: 10875.0, Count: 1, Percentage: %0.03
# Value: 10877.0, Count: 1, Percentage: %0.03
# Value: 10878.0, Count: 2, Percentage: %0.05
# Value: 10879.0, Count: 1, Percentage: %0.03
# Value: 10880.0, Count: 1, Percentage: %0.03
# Value: 10882.0, Count: 1, Percentage: %0.03
# Value: 10884.0, Count: 1, Percentage: %0.03
# Value: 10885.0, Count: 1, Percentage: %0.03
# Value: 10886.0, Count: 1, Percentage: %0.03
# Value: 10889.0, Count: 1, Percentage: %0.03
# Value: 10891.0, Count: 1, Percentage: %0.03
# Value: 10895.0, Count: 1, Percentage: %0.03
# Value: 10896.0, Count: 1, Percentage: %0.03
# Value: 10897.0, Count: 1, Percentage: %0.03
# Value: 10898.0, Count: 1, Percentage: %0.03
# Value: 10899.0, Count: 1, Percentage: %0.03
# Value: 10900.0, Count: 1, Percentage: %0.03
# Value: 10901.0, Count: 1, Percentage: %0.03
# Value: 10903.0, Count: 1, Percentage: %0.03
# Value: 10908.0, Count: 1, Percentage: %0.03
# Value: 10910.0, Count: 2, Percentage: %0.05
# Value: 10911.0, Count: 1, Percentage: %0.03
# Value: 10912.0, Count: 1, Percentage: %0.03
# Value: 10913.0, Count: 1, Percentage: %0.03
# Value: 10915.0, Count: 1, Percentage: %0.03
# Value: 10916.0, Count: 1, Percentage: %0.03
# Value: 10917.0, Count: 1, Percentage: %0.03
# Value: 10918.0, Count: 1, Percentage: %0.03
# Value: 10919.0, Count: 3, Percentage: %0.08
# Value: 10921.0, Count: 1, Percentage: %0.03
# Value: 10924.0, Count: 1, Percentage: %0.03
# Value: 10925.0, Count: 2, Percentage: %0.05
# Value: 10926.0, Count: 1, Percentage: %0.03
# Value: 10928.0, Count: 2, Percentage: %0.05
# Value: 10937.0, Count: 2, Percentage: %0.05
# Value: 10940.0, Count: 1, Percentage: %0.03
# Value: 10941.0, Count: 1, Percentage: %0.03
# Value: 10943.0, Count: 2, Percentage: %0.05
# Value: 10948.0, Count: 1, Percentage: %0.03
# Value: 10949.0, Count: 3, Percentage: %0.08
# Value: 10950.0, Count: 1, Percentage: %0.03
# Value: 10951.0, Count: 3, Percentage: %0.08
# Value: 10952.0, Count: 1, Percentage: %0.03
# Value: 10955.0, Count: 1, Percentage: %0.03
# Value: 10956.0, Count: 1, Percentage: %0.03
# Value: 10958.0, Count: 1, Percentage: %0.03
# Value: 10959.0, Count: 1, Percentage: %0.03
# Value: 10961.0, Count: 1, Percentage: %0.03
# Value: 10962.0, Count: 2, Percentage: %0.05
# Value: 10964.0, Count: 2, Percentage: %0.05
# Value: 10965.0, Count: 3, Percentage: %0.08
# Value: 10968.0, Count: 1, Percentage: %0.03
# Value: 10971.0, Count: 1, Percentage: %0.03
# Value: 10972.0, Count: 1, Percentage: %0.03
# Value: 10973.0, Count: 2, Percentage: %0.05
# Value: 10974.0, Count: 1, Percentage: %0.03
# Value: 10975.0, Count: 2, Percentage: %0.05
# Value: 10979.0, Count: 1, Percentage: %0.03
# Value: 10980.0, Count: 1, Percentage: %0.03
# Value: 10982.0, Count: 2, Percentage: %0.05
# Value: 10983.0, Count: 1, Percentage: %0.03
# Value: 10984.0, Count: 2, Percentage: %0.05
# Value: 10985.0, Count: 1, Percentage: %0.03
# Value: 10986.0, Count: 1, Percentage: %0.03
# Value: 10989.0, Count: 1, Percentage: %0.03
# Value: 10993.0, Count: 2, Percentage: %0.05
# Value: 10997.0, Count: 1, Percentage: %0.03
# Value: 11000.0, Count: 1, Percentage: %0.03
# Value: 11001.0, Count: 1, Percentage: %0.03
# Value: 11003.0, Count: 1, Percentage: %0.03
# Value: 11004.0, Count: 1, Percentage: %0.03
# Value: 11011.0, Count: 1, Percentage: %0.03
# Value: 11012.0, Count: 1, Percentage: %0.03
# Value: 11014.0, Count: 2, Percentage: %0.05
# Value: 11016.0, Count: 3, Percentage: %0.08
# Value: 11017.0, Count: 1, Percentage: %0.03
# Value: 11022.0, Count: 1, Percentage: %0.03
# Value: 11023.0, Count: 1, Percentage: %0.03
# Value: 11024.0, Count: 1, Percentage: %0.03
# Value: 11026.0, Count: 1, Percentage: %0.03
# Value: 11027.0, Count: 1, Percentage: %0.03
# Value: 11029.0, Count: 1, Percentage: %0.03
# Value: 11030.0, Count: 1, Percentage: %0.03
# Value: 11031.0, Count: 2, Percentage: %0.05
# Value: 11034.0, Count: 1, Percentage: %0.03
# Value: 11036.0, Count: 1, Percentage: %0.03
# Value: 11042.0, Count: 2, Percentage: %0.05
# Value: 11044.0, Count: 1, Percentage: %0.03
# Value: 11046.0, Count: 1, Percentage: %0.03
# Value: 11048.0, Count: 1, Percentage: %0.03
# Value: 11049.0, Count: 1, Percentage: %0.03
# Value: 11050.0, Count: 2, Percentage: %0.05
# Value: 11051.0, Count: 2, Percentage: %0.05
# Value: 11052.0, Count: 1, Percentage: %0.03
# Value: 11062.0, Count: 2, Percentage: %0.05
# Value: 11063.0, Count: 2, Percentage: %0.05
# Value: 11065.0, Count: 1, Percentage: %0.03
# Value: 11068.0, Count: 2, Percentage: %0.05
# Value: 11069.0, Count: 1, Percentage: %0.03
# Value: 11070.0, Count: 2, Percentage: %0.05
# Value: 11071.0, Count: 1, Percentage: %0.03
# Value: 11072.0, Count: 1, Percentage: %0.03
# Value: 11073.0, Count: 1, Percentage: %0.03
# Value: 11074.0, Count: 2, Percentage: %0.05
# Value: 11075.0, Count: 2, Percentage: %0.05
# Value: 11077.0, Count: 2, Percentage: %0.05
# Value: 11080.0, Count: 2, Percentage: %0.05
# Value: 11081.0, Count: 1, Percentage: %0.03
# Value: 11083.0, Count: 1, Percentage: %0.03
# Value: 11084.0, Count: 1, Percentage: %0.03
# Value: 11087.0, Count: 1, Percentage: %0.03
# Value: 11088.0, Count: 3, Percentage: %0.08
# Value: 11089.0, Count: 1, Percentage: %0.03
# Value: 11090.0, Count: 1, Percentage: %0.03
# Value: 11091.0, Count: 1, Percentage: %0.03
# Value: 11095.0, Count: 1, Percentage: %0.03
# Value: 11097.0, Count: 2, Percentage: %0.05
# Value: 11099.0, Count: 1, Percentage: %0.03
# Value: 11100.0, Count: 1, Percentage: %0.03
# Value: 11101.0, Count: 1, Percentage: %0.03
# Value: 11102.0, Count: 2, Percentage: %0.05
# Value: 11104.0, Count: 1, Percentage: %0.03
# Value: 11106.0, Count: 1, Percentage: %0.03
# Value: 11107.0, Count: 1, Percentage: %0.03
# Value: 11108.0, Count: 2, Percentage: %0.05
# Value: 11111.0, Count: 1, Percentage: %0.03
# Value: 11112.0, Count: 1, Percentage: %0.03
# Value: 11114.0, Count: 1, Percentage: %0.03
# Value: 11115.0, Count: 1, Percentage: %0.03
# Value: 11116.0, Count: 2, Percentage: %0.05
# Value: 11119.0, Count: 3, Percentage: %0.08
# Value: 11122.0, Count: 1, Percentage: %0.03
# Value: 11123.0, Count: 1, Percentage: %0.03
# Value: 11125.0, Count: 1, Percentage: %0.03
# Value: 11128.0, Count: 2, Percentage: %0.05
# Value: 11130.0, Count: 1, Percentage: %0.03
# Value: 11133.0, Count: 1, Percentage: %0.03
# Value: 11136.0, Count: 3, Percentage: %0.08
# Value: 11139.0, Count: 2, Percentage: %0.05
# Value: 11140.0, Count: 2, Percentage: %0.05
# Value: 11141.0, Count: 1, Percentage: %0.03
# Value: 11144.0, Count: 2, Percentage: %0.05
# Value: 11145.0, Count: 2, Percentage: %0.05
# Value: 11146.0, Count: 1, Percentage: %0.03
# Value: 11147.0, Count: 1, Percentage: %0.03
# Value: 11149.0, Count: 2, Percentage: %0.05
# Value: 11150.0, Count: 1, Percentage: %0.03
# Value: 11151.0, Count: 1, Percentage: %0.03
# Value: 11153.0, Count: 1, Percentage: %0.03
# Value: 11154.0, Count: 1, Percentage: %0.03
# Value: 11161.0, Count: 2, Percentage: %0.05
# Value: 11165.0, Count: 1, Percentage: %0.03
# Value: 11166.0, Count: 2, Percentage: %0.05
# Value: 11168.0, Count: 1, Percentage: %0.03
# Value: 11169.0, Count: 1, Percentage: %0.03
# Value: 11173.0, Count: 1, Percentage: %0.03
# Value: 11174.0, Count: 1, Percentage: %0.03
# Value: 11176.0, Count: 2, Percentage: %0.05
# Value: 11178.0, Count: 1, Percentage: %0.03
# Value: 11179.0, Count: 1, Percentage: %0.03
# Value: 11180.0, Count: 3, Percentage: %0.08
# Value: 11181.0, Count: 1, Percentage: %0.03
# Value: 11182.0, Count: 1, Percentage: %0.03
# Value: 11183.0, Count: 1, Percentage: %0.03
# Value: 11184.0, Count: 2, Percentage: %0.05
# Value: 11185.0, Count: 1, Percentage: %0.03
# Value: 11186.0, Count: 1, Percentage: %0.03
# Value: 11189.0, Count: 1, Percentage: %0.03
# Value: 11191.0, Count: 2, Percentage: %0.05
# Value: 11197.0, Count: 1, Percentage: %0.03
# Value: 11199.0, Count: 1, Percentage: %0.03
# Value: 11200.0, Count: 1, Percentage: %0.03
# Value: 11201.0, Count: 2, Percentage: %0.05
# Value: 11203.0, Count: 1, Percentage: %0.03
# Value: 11206.0, Count: 1, Percentage: %0.03
# Value: 11210.0, Count: 1, Percentage: %0.03
# Value: 11211.0, Count: 1, Percentage: %0.03
# Value: 11212.0, Count: 1, Percentage: %0.03
# Value: 11215.0, Count: 1, Percentage: %0.03
# Value: 11217.0, Count: 1, Percentage: %0.03
# Value: 11219.0, Count: 1, Percentage: %0.03
# Value: 11220.0, Count: 1, Percentage: %0.03
# Value: 11221.0, Count: 1, Percentage: %0.03
# Value: 11224.0, Count: 1, Percentage: %0.03
# Value: 11226.0, Count: 3, Percentage: %0.08
# Value: 11227.0, Count: 1, Percentage: %0.03
# Value: 11230.0, Count: 1, Percentage: %0.03
# Value: 11231.0, Count: 1, Percentage: %0.03
# Value: 11232.0, Count: 1, Percentage: %0.03
# Value: 11234.0, Count: 1, Percentage: %0.03
# Value: 11236.0, Count: 1, Percentage: %0.03
# Value: 11237.0, Count: 1, Percentage: %0.03
# Value: 11239.0, Count: 1, Percentage: %0.03
# Value: 11240.0, Count: 2, Percentage: %0.05
# Value: 11241.0, Count: 1, Percentage: %0.03
# Value: 11242.0, Count: 2, Percentage: %0.05
# Value: 11243.0, Count: 2, Percentage: %0.05
# Value: 11245.0, Count: 1, Percentage: %0.03
# Value: 11247.0, Count: 2, Percentage: %0.05
# Value: 11248.0, Count: 1, Percentage: %0.03
# Value: 11249.0, Count: 3, Percentage: %0.08
# Value: 11251.0, Count: 2, Percentage: %0.05
# Value: 11253.0, Count: 1, Percentage: %0.03
# Value: 11255.0, Count: 1, Percentage: %0.03
# Value: 11259.0, Count: 1, Percentage: %0.03
# Value: 11264.0, Count: 2, Percentage: %0.05
# Value: 11266.0, Count: 1, Percentage: %0.03
# Value: 11267.0, Count: 1, Percentage: %0.03
# Value: 11268.0, Count: 1, Percentage: %0.03
# Value: 11270.0, Count: 1, Percentage: %0.03
# Value: 11271.0, Count: 1, Percentage: %0.03
# Value: 11273.0, Count: 1, Percentage: %0.03
# Value: 11274.0, Count: 3, Percentage: %0.08
# Value: 11277.0, Count: 1, Percentage: %0.03
# Value: 11278.0, Count: 2, Percentage: %0.05
# Value: 11279.0, Count: 1, Percentage: %0.03
# Value: 11280.0, Count: 2, Percentage: %0.05
# Value: 11281.0, Count: 2, Percentage: %0.05
# Value: 11285.0, Count: 1, Percentage: %0.03
# Value: 11287.0, Count: 3, Percentage: %0.08
# Value: 11288.0, Count: 1, Percentage: %0.03
# Value: 11290.0, Count: 1, Percentage: %0.03
# Value: 11291.0, Count: 1, Percentage: %0.03
# Value: 11293.0, Count: 1, Percentage: %0.03
# Value: 11295.0, Count: 2, Percentage: %0.05
# Value: 11296.0, Count: 1, Percentage: %0.03
# Value: 11297.0, Count: 2, Percentage: %0.05
# Value: 11298.0, Count: 1, Percentage: %0.03
# Value: 11299.0, Count: 2, Percentage: %0.05
# Value: 11300.0, Count: 1, Percentage: %0.03
# Value: 11302.0, Count: 2, Percentage: %0.05
# Value: 11303.0, Count: 3, Percentage: %0.08
# Value: 11304.0, Count: 1, Percentage: %0.03
# Value: 11307.0, Count: 3, Percentage: %0.08
# Value: 11309.0, Count: 1, Percentage: %0.03
# Value: 11310.0, Count: 1, Percentage: %0.03
# Value: 11312.0, Count: 1, Percentage: %0.03
# Value: 11314.0, Count: 1, Percentage: %0.03
# Value: 11316.0, Count: 2, Percentage: %0.05
# Value: 11317.0, Count: 1, Percentage: %0.03
# Value: 11318.0, Count: 1, Percentage: %0.03
# Value: 11319.0, Count: 1, Percentage: %0.03
# Value: 11320.0, Count: 1, Percentage: %0.03
# Value: 11321.0, Count: 1, Percentage: %0.03
# Value: 11322.0, Count: 4, Percentage: %0.1
# Value: 11323.0, Count: 2, Percentage: %0.05
# Value: 11327.0, Count: 3, Percentage: %0.08
# Value: 11329.0, Count: 2, Percentage: %0.05
# Value: 11332.0, Count: 3, Percentage: %0.08
# Value: 11334.0, Count: 1, Percentage: %0.03
# Value: 11335.0, Count: 1, Percentage: %0.03
# Value: 11337.0, Count: 3, Percentage: %0.08
# Value: 11338.0, Count: 1, Percentage: %0.03
# Value: 11339.0, Count: 2, Percentage: %0.05
# Value: 11340.0, Count: 1, Percentage: %0.03
# Value: 11341.0, Count: 1, Percentage: %0.03
# Value: 11342.0, Count: 2, Percentage: %0.05
# Value: 11343.0, Count: 2, Percentage: %0.05
# Value: 11350.0, Count: 2, Percentage: %0.05
# Value: 11351.0, Count: 1, Percentage: %0.03
# Value: 11352.0, Count: 1, Percentage: %0.03
# Value: 11353.0, Count: 3, Percentage: %0.08
# Value: 11354.0, Count: 1, Percentage: %0.03
# Value: 11355.0, Count: 1, Percentage: %0.03
# Value: 11357.0, Count: 1, Percentage: %0.03
# Value: 11358.0, Count: 2, Percentage: %0.05
# Value: 11359.0, Count: 3, Percentage: %0.08
# Value: 11363.0, Count: 3, Percentage: %0.08
# Value: 11364.0, Count: 1, Percentage: %0.03
# Value: 11365.0, Count: 1, Percentage: %0.03
# Value: 11366.0, Count: 2, Percentage: %0.05
# Value: 11370.0, Count: 1, Percentage: %0.03
# Value: 11372.0, Count: 1, Percentage: %0.03
# Value: 11377.0, Count: 3, Percentage: %0.08
# Value: 11378.0, Count: 1, Percentage: %0.03
# Value: 11379.0, Count: 1, Percentage: %0.03
# Value: 11380.0, Count: 1, Percentage: %0.03
# Value: 11381.0, Count: 1, Percentage: %0.03
# Value: 11382.0, Count: 1, Percentage: %0.03
# Value: 11385.0, Count: 2, Percentage: %0.05
# Value: 11386.0, Count: 2, Percentage: %0.05
# Value: 11387.0, Count: 1, Percentage: %0.03
# Value: 11391.0, Count: 1, Percentage: %0.03
# Value: 11392.0, Count: 3, Percentage: %0.08
# Value: 11393.0, Count: 2, Percentage: %0.05
# Value: 11394.0, Count: 1, Percentage: %0.03
# Value: 11395.0, Count: 1, Percentage: %0.03
# Value: 11396.0, Count: 2, Percentage: %0.05
# Value: 11397.0, Count: 1, Percentage: %0.03
# Value: 11398.0, Count: 1, Percentage: %0.03
# Value: 11410.0, Count: 1, Percentage: %0.03
# Value: 11411.0, Count: 2, Percentage: %0.05
# Value: 11413.0, Count: 1, Percentage: %0.03
# Value: 11415.0, Count: 3, Percentage: %0.08
# Value: 11417.0, Count: 1, Percentage: %0.03
# Value: 11418.0, Count: 1, Percentage: %0.03
# Value: 11419.0, Count: 1, Percentage: %0.03
# Value: 11421.0, Count: 1, Percentage: %0.03
# Value: 11422.0, Count: 5, Percentage: %0.13
# Value: 11423.0, Count: 1, Percentage: %0.03
# Value: 11428.0, Count: 1, Percentage: %0.03
# Value: 11432.0, Count: 2, Percentage: %0.05
# Value: 11433.0, Count: 2, Percentage: %0.05
# Value: 11434.0, Count: 1, Percentage: %0.03
# Value: 11435.0, Count: 1, Percentage: %0.03
# Value: 11437.0, Count: 1, Percentage: %0.03
# Value: 11438.0, Count: 1, Percentage: %0.03
# Value: 11440.0, Count: 2, Percentage: %0.05
# Value: 11441.0, Count: 1, Percentage: %0.03
# Value: 11443.0, Count: 2, Percentage: %0.05
# Value: 11444.0, Count: 1, Percentage: %0.03
# Value: 11445.0, Count: 1, Percentage: %0.03
# Value: 11447.0, Count: 3, Percentage: %0.08
# Value: 11449.0, Count: 1, Percentage: %0.03
# Value: 11451.0, Count: 1, Percentage: %0.03
# Value: 11454.0, Count: 2, Percentage: %0.05
# Value: 11455.0, Count: 1, Percentage: %0.03
# Value: 11458.0, Count: 2, Percentage: %0.05
# Value: 11459.0, Count: 1, Percentage: %0.03
# Value: 11462.0, Count: 3, Percentage: %0.08
# Value: 11465.0, Count: 4, Percentage: %0.1
# Value: 11467.0, Count: 1, Percentage: %0.03
# Value: 11469.0, Count: 1, Percentage: %0.03
# Value: 11470.0, Count: 3, Percentage: %0.08
# Value: 11472.0, Count: 1, Percentage: %0.03
# Value: 11475.0, Count: 1, Percentage: %0.03
# Value: 11476.0, Count: 1, Percentage: %0.03
# Value: 11479.0, Count: 2, Percentage: %0.05
# Value: 11480.0, Count: 3, Percentage: %0.08
# Value: 11481.0, Count: 1, Percentage: %0.03
# Value: 11483.0, Count: 2, Percentage: %0.05
# Value: 11485.0, Count: 3, Percentage: %0.08
# Value: 11486.0, Count: 1, Percentage: %0.03
# Value: 11487.0, Count: 1, Percentage: %0.03
# Value: 11488.0, Count: 1, Percentage: %0.03
# Value: 11489.0, Count: 2, Percentage: %0.05
# Value: 11490.0, Count: 3, Percentage: %0.08
# Value: 11491.0, Count: 1, Percentage: %0.03
# Value: 11492.0, Count: 1, Percentage: %0.03
# Value: 11493.0, Count: 1, Percentage: %0.03
# Value: 11494.0, Count: 1, Percentage: %0.03
# Value: 11496.0, Count: 1, Percentage: %0.03
# Value: 11497.0, Count: 1, Percentage: %0.03
# Value: 11500.0, Count: 2, Percentage: %0.05
# Value: 11501.0, Count: 2, Percentage: %0.05
# Value: 11502.0, Count: 4, Percentage: %0.1
# Value: 11504.0, Count: 1, Percentage: %0.03
# Value: 11505.0, Count: 1, Percentage: %0.03
# Value: 11506.0, Count: 2, Percentage: %0.05
# Value: 11508.0, Count: 1, Percentage: %0.03
# Value: 11509.0, Count: 1, Percentage: %0.03
# Value: 11510.0, Count: 1, Percentage: %0.03
# Value: 11511.0, Count: 2, Percentage: %0.05
# Value: 11512.0, Count: 2, Percentage: %0.05
# Value: 11513.0, Count: 1, Percentage: %0.03
# Value: 11515.0, Count: 1, Percentage: %0.03
# Value: 11518.0, Count: 1, Percentage: %0.03
# Value: 11521.0, Count: 1, Percentage: %0.03
# Value: 11523.0, Count: 1, Percentage: %0.03
# Value: 11525.0, Count: 2, Percentage: %0.05
# Value: 11528.0, Count: 1, Percentage: %0.03
# Value: 11529.0, Count: 1, Percentage: %0.03
# Value: 11530.0, Count: 2, Percentage: %0.05
# Value: 11531.0, Count: 1, Percentage: %0.03
# Value: 11532.0, Count: 1, Percentage: %0.03
# Value: 11533.0, Count: 1, Percentage: %0.03
# Value: 11535.0, Count: 1, Percentage: %0.03
# Value: 11536.0, Count: 1, Percentage: %0.03
# Value: 11537.0, Count: 1, Percentage: %0.03
# Value: 11538.0, Count: 2, Percentage: %0.05
# Value: 11539.0, Count: 2, Percentage: %0.05
# Value: 11540.0, Count: 2, Percentage: %0.05
# Value: 11542.0, Count: 2, Percentage: %0.05
# Value: 11543.0, Count: 3, Percentage: %0.08
# Value: 11544.0, Count: 1, Percentage: %0.03
# Value: 11545.0, Count: 3, Percentage: %0.08
# Value: 11546.0, Count: 2, Percentage: %0.05
# Value: 11548.0, Count: 1, Percentage: %0.03
# Value: 11549.0, Count: 3, Percentage: %0.08
# Value: 11550.0, Count: 3, Percentage: %0.08
# Value: 11552.0, Count: 1, Percentage: %0.03
# Value: 11553.0, Count: 3, Percentage: %0.08
# Value: 11559.0, Count: 2, Percentage: %0.05
# Value: 11562.0, Count: 1, Percentage: %0.03
# Value: 11564.0, Count: 1, Percentage: %0.03
# Value: 11565.0, Count: 1, Percentage: %0.03
# Value: 11568.0, Count: 2, Percentage: %0.05
# Value: 11569.0, Count: 1, Percentage: %0.03
# Value: 11571.0, Count: 1, Percentage: %0.03
# Value: 11572.0, Count: 1, Percentage: %0.03
# Value: 11573.0, Count: 2, Percentage: %0.05
# Value: 11577.0, Count: 2, Percentage: %0.05
# Value: 11578.0, Count: 1, Percentage: %0.03
# Value: 11580.0, Count: 1, Percentage: %0.03
# Value: 11584.0, Count: 2, Percentage: %0.05
# Value: 11585.0, Count: 1, Percentage: %0.03
# Value: 11587.0, Count: 1, Percentage: %0.03
# Value: 11588.0, Count: 1, Percentage: %0.03
# Value: 11589.0, Count: 1, Percentage: %0.03
# Value: 11590.0, Count: 1, Percentage: %0.03
# Value: 11592.0, Count: 2, Percentage: %0.05
# Value: 11593.0, Count: 2, Percentage: %0.05
# Value: 11594.0, Count: 1, Percentage: %0.03
# Value: 11597.0, Count: 1, Percentage: %0.03
# Value: 11599.0, Count: 2, Percentage: %0.05
# Value: 11601.0, Count: 3, Percentage: %0.08
# Value: 11603.0, Count: 1, Percentage: %0.03
# Value: 11604.0, Count: 1, Percentage: %0.03
# Value: 11605.0, Count: 2, Percentage: %0.05
# Value: 11606.0, Count: 1, Percentage: %0.03
# Value: 11607.0, Count: 1, Percentage: %0.03
# Value: 11611.0, Count: 1, Percentage: %0.03
# Value: 11614.0, Count: 2, Percentage: %0.05
# Value: 11617.0, Count: 1, Percentage: %0.03
# Value: 11618.0, Count: 1, Percentage: %0.03
# Value: 11619.0, Count: 2, Percentage: %0.05
# Value: 11621.0, Count: 2, Percentage: %0.05
# Value: 11622.0, Count: 2, Percentage: %0.05
# Value: 11623.0, Count: 2, Percentage: %0.05
# Value: 11624.0, Count: 1, Percentage: %0.03
# Value: 11625.0, Count: 3, Percentage: %0.08
# Value: 11626.0, Count: 2, Percentage: %0.05
# Value: 11630.0, Count: 1, Percentage: %0.03
# Value: 11632.0, Count: 1, Percentage: %0.03
# Value: 11634.0, Count: 1, Percentage: %0.03
# Value: 11635.0, Count: 2, Percentage: %0.05
# Value: 11638.0, Count: 1, Percentage: %0.03
# Value: 11639.0, Count: 3, Percentage: %0.08
# Value: 11642.0, Count: 1, Percentage: %0.03
# Value: 11644.0, Count: 1, Percentage: %0.03
# Value: 11646.0, Count: 1, Percentage: %0.03
# Value: 11652.0, Count: 2, Percentage: %0.05
# Value: 11656.0, Count: 1, Percentage: %0.03
# Value: 11657.0, Count: 1, Percentage: %0.03
# Value: 11658.0, Count: 2, Percentage: %0.05
# Value: 11659.0, Count: 3, Percentage: %0.08
# Value: 11660.0, Count: 1, Percentage: %0.03
# Value: 11661.0, Count: 1, Percentage: %0.03
# Value: 11665.0, Count: 2, Percentage: %0.05
# Value: 11667.0, Count: 1, Percentage: %0.03
# Value: 11669.0, Count: 2, Percentage: %0.05
# Value: 11670.0, Count: 1, Percentage: %0.03
# Value: 11671.0, Count: 2, Percentage: %0.05
# Value: 11672.0, Count: 2, Percentage: %0.05
# Value: 11674.0, Count: 1, Percentage: %0.03
# Value: 11675.0, Count: 1, Percentage: %0.03
# Value: 11678.0, Count: 1, Percentage: %0.03
# Value: 11679.0, Count: 2, Percentage: %0.05
# Value: 11681.0, Count: 2, Percentage: %0.05
# Value: 11682.0, Count: 2, Percentage: %0.05
# Value: 11686.0, Count: 2, Percentage: %0.05
# Value: 11689.0, Count: 2, Percentage: %0.05
# Value: 11690.0, Count: 1, Percentage: %0.03
# Value: 11691.0, Count: 1, Percentage: %0.03
# Value: 11693.0, Count: 2, Percentage: %0.05
# Value: 11694.0, Count: 2, Percentage: %0.05
# Value: 11695.0, Count: 1, Percentage: %0.03
# Value: 11696.0, Count: 1, Percentage: %0.03
# Value: 11697.0, Count: 1, Percentage: %0.03
# Value: 11699.0, Count: 1, Percentage: %0.03
# Value: 11700.0, Count: 1, Percentage: %0.03
# Value: 11701.0, Count: 1, Percentage: %0.03
# Value: 11702.0, Count: 1, Percentage: %0.03
# Value: 11703.0, Count: 1, Percentage: %0.03
# Value: 11706.0, Count: 2, Percentage: %0.05
# Value: 11708.0, Count: 2, Percentage: %0.05
# Value: 11710.0, Count: 2, Percentage: %0.05
# Value: 11711.0, Count: 2, Percentage: %0.05
# Value: 11714.0, Count: 1, Percentage: %0.03
# Value: 11715.0, Count: 3, Percentage: %0.08
# Value: 11717.0, Count: 2, Percentage: %0.05
# Value: 11718.0, Count: 3, Percentage: %0.08
# Value: 11719.0, Count: 2, Percentage: %0.05
# Value: 11720.0, Count: 1, Percentage: %0.03
# Value: 11721.0, Count: 1, Percentage: %0.03
# Value: 11722.0, Count: 1, Percentage: %0.03
# Value: 11723.0, Count: 2, Percentage: %0.05
# Value: 11725.0, Count: 1, Percentage: %0.03
# Value: 11726.0, Count: 1, Percentage: %0.03
# Value: 11730.0, Count: 2, Percentage: %0.05
# Value: 11732.0, Count: 3, Percentage: %0.08
# Value: 11733.0, Count: 1, Percentage: %0.03
# Value: 11734.0, Count: 2, Percentage: %0.05
# Value: 11735.0, Count: 1, Percentage: %0.03
# Value: 11739.0, Count: 3, Percentage: %0.08
# Value: 11740.0, Count: 1, Percentage: %0.03
# Value: 11741.0, Count: 1, Percentage: %0.03
# Value: 11742.0, Count: 3, Percentage: %0.08
# Value: 11743.0, Count: 1, Percentage: %0.03
# Value: 11745.0, Count: 1, Percentage: %0.03
# Value: 11746.0, Count: 3, Percentage: %0.08
# Value: 11747.0, Count: 1, Percentage: %0.03
# Value: 11748.0, Count: 2, Percentage: %0.05
# Value: 11749.0, Count: 1, Percentage: %0.03
# Value: 11750.0, Count: 1, Percentage: %0.03
# Value: 11752.0, Count: 2, Percentage: %0.05
# Value: 11753.0, Count: 1, Percentage: %0.03
# Value: 11756.0, Count: 1, Percentage: %0.03
# Value: 11757.0, Count: 1, Percentage: %0.03
# Value: 11758.0, Count: 1, Percentage: %0.03
# Value: 11759.0, Count: 2, Percentage: %0.05
# Value: 11760.0, Count: 1, Percentage: %0.03
# Value: 11764.0, Count: 2, Percentage: %0.05
# Value: 11765.0, Count: 2, Percentage: %0.05
# Value: 11766.0, Count: 1, Percentage: %0.03
# Value: 11768.0, Count: 1, Percentage: %0.03
# Value: 11769.0, Count: 2, Percentage: %0.05
# Value: 11770.0, Count: 1, Percentage: %0.03
# Value: 11771.0, Count: 2, Percentage: %0.05
# Value: 11772.0, Count: 2, Percentage: %0.05
# Value: 11773.0, Count: 1, Percentage: %0.03
# Value: 11774.0, Count: 2, Percentage: %0.05
# Value: 11776.0, Count: 1, Percentage: %0.03
# Value: 11778.0, Count: 1, Percentage: %0.03
# Value: 11779.0, Count: 1, Percentage: %0.03
# Value: 11780.0, Count: 2, Percentage: %0.05
# Value: 11782.0, Count: 2, Percentage: %0.05
# Value: 11783.0, Count: 2, Percentage: %0.05
# Value: 11784.0, Count: 1, Percentage: %0.03
# Value: 11786.0, Count: 1, Percentage: %0.03
# Value: 11787.0, Count: 1, Percentage: %0.03
# Value: 11790.0, Count: 2, Percentage: %0.05
# Value: 11792.0, Count: 2, Percentage: %0.05
# Value: 11793.0, Count: 1, Percentage: %0.03
# Value: 11794.0, Count: 4, Percentage: %0.1
# Value: 11795.0, Count: 2, Percentage: %0.05
# Value: 11797.0, Count: 1, Percentage: %0.03
# Value: 11802.0, Count: 1, Percentage: %0.03
# Value: 11803.0, Count: 1, Percentage: %0.03
# Value: 11808.0, Count: 1, Percentage: %0.03
# Value: 11809.0, Count: 2, Percentage: %0.05
# Value: 11810.0, Count: 1, Percentage: %0.03
# Value: 11811.0, Count: 1, Percentage: %0.03
# Value: 11813.0, Count: 1, Percentage: %0.03
# Value: 11814.0, Count: 2, Percentage: %0.05
# Value: 11815.0, Count: 2, Percentage: %0.05
# Value: 11816.0, Count: 2, Percentage: %0.05
# Value: 11817.0, Count: 1, Percentage: %0.03
# Value: 11818.0, Count: 1, Percentage: %0.03
# Value: 11819.0, Count: 1, Percentage: %0.03
# Value: 11825.0, Count: 1, Percentage: %0.03
# Value: 11827.0, Count: 1, Percentage: %0.03
# Value: 11828.0, Count: 1, Percentage: %0.03
# Value: 11831.0, Count: 1, Percentage: %0.03
# Value: 11835.0, Count: 2, Percentage: %0.05
# Value: 11836.0, Count: 1, Percentage: %0.03
# Value: 11838.0, Count: 1, Percentage: %0.03
# Value: 11840.0, Count: 2, Percentage: %0.05
# Value: 11842.0, Count: 1, Percentage: %0.03
# Value: 11846.0, Count: 2, Percentage: %0.05
# Value: 11848.0, Count: 1, Percentage: %0.03
# Value: 11850.0, Count: 2, Percentage: %0.05
# Value: 11852.0, Count: 1, Percentage: %0.03
# Value: 11856.0, Count: 2, Percentage: %0.05
# Value: 11857.0, Count: 2, Percentage: %0.05
# Value: 11858.0, Count: 1, Percentage: %0.03
# Value: 11859.0, Count: 3, Percentage: %0.08
# Value: 11860.0, Count: 3, Percentage: %0.08
# Value: 11861.0, Count: 1, Percentage: %0.03
# Value: 11862.0, Count: 1, Percentage: %0.03
# Value: 11865.0, Count: 1, Percentage: %0.03
# Value: 11866.0, Count: 1, Percentage: %0.03
# Value: 11867.0, Count: 2, Percentage: %0.05
# Value: 11869.0, Count: 1, Percentage: %0.03
# Value: 11870.0, Count: 1, Percentage: %0.03
# Value: 11872.0, Count: 1, Percentage: %0.03
# Value: 11873.0, Count: 2, Percentage: %0.05
# Value: 11874.0, Count: 2, Percentage: %0.05
# Value: 11875.0, Count: 2, Percentage: %0.05
# Value: 11879.0, Count: 1, Percentage: %0.03
# Value: 11881.0, Count: 3, Percentage: %0.08
# Value: 11883.0, Count: 4, Percentage: %0.1
# Value: 11884.0, Count: 1, Percentage: %0.03
# Value: 11889.0, Count: 4, Percentage: %0.1
# Value: 11890.0, Count: 2, Percentage: %0.05
# Value: 11891.0, Count: 2, Percentage: %0.05
# Value: 11893.0, Count: 2, Percentage: %0.05
# Value: 11895.0, Count: 1, Percentage: %0.03
# Value: 11898.0, Count: 3, Percentage: %0.08
# Value: 11900.0, Count: 1, Percentage: %0.03
# Value: 11901.0, Count: 1, Percentage: %0.03
# Value: 11902.0, Count: 1, Percentage: %0.03
# Value: 11903.0, Count: 1, Percentage: %0.03
# Value: 11905.0, Count: 2, Percentage: %0.05
# Value: 11906.0, Count: 2, Percentage: %0.05
# Value: 11907.0, Count: 2, Percentage: %0.05
# Value: 11908.0, Count: 2, Percentage: %0.05
# Value: 11910.0, Count: 2, Percentage: %0.05
# Value: 11911.0, Count: 1, Percentage: %0.03
# Value: 11912.0, Count: 2, Percentage: %0.05
# Value: 11914.0, Count: 1, Percentage: %0.03
# Value: 11915.0, Count: 1, Percentage: %0.03
# Value: 11916.0, Count: 1, Percentage: %0.03
# Value: 11917.0, Count: 1, Percentage: %0.03
# Value: 11919.0, Count: 2, Percentage: %0.05
# Value: 11921.0, Count: 1, Percentage: %0.03
# Value: 11923.0, Count: 5, Percentage: %0.13
# Value: 11926.0, Count: 1, Percentage: %0.03
# Value: 11928.0, Count: 3, Percentage: %0.08
# Value: 11929.0, Count: 2, Percentage: %0.05
# ...
# Value: 0.7862654328346252, Count: 1, Percentage: %0.03
# Value: 0.7863311171531677, Count: 1, Percentage: %0.03
# Value: 0.7864108681678772, Count: 1, Percentage: %0.03
# Value: 0.78644198179245, Count: 1, Percentage: %0.03
# Value: 0.7864893078804016, Count: 1, Percentage: %0.03
# Value: 0.7865937352180481, Count: 1, Percentage: %0.03
# Value: 0.7866106629371643, Count: 1, Percentage: %0.03
# Value: 0.7866440415382385, Count: 1, Percentage: %0.03
# Value: 0.7867449522018433, Count: 1, Percentage: %0.03
# Value: 0.7868421077728271, Count: 1, Percentage: %0.03
# Value: 0.7869349718093872, Count: 1, Percentage: %0.03
# Value: 0.7870580554008484, Count: 1, Percentage: %0.03
# Value: 0.7870768904685974, Count: 1, Percentage: %0.03
# Value: 0.7871315479278564, Count: 1, Percentage: %0.03
# Value: 0.7871767282485962, Count: 1, Percentage: %0.03
# Value: 0.7872329354286194, Count: 1, Percentage: %0.03
# Value: 0.7873389720916748, Count: 1, Percentage: %0.03
# Value: 0.7873783111572266, Count: 1, Percentage: %0.03
# Value: 0.7874364852905273, Count: 1, Percentage: %0.03
# Value: 0.7875458002090454, Count: 1, Percentage: %0.03
# Value: 0.7875674366950989, Count: 1, Percentage: %0.03
# Value: 0.7875866889953613, Count: 1, Percentage: %0.03
# Value: 0.7877751588821411, Count: 1, Percentage: %0.03
# Value: 0.7879102826118469, Count: 1, Percentage: %0.03
# Value: 0.7879123687744141, Count: 1, Percentage: %0.03
# Value: 0.7879210114479065, Count: 1, Percentage: %0.03
# Value: 0.7881377339363098, Count: 1, Percentage: %0.03
# Value: 0.7882674336433411, Count: 1, Percentage: %0.03
# Value: 0.7883230447769165, Count: 1, Percentage: %0.03
# Value: 0.7884267568588257, Count: 1, Percentage: %0.03
# Value: 0.788435161113739, Count: 1, Percentage: %0.03
# Value: 0.7885288596153259, Count: 1, Percentage: %0.03
# Value: 0.7887048125267029, Count: 1, Percentage: %0.03
# Value: 0.7887359857559204, Count: 1, Percentage: %0.03
# Value: 0.7888022661209106, Count: 1, Percentage: %0.03
# Value: 0.7888467311859131, Count: 1, Percentage: %0.03
# Value: 0.7889577150344849, Count: 1, Percentage: %0.03
# Value: 0.7892237901687622, Count: 1, Percentage: %0.03
# Value: 0.7892676591873169, Count: 1, Percentage: %0.03
# Value: 0.7892919778823853, Count: 1, Percentage: %0.03
# Value: 0.7893617153167725, Count: 1, Percentage: %0.03
# Value: 0.7893887162208557, Count: 1, Percentage: %0.03
# Value: 0.7894618511199951, Count: 1, Percentage: %0.03
# Value: 0.7896209955215454, Count: 1, Percentage: %0.03
# Value: 0.7896976470947266, Count: 1, Percentage: %0.03
# Value: 0.7897146940231323, Count: 1, Percentage: %0.03
# Value: 0.789814829826355, Count: 1, Percentage: %0.03
# Value: 0.7899201512336731, Count: 1, Percentage: %0.03
# Value: 0.7902280688285828, Count: 1, Percentage: %0.03
# Value: 0.7905586361885071, Count: 1, Percentage: %0.03
# Value: 0.7905759215354919, Count: 1, Percentage: %0.03
# Value: 0.7906055450439453, Count: 1, Percentage: %0.03
# Value: 0.7906281352043152, Count: 1, Percentage: %0.03
# Value: 0.790646493434906, Count: 1, Percentage: %0.03
# Value: 0.79067462682724, Count: 1, Percentage: %0.03
# Value: 0.7907125353813171, Count: 1, Percentage: %0.03
# Value: 0.7907935976982117, Count: 1, Percentage: %0.03
# Value: 0.7909241914749146, Count: 1, Percentage: %0.03
# Value: 0.7910602688789368, Count: 1, Percentage: %0.03
# Value: 0.7910846471786499, Count: 1, Percentage: %0.03
# Value: 0.7911933064460754, Count: 1, Percentage: %0.03
# Value: 0.7912322878837585, Count: 1, Percentage: %0.03
# Value: 0.7913503646850586, Count: 1, Percentage: %0.03
# Value: 0.7913948893547058, Count: 1, Percentage: %0.03
# Value: 0.7916251420974731, Count: 1, Percentage: %0.03
# Value: 0.7918241620063782, Count: 1, Percentage: %0.03
# Value: 0.7918424606323242, Count: 1, Percentage: %0.03
# Value: 0.791881799697876, Count: 1, Percentage: %0.03
# Value: 0.7920731902122498, Count: 1, Percentage: %0.03
# Value: 0.7921122908592224, Count: 1, Percentage: %0.03
# Value: 0.7921276688575745, Count: 1, Percentage: %0.03
# Value: 0.7923838496208191, Count: 1, Percentage: %0.03
# Value: 0.7924167513847351, Count: 1, Percentage: %0.03
# Value: 0.7924493551254272, Count: 1, Percentage: %0.03
# Value: 0.7926489114761353, Count: 1, Percentage: %0.03
# Value: 0.7927436828613281, Count: 1, Percentage: %0.03
# Value: 0.7929019927978516, Count: 1, Percentage: %0.03
# Value: 0.7930604815483093, Count: 1, Percentage: %0.03
# Value: 0.7933481335639954, Count: 1, Percentage: %0.03
# Value: 0.7934340834617615, Count: 1, Percentage: %0.03
# Value: 0.7935240864753723, Count: 1, Percentage: %0.03
# Value: 0.7936508059501648, Count: 1, Percentage: %0.03
# Value: 0.7936698198318481, Count: 1, Percentage: %0.03
# Value: 0.794152021408081, Count: 1, Percentage: %0.03
# Value: 0.7941702604293823, Count: 1, Percentage: %0.03
# Value: 0.7941888570785522, Count: 1, Percentage: %0.03
# Value: 0.7942029237747192, Count: 1, Percentage: %0.03
# Value: 0.7942112684249878, Count: 1, Percentage: %0.03
# Value: 0.7943276762962341, Count: 1, Percentage: %0.03
# Value: 0.7943485379219055, Count: 1, Percentage: %0.03
# Value: 0.7943720817565918, Count: 1, Percentage: %0.03
# Value: 0.7943877577781677, Count: 1, Percentage: %0.03
# Value: 0.794499933719635, Count: 1, Percentage: %0.03
# Value: 0.7945355176925659, Count: 1, Percentage: %0.03
# Value: 0.7945712804794312, Count: 1, Percentage: %0.03
# Value: 0.7945719361305237, Count: 1, Percentage: %0.03
# Value: 0.7948306798934937, Count: 1, Percentage: %0.03
# Value: 0.794863760471344, Count: 1, Percentage: %0.03
# Value: 0.7948814034461975, Count: 1, Percentage: %0.03
# Value: 0.7948898077011108, Count: 1, Percentage: %0.03
# Value: 0.7950283288955688, Count: 1, Percentage: %0.03
# Value: 0.795104444026947, Count: 1, Percentage: %0.03
# Value: 0.7951397895812988, Count: 1, Percentage: %0.03
# Value: 0.7952153086662292, Count: 1, Percentage: %0.03
# Value: 0.7953761219978333, Count: 1, Percentage: %0.03
# Value: 0.7954022884368896, Count: 1, Percentage: %0.03
# Value: 0.7954802513122559, Count: 1, Percentage: %0.03
# Value: 0.7955710887908936, Count: 1, Percentage: %0.03
# Value: 0.7956470847129822, Count: 1, Percentage: %0.03
# Value: 0.7956844568252563, Count: 1, Percentage: %0.03
# Value: 0.7957219481468201, Count: 1, Percentage: %0.03
# Value: 0.7958434224128723, Count: 1, Percentage: %0.03
# Value: 0.7958725094795227, Count: 1, Percentage: %0.03
# Value: 0.7958980798721313, Count: 1, Percentage: %0.03
# Value: 0.7960273623466492, Count: 1, Percentage: %0.03
# Value: 0.7960658669471741, Count: 1, Percentage: %0.03
# Value: 0.796371579170227, Count: 1, Percentage: %0.03
# Value: 0.796532928943634, Count: 1, Percentage: %0.03
# Value: 0.7966090440750122, Count: 1, Percentage: %0.03
# Value: 0.7966366410255432, Count: 1, Percentage: %0.03
# Value: 0.7966991662979126, Count: 1, Percentage: %0.03
# Value: 0.7967374920845032, Count: 1, Percentage: %0.03
# Value: 0.7968435883522034, Count: 1, Percentage: %0.03
# Value: 0.7968451380729675, Count: 1, Percentage: %0.03
# Value: 0.7968934774398804, Count: 1, Percentage: %0.03
# Value: 0.7969072461128235, Count: 1, Percentage: %0.03
# Value: 0.7970332503318787, Count: 1, Percentage: %0.03
# Value: 0.7970655560493469, Count: 1, Percentage: %0.03
# Value: 0.7971899509429932, Count: 1, Percentage: %0.03
# Value: 0.7972930669784546, Count: 1, Percentage: %0.03
# Value: 0.7973142862319946, Count: 1, Percentage: %0.03
# Value: 0.797354519367218, Count: 1, Percentage: %0.03
# Value: 0.7974358797073364, Count: 1, Percentage: %0.03
# Value: 0.7975121736526489, Count: 1, Percentage: %0.03
# Value: 0.7976964712142944, Count: 1, Percentage: %0.03
# Value: 0.7977052927017212, Count: 1, Percentage: %0.03
# Value: 0.79776930809021, Count: 1, Percentage: %0.03
# Value: 0.7977837324142456, Count: 1, Percentage: %0.03
# Value: 0.79792720079422, Count: 1, Percentage: %0.03
# Value: 0.7979274392127991, Count: 1, Percentage: %0.03
# Value: 0.7979310154914856, Count: 1, Percentage: %0.03
# Value: 0.7979857921600342, Count: 1, Percentage: %0.03
# Value: 0.7980872392654419, Count: 1, Percentage: %0.03
# Value: 0.7980969548225403, Count: 1, Percentage: %0.03
# Value: 0.7981546521186829, Count: 1, Percentage: %0.03
# Value: 0.7981995344161987, Count: 1, Percentage: %0.03
# Value: 0.7982450127601624, Count: 1, Percentage: %0.03
# Value: 0.7983269095420837, Count: 1, Percentage: %0.03
# Value: 0.7984176278114319, Count: 1, Percentage: %0.03
# Value: 0.7985498905181885, Count: 1, Percentage: %0.03
# Value: 0.7987066507339478, Count: 1, Percentage: %0.03
# Value: 0.7987071871757507, Count: 1, Percentage: %0.03
# Value: 0.7987112998962402, Count: 1, Percentage: %0.03
# Value: 0.7988387942314148, Count: 1, Percentage: %0.03
# Value: 0.7988585829734802, Count: 1, Percentage: %0.03
# Value: 0.7988755702972412, Count: 1, Percentage: %0.03
# Value: 0.7990440130233765, Count: 1, Percentage: %0.03
# Value: 0.799068033695221, Count: 1, Percentage: %0.03
# Value: 0.7990950345993042, Count: 1, Percentage: %0.03
# Value: 0.7992097735404968, Count: 1, Percentage: %0.03
# Value: 0.7992183566093445, Count: 1, Percentage: %0.03
# Value: 0.7994186282157898, Count: 1, Percentage: %0.03
# Value: 0.7994261384010315, Count: 1, Percentage: %0.03
# Value: 0.7994276881217957, Count: 1, Percentage: %0.03
# Value: 0.7996256947517395, Count: 1, Percentage: %0.03
# Value: 0.7996860146522522, Count: 1, Percentage: %0.03
# Value: 0.7997256517410278, Count: 1, Percentage: %0.03
# Value: 0.7998263239860535, Count: 1, Percentage: %0.03
# Value: 0.7998467683792114, Count: 1, Percentage: %0.03
# Value: 0.7998774647712708, Count: 1, Percentage: %0.03
# Value: 0.7998971343040466, Count: 1, Percentage: %0.03
# Value: 0.7999527454376221, Count: 1, Percentage: %0.03
# Value: 0.800197184085846, Count: 1, Percentage: %0.03
# Value: 0.8004913926124573, Count: 1, Percentage: %0.03
# Value: 0.8010489344596863, Count: 1, Percentage: %0.03
# Value: 0.8014438152313232, Count: 1, Percentage: %0.03
# Value: 0.8014652132987976, Count: 1, Percentage: %0.03
# Value: 0.8016341924667358, Count: 1, Percentage: %0.03
# Value: 0.8017144799232483, Count: 1, Percentage: %0.03
# Value: 0.8018226623535156, Count: 1, Percentage: %0.03
# Value: 0.801966667175293, Count: 1, Percentage: %0.03
# Value: 0.8020662069320679, Count: 1, Percentage: %0.03
# Value: 0.8023256063461304, Count: 1, Percentage: %0.03
# Value: 0.802401065826416, Count: 1, Percentage: %0.03
# Value: 0.8027175068855286, Count: 1, Percentage: %0.03
# Value: 0.8027639985084534, Count: 1, Percentage: %0.03
# Value: 0.8029462099075317, Count: 1, Percentage: %0.03
# Value: 0.8029494285583496, Count: 1, Percentage: %0.03
# Value: 0.8030722737312317, Count: 1, Percentage: %0.03
# Value: 0.8031444549560547, Count: 1, Percentage: %0.03
# Value: 0.803247332572937, Count: 1, Percentage: %0.03
# Value: 0.8033716082572937, Count: 1, Percentage: %0.03
# Value: 0.8033774495124817, Count: 1, Percentage: %0.03
# Value: 0.8034132122993469, Count: 1, Percentage: %0.03
# Value: 0.8034206032752991, Count: 1, Percentage: %0.03
# Value: 0.803449273109436, Count: 1, Percentage: %0.03
# Value: 0.8037516474723816, Count: 1, Percentage: %0.03
# Value: 0.8037651181221008, Count: 1, Percentage: %0.03
# Value: 0.8041241765022278, Count: 1, Percentage: %0.03
# Value: 0.8042354583740234, Count: 1, Percentage: %0.03
# Value: 0.8042449355125427, Count: 1, Percentage: %0.03
# Value: 0.804679811000824, Count: 1, Percentage: %0.03
# Value: 0.8048041462898254, Count: 1, Percentage: %0.03
# Value: 0.804836630821228, Count: 1, Percentage: %0.03
# Value: 0.8052298426628113, Count: 1, Percentage: %0.03
# Value: 0.8056262135505676, Count: 1, Percentage: %0.03
# Value: 0.8057509064674377, Count: 1, Percentage: %0.03
# Value: 0.8057532906532288, Count: 1, Percentage: %0.03
# Value: 0.8060855269432068, Count: 1, Percentage: %0.03
# Value: 0.806259036064148, Count: 1, Percentage: %0.03
# Value: 0.8064119815826416, Count: 1, Percentage: %0.03
# Value: 0.8064789175987244, Count: 1, Percentage: %0.03
# Value: 0.8064805865287781, Count: 1, Percentage: %0.03
# Value: 0.8065717220306396, Count: 1, Percentage: %0.03
# Value: 0.8065909147262573, Count: 1, Percentage: %0.03
# Value: 0.8066319823265076, Count: 1, Percentage: %0.03
# Value: 0.8066884875297546, Count: 1, Percentage: %0.03
# Value: 0.8066998720169067, Count: 1, Percentage: %0.03
# Value: 0.8067737221717834, Count: 1, Percentage: %0.03
# Value: 0.8070090413093567, Count: 1, Percentage: %0.03
# Value: 0.8074247241020203, Count: 1, Percentage: %0.03
# Value: 0.8077300786972046, Count: 1, Percentage: %0.03
# Value: 0.8078792095184326, Count: 1, Percentage: %0.03
# Value: 0.8079560995101929, Count: 1, Percentage: %0.03
# Value: 0.8080000281333923, Count: 1, Percentage: %0.03
# Value: 0.8081020712852478, Count: 1, Percentage: %0.03
# Value: 0.8081448078155518, Count: 1, Percentage: %0.03
# Value: 0.8083371520042419, Count: 1, Percentage: %0.03
# Value: 0.808387041091919, Count: 1, Percentage: %0.03
# Value: 0.8085868954658508, Count: 1, Percentage: %0.03
# Value: 0.8088265657424927, Count: 1, Percentage: %0.03
# Value: 0.8088882565498352, Count: 1, Percentage: %0.03
# Value: 0.8090233206748962, Count: 1, Percentage: %0.03
# Value: 0.8091670870780945, Count: 1, Percentage: %0.03
# Value: 0.8091856241226196, Count: 1, Percentage: %0.03
# Value: 0.8094594478607178, Count: 1, Percentage: %0.03
# Value: 0.8096147179603577, Count: 1, Percentage: %0.03
# Value: 0.8097601532936096, Count: 1, Percentage: %0.03
# Value: 0.8097798228263855, Count: 1, Percentage: %0.03
# Value: 0.8100398778915405, Count: 1, Percentage: %0.03
# Value: 0.8101080656051636, Count: 1, Percentage: %0.03
# Value: 0.8101488947868347, Count: 1, Percentage: %0.03
# Value: 0.8104338645935059, Count: 1, Percentage: %0.03
# Value: 0.810562014579773, Count: 1, Percentage: %0.03
# Value: 0.810987651348114, Count: 1, Percentage: %0.03
# Value: 0.8111507892608643, Count: 1, Percentage: %0.03
# Value: 0.8118952512741089, Count: 1, Percentage: %0.03
# Value: 0.8120773434638977, Count: 1, Percentage: %0.03
# Value: 0.8123505115509033, Count: 1, Percentage: %0.03
# Value: 0.8124171495437622, Count: 1, Percentage: %0.03
# Value: 0.8124281764030457, Count: 1, Percentage: %0.03
# Value: 0.8127623200416565, Count: 1, Percentage: %0.03
# Value: 0.8130268454551697, Count: 1, Percentage: %0.03
# Value: 0.8134686946868896, Count: 1, Percentage: %0.03
# Value: 0.8136151432991028, Count: 1, Percentage: %0.03
# Value: 0.8141354918479919, Count: 1, Percentage: %0.03
# Value: 0.8141604065895081, Count: 1, Percentage: %0.03
# Value: 0.8145128488540649, Count: 1, Percentage: %0.03
# Value: 0.8146211504936218, Count: 1, Percentage: %0.03
# Value: 0.8148128986358643, Count: 1, Percentage: %0.03
# Value: 0.8148717880249023, Count: 1, Percentage: %0.03
# Value: 0.8149744868278503, Count: 1, Percentage: %0.03
# Value: 0.8153865337371826, Count: 1, Percentage: %0.03
# Value: 0.8164195418357849, Count: 1, Percentage: %0.03
# Value: 0.816888153553009, Count: 1, Percentage: %0.03
# Value: 0.8170584440231323, Count: 1, Percentage: %0.03
# Value: 0.8180834054946899, Count: 1, Percentage: %0.03
# Value: 0.8181177973747253, Count: 1, Percentage: %0.03
# Value: 0.8186713457107544, Count: 1, Percentage: %0.03
# Value: 0.8189351558685303, Count: 1, Percentage: %0.03
# Value: 0.8191086053848267, Count: 1, Percentage: %0.03
# Value: 0.8201084733009338, Count: 1, Percentage: %0.03
# Value: 0.820385217666626, Count: 1, Percentage: %0.03
# Value: 0.8210970163345337, Count: 1, Percentage: %0.03
# Value: 0.8221361041069031, Count: 1, Percentage: %0.03
# Value: 0.8223004341125488, Count: 1, Percentage: %0.03
# Value: 0.8225758671760559, Count: 1, Percentage: %0.03
# Value: 0.8227933049201965, Count: 1, Percentage: %0.03
# Value: 0.823784351348877, Count: 1, Percentage: %0.03
# Value: 0.8248363733291626, Count: 1, Percentage: %0.03
# Value: 0.8251030445098877, Count: 1, Percentage: %0.03
# Value: 0.8269609808921814, Count: 1, Percentage: %0.03
# Value: 0.8273189067840576, Count: 1, Percentage: %0.03
# Value: 0.8273404240608215, Count: 1, Percentage: %0.03
# Value: 0.8284726142883301, Count: 1, Percentage: %0.03
# Value: 0.8306878209114075, Count: 1, Percentage: %0.03
# Value: 0.8327473402023315, Count: 1, Percentage: %0.03
# Value: 0.8396612405776978, Count: 1, Percentage: %0.03
# Value: 0.8610495328903198, Count: 1, Percentage: %0.03
#
# Mean: 0.6619340379094202
# Median: 0.6453614234924316
# Mode: 0.5882353186607361
# Standard Deviation: 0.07722863630037272

# %% [markdown]
# ### Dataset 4 (Mushroom):

# %%
filename = "data/agaricus-lepiota.data"
x,y = readFileLog(filename)
mushroom_values = np.array(x)
mush_labels = np.array(y)


categories = ["cap-shape", "cap-surface", "cap-color", "bruises", "odor", "gill-attachment", "gill-spacing", 
              "gill-size", "gill_color","stalk-shape","stalk-root", "stalk-surface-above-ring", 
              "stalk-surface-below-ring", "stalk-color-above-ring", "stalk-color-below-ring", "veil-type", 
              "veil-color", "ring-number", "ring-type", "spore-print-color", "population"]

classifications = ["poisonous", "edible"]

alphabet = 'abcdefghijklmnopqrstuvwxyz'
print(x[0])
# print(x)
mush_data = np.array([row[1:] for row in x])
print(mush_data[0])

alphabet = 'abcdefghijklmnopqrstuvwxyz'

# Define a function to convert a character to its index in the alphabet
def letter_to_index(letter):
    return alphabet.index(letter) if letter in alphabet else -1

# Use np.vectorize to apply the function element-wise to the array
index_converter = np.vectorize(letter_to_index)
mush_data = index_converter(mush_data)


result = np.column_stack((mush_data, mush_labels))
print(result)

# for row in result:
#     print(((row[-3])))
# # print(result)

# alphabet = 'abcdefghijklmnopqrstuvwxyz'

# for i in range(len(alphabet)):
#     letter = alphabet[i]
#     mushroom_data[mushroom_data == letter] = i
    
# for mush in mushroom_data:
#     print(mush)




# # Count the number of positive class instances
# positive_count = sum(1 for label in mushroom_labels if label == 1)

# # Count the number of negative class instances
# negative_count = sum(1 for label in mushroom_labels if label == 0)

# print("Distribution of classes:")
# print("Positive (Poisinous):", positive_count)
# print("Negative (Edible):", negative_count)

# print("\nData:")
# print(mushroom_data, mushroom_labels)

# mushroom_data = np.array(x[0])
# mushroom_labels = np.array(y)

# new_mushroom_data = np.hstack((mushroom_data, mushroom_labels))
#=====================================================
#Analyze Data
#=====================================================
mushroomAnalysis = dataAnalysis(result,categories,classifications)
mushroomAnalysis.printLabelStats()
mushroomAnalysis.printCategoryStats()
# Out:
# ['p', 'x', 's', 'n', 't', 'p', 'f', 'c', 'n', 'k', 'e', 'e', 's', 's', 'w', 'w', 'p', 'w', 'o', 'p', 'k', 's']
# ['x' 's' 'n' 't' 'p' 'f' 'c' 'n' 'k' 'e' 'e' 's' 's' 'w' 'w' 'p' 'w' 'o'
#  'p' 'k' 's']
# [['23' '18' '13' ... '10' '18' 'edible']
#  ['23' '18' '24' ... '13' '13' 'poisonous']
#  ['1' '18' '22' ... '13' '13' 'poisonous']
#  ...
#  ['23' '24' '6' ... '22' '24' 'poisonous']
#  ['23' '24' '2' ... '22' '2' 'edible']
#  ['5' '24' '2' ... '22' '2' 'edible']]
# =====================================================
# Classification Analysis:
# =====================================================
# Total: 5644 (%100)
# Value: poisonous, Count: 3488, Percentage: %61.8
# Value: edible, Count: 2156, Percentage: %38.2
# =====================================================
# Attribute Analysis:
# =====================================================
# -----------------------------------------------------
# CAP-SHAPE Analysis:
# -----------------------------------------------------
# Value: 1.0, Count: 300, Percentage: %5.32
# Value: 2.0, Count: 4, Percentage: %0.07
# Value: 5.0, Count: 2432, Percentage: %43.09
# Value: 10.0, Count: 36, Percentage: %0.64
# Value: 18.0, Count: 32, Percentage: %0.57
# Value: 23.0, Count: 2840, Percentage: %50.32
#
# Mean: 13.94826364280652
# Median: 23.0
# Mode: 23.0
# Standard Deviation: 9.216093188996469
# -----------------------------------------------------
# CAP-SURFACE Analysis:
# -----------------------------------------------------
# Value: 5.0, Count: 2160, Percentage: %38.27
# Value: 6.0, Count: 4, Percentage: %0.07
# Value: 18.0, Count: 1260, Percentage: %22.32
# Value: 24.0, Count: 2220, Percentage: %39.33
#
# Mean: 15.376328844790928
# Median: 18.0
# Mode: 24.0
# Standard Deviation: 8.488586967538737
# -----------------------------------------------------
# CAP-COLOR Analysis:
# -----------------------------------------------------
# Value: 1.0, Count: 120, Percentage: %2.13
# Value: 2.0, Count: 44, Percentage: %0.78
# Value: 4.0, Count: 588, Percentage: %10.42
# Value: 6.0, Count: 1696, Percentage: %30.05
# Value: 13.0, Count: 1164, Percentage: %20.62
# Value: 15.0, Count: 96, Percentage: %1.7
# Value: 22.0, Count: 880, Percentage: %15.59
# Value: 24.0, Count: 1056, Percentage: %18.71
#
# Mean: 13.113394755492559
# Median: 13.0
# Mode: 6.0
# Standard Deviation: 7.905172249316814
# -----------------------------------------------------
# BRUISES Analysis:
# -----------------------------------------------------
# Value: 5.0, Count: 2460, Percentage: %43.59
# Value: 19.0, Count: 3184, Percentage: %56.41
#
# Mean: 12.897944720056698
# Median: 19.0
# Mode: 19.0
# Standard Deviation: 6.942167909214117
# -----------------------------------------------------
# ODOR Analysis:
# -----------------------------------------------------
# Value: 0.0, Count: 400, Percentage: %7.09
# Value: 2.0, Count: 192, Percentage: %3.4
# Value: 5.0, Count: 1584, Percentage: %28.07
# Value: 11.0, Count: 400, Percentage: %7.09
# Value: 12.0, Count: 36, Percentage: %0.64
# Value: 13.0, Count: 2776, Percentage: %49.18
# Value: 15.0, Count: 256, Percentage: %4.54
#
# Mean: 9.401842664776755
# Median: 13.0
# Mode: 13.0
# Standard Deviation: 4.6454107123910715
# -----------------------------------------------------
# GILL-ATTACHMENT Analysis:
# -----------------------------------------------------
# Value: 0.0, Count: 18, Percentage: %0.32
# Value: 5.0, Count: 5626, Percentage: %99.68
#
# Mean: 4.984053862508859
# Median: 5.0
# Mode: 5.0
# Standard Deviation: 0.2819156046671038
# -----------------------------------------------------
# GILL-SPACING Analysis:
# -----------------------------------------------------
# Value: 2.0, Count: 4620, Percentage: %81.86
# Value: 22.0, Count: 1024, Percentage: %18.14
#
# Mean: 5.628632175761871
# Median: 2.0
# Mode: 2.0
# Standard Deviation: 7.7075075120471395
# -----------------------------------------------------
# GILL-SIZE Analysis:
# -----------------------------------------------------
# Value: 1.0, Count: 4940, Percentage: %87.53
# Value: 13.0, Count: 704, Percentage: %12.47
#
# Mean: 2.496810772501772
# Median: 1.0
# Mode: 1.0
# Standard Deviation: 3.965007790830166
# -----------------------------------------------------
# GILL_COLOR Analysis:
# -----------------------------------------------------
# Value: 6.0, Count: 656, Percentage: %11.62
# Value: 7.0, Count: 720, Percentage: %12.76
# Value: 10.0, Count: 408, Percentage: %7.23
# Value: 13.0, Count: 984, Percentage: %17.43
# Value: 15.0, Count: 1384, Percentage: %24.52
# Value: 17.0, Count: 24, Percentage: %0.43
# Value: 20.0, Count: 480, Percentage: %8.5
# Value: 22.0, Count: 966, Percentage: %17.12
# Value: 24.0, Count: 22, Percentage: %0.39
#
# Mean: 13.890148830616583
# Median: 15.0
# Mode: 15.0
# Standard Deviation: 5.449528296984558
# -----------------------------------------------------
# STALK-SHAPE Analysis:
# -----------------------------------------------------
# Value: 4.0, Count: 2764, Percentage: %48.97
# Value: 19.0, Count: 2880, Percentage: %51.03
#
# Mean: 11.654145995747697
# Median: 19.0
# Mode: 19.0
# Standard Deviation: 7.498415766813344
# -----------------------------------------------------
# STALK-ROOT Analysis:
# -----------------------------------------------------
# Value: 1.0, Count: 3776, Percentage: %66.9
# Value: 2.0, Count: 556, Percentage: %9.85
# Value: 4.0, Count: 1120, Percentage: %19.84
# Value: 17.0, Count: 192, Percentage: %3.4
#
# Mean: 2.238128986534373
# Median: 1.0
# Mode: 1.0
# Standard Deviation: 3.010022080878114
# -----------------------------------------------------
# STALK-SURFACE-ABOVE-RING Analysis:
# -----------------------------------------------------
# Value: 5.0, Count: 552, Percentage: %9.78
# Value: 10.0, Count: 1332, Percentage: %23.6
# Value: 18.0, Count: 3736, Percentage: %66.19
# Value: 24.0, Count: 24, Percentage: %0.43
#
# Mean: 14.866052445074414
# Median: 18.0
# Mode: 18.0
# Standard Deviation: 4.686612862396866
# -----------------------------------------------------
# STALK-SURFACE-BELOW-RING Analysis:
# -----------------------------------------------------
# Value: 5.0, Count: 552, Percentage: %9.78
# Value: 10.0, Count: 1296, Percentage: %22.96
# Value: 18.0, Count: 3544, Percentage: %62.79
# Value: 24.0, Count: 252, Percentage: %4.46
#
# Mean: 15.15946137491141
# Median: 18.0
# Mode: 18.0
# Standard Deviation: 4.976281175517163
# -----------------------------------------------------
# STALK-COLOR-ABOVE-RING Analysis:
# -----------------------------------------------------
# Value: 1.0, Count: 432, Percentage: %7.65
# Value: 2.0, Count: 36, Percentage: %0.64
# Value: 6.0, Count: 576, Percentage: %10.21
# Value: 13.0, Count: 448, Percentage: %7.94
# Value: 15.0, Count: 1008, Percentage: %17.86
# Value: 22.0, Count: 3136, Percentage: %55.56
# Value: 24.0, Count: 8, Percentage: %0.14
#
# Mean: 16.670446491849752
# Median: 22.0
# Mode: 22.0
# Standard Deviation: 7.015309653780057
# -----------------------------------------------------
# STALK-COLOR-BELOW-RING Analysis:
# -----------------------------------------------------
# Value: 1.0, Count: 432, Percentage: %7.65
# Value: 2.0, Count: 36, Percentage: %0.64
# Value: 6.0, Count: 576, Percentage: %10.21
# Value: 13.0, Count: 496, Percentage: %8.79
# Value: 15.0, Count: 1008, Percentage: %17.86
# Value: 22.0, Count: 3088, Percentage: %54.71
# Value: 24.0, Count: 8, Percentage: %0.14
#
# Mean: 16.593905031892277
# Median: 22.0
# Mode: 22.0
# Standard Deviation: 7.005834744702012
# -----------------------------------------------------
# VEIL-TYPE Analysis:
# -----------------------------------------------------
# Value: 15.0, Count: 5644, Percentage: %100.0
#
# Mean: 15.0
# Median: 15.0
# Mode: 15.0
# Standard Deviation: 0.0
# -----------------------------------------------------
# VEIL-COLOR Analysis:
# -----------------------------------------------------
# Value: 22.0, Count: 5636, Percentage: %99.86
# Value: 24.0, Count: 8, Percentage: %0.14
#
# Mean: 22.002834868887312
# Median: 22.0
# Mode: 22.0
# Standard Deviation: 0.07524427747689298
# -----------------------------------------------------
# RING-NUMBER Analysis:
# -----------------------------------------------------
# Value: 13.0, Count: 36, Percentage: %0.64
# Value: 14.0, Count: 5488, Percentage: %97.24
# Value: 19.0, Count: 120, Percentage: %2.13
#
# Mean: 14.099929128277816
# Median: 14.0
# Mode: 14.0
# Standard Deviation: 0.7265882882963774
# -----------------------------------------------------
# RING-TYPE Analysis:
# -----------------------------------------------------
# Value: 4.0, Count: 824, Percentage: %14.6
# Value: 11.0, Count: 1296, Percentage: %22.96
# Value: 13.0, Count: 36, Percentage: %0.64
# Value: 15.0, Count: 3488, Percentage: %61.8
#
# Mean: 12.462792345854004
# Median: 15.0
# Mode: 15.0
# Standard Deviation: 3.8636209297736035
# -----------------------------------------------------
# SPORE-PRINT-COLOR Analysis:
# -----------------------------------------------------
# Value: 7.0, Count: 1584, Percentage: %28.07
# Value: 10.0, Count: 1872, Percentage: %33.17
# Value: 13.0, Count: 1920, Percentage: %34.02
# Value: 17.0, Count: 72, Percentage: %1.28
# Value: 20.0, Count: 48, Percentage: %0.85
# Value: 22.0, Count: 148, Percentage: %2.62
#
# Mean: 10.667611622962438
# Median: 10.0
# Mode: 13.0
# Standard Deviation: 3.223882118119456
# -----------------------------------------------------
# POPULATION Analysis:
# -----------------------------------------------------
# Value: 0.0, Count: 384, Percentage: %6.8
# Value: 2.0, Count: 52, Percentage: %0.92
# Value: 13.0, Count: 256, Percentage: %4.54
# Value: 18.0, Count: 1104, Percentage: %19.56
# Value: 21.0, Count: 2160, Percentage: %38.27
# Value: 24.0, Count: 1688, Percentage: %29.91
#
# Mean: 19.343727852586817
# Median: 21.0
# Mode: 21.0
# Standard Deviation: 6.159715263485113

# %% [markdown]
# ## Task 2: Implement the models
#
# #### 1. Implement logistic regression, and use (full batch) gradient descent for optimization.
# #### 2. Implement k-Nearest Neighbor (KNN), and find the best K.
#
# Implement both models as Python classes. You should use the constructor for the class to initialize the model
# parameters as attributes, as well as to define other important properties of the model.
# • Each of your models’ classes should have (at least) two functions:
# – Define a fit function, which takes the training data (i.e., x and y)—as well as other hyperparameters (e.g.,
# the learning rate and/or number of gradient descent iterations)—as input. This function should train your
# model by modifying the model parameters.
# – Define a predict function, which takes a set of input points (i.e., x) as input and outputs predictions (i.e.,
# yˆ) for these points. Note that for linear regression you need to convert probabilities to binary 0-1
# predictions by thresholding the output at 0.5!
# In addition to the model classes, you should also define functions evaluate_acc to evaluate the model accuracy.
# This function should take the true labels (i.e., y), and target labels (i.e., yˆ) as input, and it should output the accuracy
# score.
# • Lastly, you should implement a script to run k-fold cross-validation

# %% [markdown]
# ### Logistic Regression:

# %%
class logistic_regression:
    def __init__(self):
        self.threshold = 0.5
        self.convergence = 0.01
        return None
    
    def fit(self, x,y,alpha,iterations):
        m = len(x)
        w = 0
        b = 0

        while self.convergence < self.J(w,b,m,x,y)- self.mse:
            tmp_w = w - alpha*self.J(w,b,m,x,y)
            tmp_b = b - alpha*self.J(w,b,m,x,y)

            w = tmp_w
            b = tmp_b
        
        return None

    def predict(self, x):
        return None

    def evaluate_acc(self, y, y_ex):
        return None

    def mse(self, m, w, b, x, y):
        val = 0

        for i in range(m):
            val += (b + (w*x[i]) - y[i])**2

        return val

    def J(self, w, b, m, x, y):
        return (1/2*m)*self.mse(m,w,b,x,y)

# %% [markdown]
# ### K-Nearest Neighbor (KNN):
# Riley and Torin

# %%
# 1) a new data point is input that we need to classify
# 2) check the classification of the k nearest elements
# 3) assunming we have 2 unique classifications (a,b). we take the classification of the dominant group
# 4) if a tie exists take the class with the shortest distance from 

#to calculate distance we can use the Euclidean distance formula sqrt(sum i to N (x1_i — x2_i)²)


class kNN:
    def __init__(self, k, dist_metric="euclidean"):     
        '''
        ===================================================================================
        DESCRIPTION: 
        ===================================================================================
        initialize kNN model
        ===================================================================================
        PARAMETERS:
        ===================================================================================
        * self (kNN): 
        ----------------------------------------
        kNN model to define k values, training data, and distance metric
        ----------------------------------------
        * k (int):
        ----------------------------------------
        integer representing number of neighbours to compare to
        ----------------------------------------
        * dist_metric (string):
        ----------------------------------------
        string representing distance metric formula to follow
        ===================================================================================
        '''
        self.k = k #num of neighbours
        self.dist_metric = dist_metric #equation to calculate distance with
        self.train_data = None #initialize using fit method
        self.train_labels = None
        
    def fit(self, data, labels):
        '''
        ===================================================================================
        DESCRIPTION: 
        ===================================================================================
        set train_data and train_labelsby loading in Train data used to compare new data
        ===================================================================================
        PARAMETERS:
        ===================================================================================
        * data[] (NumPy Array): 
        ----------------------------------------
        list of data with labels seperated
        ----------------------------------------
        * labels (NumPy Array):
        ----------------------------------------
        list of labels with data removed
        ===================================================================================
        '''
        self.train_data = data
        self.train_labels = labels

    def predict(self, new_data):
        '''
        ===================================================================================
        DESCRIPTION: 
        ===================================================================================
        given new data, compare its items to the k closest elements of training data based 
        on a set distance metric and predict the datas classification.
        ===================================================================================
        PARAMETERS:
        ===================================================================================
        * self (kNN): 
        ----------------------------------------
        kNN model with predefined k values, training data, and distance metric
        ----------------------------------------
        * new_data (NumPy Array):
        ----------------------------------------
        Array of new data to predict classifications for
        ===================================================================================
        RETURNS:
        ===================================================================================
        * predictions (List):
        ----------------------------------------
        list of labels for each item in new_data
        ===================================================================================
        '''
        predictions = []#return array of predicted classifications, for each row in new_data
        for new_row in new_data:
            # calculate distances between new data and training data                   
            k_neighbours = self.__neighbours(new_row) #determine the k nearest neighbours using preffered distance metric
            classifications = []#for the given neighbors check their label
            distances = [] #for tiebreak if need be
            for result in k_neighbours:
                #print(f"new = {new_row}: train = {result[2]}")
                i = result[1]#results formatted [row, index of row], so take the index to find the associated label
                dist = result[0]
                classifications.append(self.train_labels[i])#add label at index i
                distances.append(dist)

            
            #check for ties in classifications here
            # thinking is use multimode to check for classification ties, to know then we need to check lowest distance 
            classifications_mode = statistics.multimode(classifications)
            #print(classifications_mode)
            #print(distances)

            if len(classifications_mode) > 1: #i.e we have a tie
                #go over distances, and get the lowest average and append that to predictions
                #print(classifications_mode)
                #make an array of size len(classifications) to store distances
                distances_mode = [0.0] * len(classifications_mode)
                #print(distances_mode, len(distances_mode), len(classifications_mode))
                #if label from classifications is in modes, add the distance to the appropriate index in the distances array
                classification_index = 0
                for classification in classifications:
                    if classification in classifications_mode: #if the classification is part of the multimode
                        #get the proper index for the distance array for that 
                        distance_index = classifications_mode.index(classification)
                        #print(distance_index)
                        #print(distances_mode)
                        distances_mode[distance_index] += distances[classification_index] #increase the correct distance by the distance of the classification

                    classification_index += 1

                #print(distances)
                #print(distances_mode)
                #choose the minimum distance label and append to predictions
                min_distance = min(distances_mode)

                min_distance_index = distances_mode.index(min_distance)
                #print(min_distance_index)
                min_classification = classifications_mode[min_distance_index]

                #print("The label with the minimum distance to neighbors is:", min_classification, "with distance:", min_distance)

                predictions.append(min_classification)

            else:
                predictions.append(str(max(classifications, key=classifications.count))) #from collections import Counter
        
        return predictions
    
    def evaluate_acc(self,predictions, test_labels):
        '''
        ===================================================================================
        DESCRIPTION: 
        ===================================================================================
        Compare model predictions to actual values and print success rate
        ===================================================================================
        '''
        total = len(predictions)
        hits = 0

        for i in range(total):
            if predictions[i] == test_labels[i]:
                hits += 1
#             print(f"guess:{predictions[i]}|answer:{test_labels[i]}")
        percentage = round(100*hits/total,2)
        print(f"Success Rate: %{percentage}")

        return percentage
    
    def __calc_distance(self,newRow, trainRow):
        '''
        ===================================================================================
        DESCRIPTION: 
        ===================================================================================
        Private Function used in self.__neighbours(). Given a row from new data, calculate 
        the distance based on a set metric from a row in Train data
        ===================================================================================
        PARAMETERS:
        ===================================================================================
        * self (kNN): 
        ----------------------------------------
        kNN model with predefined k values, training data, and distance metric
        ----------------------------------------
        * newRow[] (List of data points (float/int)):
        ----------------------------------------
        data row to compare distance from train row data 
        ----------------------------------------
        * trainRow[] (List of data points (float/int)):
        ----------------------------------------
        data row to compare distance with test data
        ===================================================================================
        RETURNS:
        ===================================================================================
        * distance (float):
        ----------------------------------------
        float distance between to rows of data
        ===================================================================================
        '''
        distance = 0
        if self.dist_metric == "euclidean":
            for i in range(len(newRow)):
                squared = pow(newRow[i] - trainRow[i],2)
                distance += squared
            distance = sqrt(distance)
        return(distance)

    def __neighbours(self, new_row):
        '''
        ===================================================================================
        DESCRIPTION: 
        ===================================================================================
        private function used in self.predict(). Given a row from new data, return k number
        of neigbours based on distance
        ===================================================================================
        PARAMETERS:
        ===================================================================================
        * self (kNN): 
        ----------------------------------------
        kNN model with predefined k values, training data, and distance metric
        ----------------------------------------
        * newRow[] (List of data points (float/int)):
        ----------------------------------------
        data row to compare distance from train row data 
        ----------------------------------------
        * trainRow[] (List of data points (float/int)):
        ----------------------------------------
        data row to compare distance with test data
        ===================================================================================
        RETURNS:
        ===================================================================================
        * k_neighbours (List):
        ----------------------------------------
        list of k closest neighbours based on distance metric
        ===================================================================================
        '''
        distances = []#heap array
        #for every row of data
        for index in range(len(self.train_data)):#use index to return that value later
            train_row = self.train_data[index]#current row of train data
            dist = self.__calc_distance(new_row, train_row)#calculate distance between new row and train data row
            heapq.heappush(distances, [-dist, index, list(train_row)])#make negative value temporarily to assure we have smallest values 
            if len(distances) > self.k:#past k values remove largest from heap
                heapq.heappop(distances)
        
        k_neighbours = [[-dist, index, train_row] for dist, index, train_row in sorted(distances)]#make positive values, only 5 smallest remain

        return k_neighbours
    
    def __foldSplit(self, data, k_folds):
        '''
        ===================================================================================
        DESCRIPTION: 
        ===================================================================================
        split data into folds used for kFoldCross function 
        ===================================================================================
        PARAMETERS:
        ===================================================================================
        * self (kNN): [not used]
        ----------------------------------------
        kNN model with predefined k values, training data, and distance metric
        ----------------------------------------
        * data (numpy array):
        ----------------------------------------
        data to split into training and test data based on k value
        ----------------------------------------
        * k_folds (int):
        ----------------------------------------
        number of folds to split data into       
        ===================================================================================
        '''  
        data_size = len(data)
        fold_size = data_size//k_folds
        data_split = []
        
        for i in range(k_folds):
#             print(i)
            start_i = i * fold_size
            end_i = (i + 1) * fold_size if i < k_folds - 1 else len(data)

            # Extract the test data for this fold
            test_data = data[start_i:end_i]
#             print(test_data)

            # Extract the training data for this fold
            train_data = np.concatenate([data[:start_i], data[end_i:]], axis=0)
            data_split.append((train_data, test_data))        
        return data_split
    
    def kFoldCross(self, data, k_folds):
        '''
        ===================================================================================
        DESCRIPTION: 
        ===================================================================================
        A script to run an evaluation of the same data with different training values based 
        on k Fold cross validatio 
        ===================================================================================
        PARAMETERS:
        ===================================================================================
        * self (kNN): [not used]
        ----------------------------------------
        kNN model with predefined k values, training data, and distance metric
        ----------------------------------------
        * data (numpy array):
        ----------------------------------------
        data to split into training and test data based on k value
        ----------------------------------------
        * k_folds (int):
        ----------------------------------------
        number of folds to split data into       
        ===================================================================================
        '''    
        
        dataSplit = self.__foldSplit(data,k_folds)
        size = len(dataSplit)
        accAvg = 0
        
        for i in range(size):
            print("=================================")
            print(f"Training with Fold {i+1}")
            print("---------------------------------")

            train_data_list,test_data_list = dataSplit[i]
            train_data, train_labels = self.__seperateLabels(train_data_list)
            test_data, test_labels = self.__seperateLabels(test_data_list)
            
            self.fit(train_data, train_labels)
            predictions = self.predict(test_data)
            accAvg += self.evaluate_acc(predictions, test_labels)
        accAvg/=k_folds
        print(f"Average Accuracy: %{accAvg}")
        return accAvg
            

        
    def __seperateLabels(self, data):
        '''
        ===================================================================================
        DESCRIPTION: 
        ===================================================================================
        seperate data into values and classifications (data,labels)
        ===================================================================================
        PARAMETERS:
        ===================================================================================
        * self (kNN): [not used]
        ----------------------------------------
        kNN model with predefined k values, training data, and distance metric
        ----------------------------------------
        * data (NumPy Array):
        ----------------------------------------
        data imported for assignment
        ===================================================================================
        RETURNS:
        ===================================================================================
        * values , labels
        ----------------------------------------
        a tuple of 2 numpy arrays, one of data and one of labels
        ===================================================================================
        '''
        values = data[:,:-1].astype(float)#data only
        labels = data[:,-1]#classifications only
        
        return (values,labels)
        
    def testTrainSplit(self, data, testSplit=0.7):
        '''
        ===================================================================================
        DESCRIPTION: 
        ===================================================================================
        Used externally to split data into test and train data. probably remove later
        ===================================================================================
        PARAMETERS:
        ===================================================================================
        * self (kNN): [not used]
        ----------------------------------------
        kNN model with predefined k values, training data, and distance metric
        ----------------------------------------
        * data (NumPy Array):
        ----------------------------------------
        data imported for assignment
        ----------------------------------------
        * testSplit (float):
        ----------------------------------------
        ratio of data to be used for testing, default 70/30 split
        ===================================================================================
        RETURNS:
        ===================================================================================
        * dataSplit (tuple(List1,List2)):
        ----------------------------------------
        a tuple of 2 lists where list 1 contains training data and training labels,
        similarily list 2 contains test data and tes labels
        ===================================================================================
        '''
        split = int(len(data) * testSplit )
        #Split train data (70% standard)
        train_data, train_labels = self.__seperateLabels(data[:split]) 
        test_data, test_labels = self.__seperateLabels(data[split:])
        
        dataSplit = ([train_data, train_labels], [test_data, test_labels])
        
        return(dataSplit)

# %%
model1 = kNN(3)
model1.kFoldCross(ionosphere_data,3)
# Out:
# =================================
# Training with Fold 1
# ---------------------------------
# Success Rate: %71.79
# =================================
# Training with Fold 2
# ---------------------------------
# Success Rate: %76.92
# =================================
# Training with Fold 3
# ---------------------------------
# Success Rate: %95.73
# Average Accuracy: %81.48
# 81.48

# %%
model2 = kNN(3)
model2.kFoldCross(cleaned_data,3)
# Out:
# =================================
# Training with Fold 1
# ---------------------------------
# Success Rate: %75.08
# =================================
# Training with Fold 2
# ---------------------------------
# Success Rate: %74.91
# =================================
# Training with Fold 3
# ---------------------------------
# Success Rate: %74.93
# Average Accuracy: %74.97333333333334
# 74.97333333333334

# %%
# model2 = kNN(5)
# train,test = model2.testTrainSplit(adult_data)
# model2.fit(train[0],train[1])
# predictions = model2.predict(test[0])



model3 = kNN(3)
# train,test = model3.testTrainSplit(rice_data)
# model3.fit(train[0],train[1])
# predictions = model3.predict(test[0])
model3.kFoldCross(result,3)

# model4 = kNN(3)
# train,test = model4.testTrainSplit(cars_data)
# model.fit(train[0],train[1])
# predictions = model4.predict(test[0])
# Out:
# =================================
# Training with Fold 1
# ---------------------------------
# Success Rate: %83.57
# =================================
# Training with Fold 2
# ---------------------------------
# Success Rate: %100.0
# =================================
# Training with Fold 3
# ---------------------------------
# Success Rate: %77.05
# Average Accuracy: %86.87333333333333

# %%
model4 = kNN(3)
model4.kFoldCross(rice_data,3)
# Out:
# =================================
# Training with Fold 1
# ---------------------------------
# Success Rate: %74.09
# =================================
# Training with Fold 2
# ---------------------------------
# Success Rate: %87.17
# =================================
# Training with Fold 3
# ---------------------------------
# Success Rate: %84.49
# Average Accuracy: %81.91666666666667

# %% [markdown]
# ## Task 3: Run Experiments
#
# The goal of this project is to have you explore linear classification and compare different features and models. Use
# 5-fold cross-validation to estimate performance in all of the experiments. Evaluate the performance using accuracy.
# You are welcome to perform any experiments and analyses you see fit (e.g., to compare different features), but at a
# minimum, you must complete the following experiments in the order stated below:
#
# #### 1. Compare the accuracy of k-nearest neighbor and logistic regression on the four datasets.
#
# #### 2. Test different k values for the k-nearest neighbor to find the best k-value by showing the accuracy plot.
#
# #### 3. Test different learning rates for gradient descent applied to logistic regression. Use a threshold for change in the value of the cost function as termination criteria and plot the accuracy on the train/validation set as a function of iterations of gradient descent.
#
# #### 4. Compare the accuracy of the two models as a function of the size of the dataset (by controlling the training size)
#
# Note: The above experiments are the minimum requirements that you must complete; however, this project is open-ended. For example, you might investigate different stopping criteria for gradient descent in logistic regression and develop an automated approach to select a good subset of features. You do not need to do all of these things, but you should demonstrate creativity, rigor, and an understanding of the course material in how you run your chosen experiments and how you report on them in your write-up.

# %%
## Testing KNN logic w/ Dataset 1
# Just arbitrairly choosing k = 5 to start, and 70/30 training/test data distribution

len_training_data = int( len(ionosphere_data) * 0.7 )
print("Length of training data set:", len_training_data)
ionosphere_train = ionosphere_data[:len_training_data] # 0 to length of training data
ionosphere_test = ionosphere_data[len_training_data+1:] # should grab everything after what we want as training data

iono_knn = knn(5, ionosphere_train, ionosphere_test)
print("5 Nearest Neighbours for Ionosphere Data:")
print(iono_knn)
# Out:
# Length of training data set: 245
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/radams/MiniProject1/CP322-A1-Group6-code.ipynb Cell 23 line 9
#       <a href='vscode-notebook-cell://wsl%2Bkali-linux/home/radams/MiniProject1/CP322-A1-Group6-code.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> ionosphere_train = ionosphere_data[:len_training_data] # 0 to length of training data
#       <a href='vscode-notebook-cell://wsl%2Bkali-linux/home/radams/MiniProject1/CP322-A1-Group6-code.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> ionosphere_test = ionosphere_data[len_training_data+1:] # should grab everything after what we want as training data
# ----> <a href='vscode-notebook-cell://wsl%2Bkali-linux/home/radams/MiniProject1/CP322-A1-Group6-code.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> iono_knn = knn(5, ionosphere_train, ionosphere_test)
#      <a href='vscode-notebook-cell://wsl%2Bkali-linux/home/radams/MiniProject1/CP322-A1-Group6-code.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> print("5 Nearest Neighbours for Ionosphere Data:")
#      <a href='vscode-notebook-cell://wsl%2Bkali-linux/home/radams/MiniProject1/CP322-A1-Group6-code.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> print(iono_knn)
#
# NameError: name 'knn' is not defined
